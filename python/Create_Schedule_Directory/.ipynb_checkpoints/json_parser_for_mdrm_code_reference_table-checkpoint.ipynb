# %% [markdown]
# ## pip install
# #### xmltodict
# #### networkx
# #### tqdm

# %%
import os
import pandas as pd
import sys
import regex as re
import numpy as np
import datetime
import time
from ffiec_data_connect import methods, credentials, ffiec_connection
creds = credentials.WebserviceCredentials(username="whills12", password="vGzHZX7EAsPCwfXuV6pI")
conn = ffiec_connection.FFIECConnection()

# %%
import snowflake.connector as snow

# %%
def extract_taxonomy_data(df, form_id):
    data_list = []
    for i in range(len(df)):
        mdrm_code = re.split('_',df.index[i])[1]
        keys_list = list(df["data"][i].keys())
        schedule_type = keys_list[0]
        subset_of_data = df["data"][i][keys_list[0]]
        schedule_label = subset_of_data['line_ids']['schedule']['label']
        mdrm_label = subset_of_data['line_ids']['extra_col_0']['label']
        if len(subset_of_data['line_ids']) > 2: 
            j = 1 
            while True:
                try:
                    mdrm_label += subset_of_data['line_ids'][f'extra_col_{j}']['label']
                    j += 1
                except TypeError:
                    j+=1
                    continue
                except KeyError:
                    break
        data_list.append({
            'mdrm_code': mdrm_code,
            'schedule_type': schedule_type,
            'schedule_label': schedule_label,
            'mdrm_label': mdrm_label,
            'form_type': form_id
        })
    final_df = pd.DataFrame(data_list)
    return final_df

# %%
def match_data_type(id_rssd_set, mdrm_set):
    master_data_type_list = []
    trials = 0
    print("The time of code execution begin is : ", time.ctime())
    while len(mdrm_set) != 0 and trials < len(id_rssd_set):
        for id_rssd in id_rssd_set:
                time_series = methods.collect_data(
                session=conn,
                creds=creds,
                rssd_id=id_rssd,
                reporting_period="9/30/2023",
                series="call",
                output_type='pandas'
                )
                for mdrm in mdrm_set.copy():
                    if mdrm in time_series['mdrm'].values:
                        data_type = time_series['data_type'][time_series['mdrm']==mdrm].values[0]
                        pair_mdrm_type = (mdrm,data_type)
                        master_data_type_list.append(pair_mdrm_type)
                        mdrm_set.remove(mdrm)
                trials +=1
                if not mdrm_set:
                    break
                time.sleep(1.5)
    print("The time of code execution end was : ", time.ctime())
    return master_data_type_list

# %%
def filter_mdrm(path):
    mdrm_csv = pd.read_csv(path, skiprows=1)
    mdrm_csv.insert(2, 'mdrm_code', mdrm_csv['Mnemonic'] + mdrm_csv['Item Code'])
    mdrm_filtered = mdrm_csv[(mdrm_csv['Reporting Form'].isin(in_report)) & (~mdrm_csv['Mnemonic'].isin(not_mnemonic))]
    mdrm_filtered.rename(columns={"Reporting Form": "form_type"},inplace=True)
    return mdrm_filtered

# %%
def create_table_query(table_name, columns_dict):
    columns = list(columns_dict.keys())
    data_types = list(columns_dict.values())

    if len(columns) != len(data_types):
        raise ValueError("Number of columns and data types must be the same.")

    columns_str = ', '.join([f'{col} {data_type}' for col, data_type in zip(columns, data_types)])
    query = f'CREATE TABLE IF NOT EXISTS {table_name} ({columns_str}, primary key (IDRSSD, RCON9999));'

    return query

# %%
def gather_all_queries(final_df):
    create_queries_list= []
    schedules = set(final_df['schedule_type'])
    for s in schedules:
        schedule_dict_list = {sd['mdrm_code']: sd['data_type'] for sd in final_df.loc[final_df['schedule_type'].isin([s]), ['mdrm_code', 'data_type']].to_dict(orient='records')}
        bank_id = 'IDRSSD'
        bank_id_data_type = 'VARCHAR'
        report_date = 'RCON9999'
        report_date_data_type= 'DATE'
        for key,item in schedule_dict_list.items():
            if item == 'str':
                schedule_dict_list[key] = 'VARCHAR'
            elif item in ['float','int']:
                schedule_dict_list[key] = 'FLOAT'
            elif item == 'bool':
                schedule_dict_list[key] = 'BOOLEAN'   
        if bank_id in schedule_dict_list:
            my_dict[bank_id] = bank_id_data_type
        else:
            schedule_dict_list[bank_id] = bank_id_data_type
        if report_date in schedule_dict_list:
            schedule_dict_list[report_date] = report_date_data_type
        else:
            schedule_dict_list[report_date] = report_date_data_type
        create_queries_list.append(create_table_query(f'Schedule_{s}', schedule_dict_list))
    return create_queries_list

# %%
full_query_list = gather_all_queries(final_df)

# %%
for query in full_query_list:
    print(query)
# Out:
# CREATE TABLE IF NOT EXISTS Schedule_RIE (RIAD0497 FLOAT, RIAD4042 FLOAT, RIAD4136 FLOAT, RIAD4141 FLOAT, RIAD4146 VARCHAR, RIAD4461 FLOAT, RIAD4462 FLOAT, RIAD4463 FLOAT, RIAD4464 FLOAT, RIAD4467 FLOAT, RIAD4468 FLOAT, RIAD4486 VARCHAR, RIAD4487 VARCHAR, RIAD4488 VARCHAR, RIAD4489 VARCHAR, RIAD4491 VARCHAR, RIAD4498 FLOAT, RIAD4499 FLOAT, RIAD4521 FLOAT, RIAD4522 FLOAT, RIAD4769 BOOLEAN, RIAD8403 FLOAT, RIADB526 FLOAT, RIADB527 FLOAT, RIADC013 FLOAT, RIADC014 FLOAT, RIADC015 FLOAT, RIADC016 FLOAT, RIADC017 FLOAT, RIADC018 FLOAT, RIADF555 FLOAT, RIADF556 FLOAT, RIADF557 FLOAT, RIADF558 FLOAT, RIADF559 FLOAT, RIADFT29 FLOAT, RIADFT30 FLOAT, RIADFT31 FLOAT, RIADFT32 FLOAT, RIADJJ26 FLOAT, RIADJJ27 FLOAT, RIADJJ28 FLOAT, RIADT047 FLOAT, RIADY923 FLOAT, RIADY924 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCRI (RCFA2170 FLOAT, RCFA3128 FLOAT, RCFA3792 FLOAT, RCFA5310 FLOAT, RCFA5311 FLOAT, RCFA7204 FLOAT, RCFA7205 FLOAT, RCFA7206 FLOAT, RCFA8274 FLOAT, RCFAA223 FLOAT, RCFAA224 FLOAT, RCFAB530 FLOAT, RCFAB596 FLOAT, RCFAH015 FLOAT, RCFAH036 FLOAT, RCFAH311 FLOAT, RCFAH313 VARCHAR, RCFAH314 VARCHAR, RCFAJJ30 FLOAT, RCFAJJ31 FLOAT, RCFAJJ32 FLOAT, RCFAKW00 FLOAT, RCFAKW03 FLOAT, RCFAKX77 FLOAT, RCFAKX78 FLOAT, RCFAKX79 FLOAT, RCFAKX80 FLOAT, RCFAKX81 FLOAT, RCFAKX82 FLOAT, RCFAKX83 FLOAT, RCFALB58 FLOAT, RCFALB59 FLOAT, RCFALB60 FLOAT, RCFALB61 FLOAT, RCFAP742 FLOAT, RCFAP793 FLOAT, RCFAP839 FLOAT, RCFAP840 FLOAT, RCFAP841 FLOAT, RCFAP842 FLOAT, RCFAP843 FLOAT, RCFAP844 FLOAT, RCFAP846 FLOAT, RCFAP847 FLOAT, RCFAP848 FLOAT, RCFAP849 FLOAT, RCFAP850 FLOAT, RCFAP852 FLOAT, RCFAP857 FLOAT, RCFAP858 FLOAT, RCFAP859 FLOAT, RCFAP860 FLOAT, RCFAP861 FLOAT, RCFAP862 FLOAT, RCFAP863 FLOAT, RCFAP864 FLOAT, RCFAP865 FLOAT, RCFAP866 FLOAT, RCFAP867 FLOAT, RCFAP868 FLOAT, RCFAP870 FLOAT, RCFAP872 FLOAT, RCFAP875 FLOAT, RCFAQ258 FLOAT, RCFAS540 FLOAT, RCFW3792 FLOAT, RCFW5310 FLOAT, RCFW5311 FLOAT, RCFW7205 FLOAT, RCFW7206 FLOAT, RCFWA223 FLOAT, RCFWH312 FLOAT, RCFWP793 FLOAT, RCFWP851 FLOAT, RCFWP852 FLOAT, RCFWP853 FLOAT, RCFWP854 FLOAT, RCFWP855 FLOAT, RCFWP856 FLOAT, RCFWP857 FLOAT, RCFWP858 FLOAT, RCFWP859 FLOAT, RCFWP870 FLOAT, RCOA2170 FLOAT, RCOA3128 FLOAT, RCOA3792 FLOAT, RCOA5310 FLOAT, RCOA5311 FLOAT, RCOA7204 FLOAT, RCOA7205 FLOAT, RCOA7206 FLOAT, RCOA8274 FLOAT, RCOAA223 FLOAT, RCOAA224 FLOAT, RCOAB530 FLOAT, RCOAB596 FLOAT, RCOAH311 FLOAT, RCOAH313 FLOAT, RCOAH314 FLOAT, RCOAJJ29 FLOAT, RCOAJJ30 FLOAT, RCOAJJ31 FLOAT, RCOAJJ32 FLOAT, RCOAKW00 FLOAT, RCOAKX77 FLOAT, RCOAKX78 FLOAT, RCOAKX79 FLOAT, RCOAKX80 FLOAT, RCOAKX81 FLOAT, RCOAKX82 FLOAT, RCOAKX83 FLOAT, RCOALB58 FLOAT, RCOALB59 FLOAT, RCOALB60 FLOAT, RCOALB61 FLOAT, RCOALE74 FLOAT, RCOANC99 FLOAT, RCOAP742 FLOAT, RCOAP793 FLOAT, RCOAP838 FLOAT, RCOAP839 FLOAT, RCOAP840 FLOAT, RCOAP841 FLOAT, RCOAP842 FLOAT, RCOAP843 FLOAT, RCOAP844 FLOAT, RCOAP846 FLOAT, RCOAP847 FLOAT, RCOAP848 FLOAT, RCOAP849 FLOAT, RCOAP850 FLOAT, RCOAP852 FLOAT, RCOAP857 FLOAT, RCOAP858 FLOAT, RCOAP859 FLOAT, RCOAP860 FLOAT, RCOAP861 FLOAT, RCOAP862 FLOAT, RCOAP863 FLOAT, RCOAP864 FLOAT, RCOAP865 FLOAT, RCOAP866 FLOAT, RCOAP867 FLOAT, RCOAP868 FLOAT, RCOAP870 FLOAT, RCOAP872 FLOAT, RCOAP875 FLOAT, RCOAQ258 FLOAT, RCOAS540 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCH (RCON0211 FLOAT, RCON1039 VARCHAR, RCON1041 VARCHAR, RCON1042 VARCHAR, RCON1043 VARCHAR, RCON1044 VARCHAR, RCON1209 VARCHAR, RCON1280 VARCHAR, RCON1281 VARCHAR, RCON1282 VARCHAR, RCON1287 FLOAT, RCON1374 VARCHAR, RCON1709 FLOAT, RCON1713 FLOAT, RCON1733 FLOAT, RCON1736 FLOAT, RCON1752 FLOAT, RCON1754 FLOAT, RCON1773 FLOAT, RCON2155 VARCHAR, RCON2163 FLOAT, RCON2192 FLOAT, RCON2920 VARCHAR, RCON2941 FLOAT, RCON3129 FLOAT, RCON3190 FLOAT, RCON3545 FLOAT, RCON3548 FLOAT, RCON8492 FLOAT, RCON8495 FLOAT, RCON8496 FLOAT, RCON8499 FLOAT, RCONA510 VARCHAR, RCONB989 FLOAT, RCONB995 FLOAT, RCONG389 FLOAT, RCONG390 FLOAT, RCONG393 FLOAT, RCONG394 FLOAT, RCONG397 FLOAT, RCONG398 FLOAT, RCONG399 FLOAT, RCONG400 FLOAT, RCONHT71 FLOAT, RCONJA22 FLOAT, RCONJF75 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_SU (RCON8725 FLOAT, RCONA126 FLOAT, RCONC391 FLOAT, RCONFT00 BOOLEAN, RCONFT01 FLOAT, RCONFT02 FLOAT, RCONFT03 BOOLEAN, RCONFT04 FLOAT, RCONFT05 FLOAT, RCONFT06 BOOLEAN, RCONFT07 BOOLEAN, RCONFT08 FLOAT, RCONFT09 BOOLEAN, RCONFT10 FLOAT, RCONFT11 BOOLEAN, RCONFT12 FLOAT, RCONFT13 BOOLEAN, RCONFT14 FLOAT, RCONFT15 FLOAT, RCONFT16 BOOLEAN, RCONHK18 FLOAT, RCONHK19 FLOAT, RIADC388 FLOAT, RIADC389 FLOAT, RIADC390 FLOAT, RIADF551 FLOAT, RIADF553 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RC (RCFD0071 FLOAT, RCFD0081 FLOAT, RCFD0426 VARCHAR, RCFD2130 FLOAT, RCFD2145 FLOAT, RCFD2155 VARCHAR, RCFD2920 VARCHAR, RCFD2948 FLOAT, RCFD3000 FLOAT, RCFD3200 FLOAT, RCFD3210 FLOAT, RCFD3230 FLOAT, RCFD3300 FLOAT, RCFD3632 FLOAT, RCFD3656 FLOAT, RCFD3838 FLOAT, RCFD3839 FLOAT, RCFD5369 FLOAT, RCFD6724 VARCHAR, RCFDA130 FLOAT, RCFDB528 FLOAT, RCFDB529 FLOAT, RCFDB530 FLOAT, RCFDB989 FLOAT, RCFDB995 FLOAT, RCFDG105 FLOAT, RCFDJA22 FLOAT, RCFDJJ34 FLOAT, RCFN6631 FLOAT, RCFN6636 FLOAT, RCON0071 FLOAT, RCON0081 FLOAT, RCON2130 FLOAT, RCON2145 FLOAT, RCON2200 FLOAT, RCON2948 FLOAT, RCON3000 FLOAT, RCON3200 FLOAT, RCON3210 FLOAT, RCON3230 FLOAT, RCON3300 FLOAT, RCON3545 FLOAT, RCON3548 FLOAT, RCON3632 FLOAT, RCON3656 FLOAT, RCON3838 FLOAT, RCON3839 FLOAT, RCON5369 FLOAT, RCON6631 FLOAT, RCON6636 FLOAT, RCON6724 VARCHAR, RCON8678 FLOAT, RCONA130 FLOAT, RCONB528 FLOAT, RCONB529 FLOAT, RCONB530 FLOAT, RCONB987 FLOAT, RCONB989 FLOAT, RCONB993 FLOAT, RCONB995 FLOAT, RCONG105 FLOAT, RCONJA22 FLOAT, RCONJJ34 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RIBII (RCFDJJ03 FLOAT, RCONJJ03 FLOAT, RIAD3123 FLOAT, RIAD4230 FLOAT, RIAD4605 FLOAT, RIAD5523 FLOAT, RIADB522 FLOAT, RIADC079 FLOAT, RIADC233 FLOAT, RIADC389 FLOAT, RIADC390 FLOAT, RIADC435 FLOAT, RIADC781 FLOAT, RIADJH88 FLOAT, RIADJH89 FLOAT, RIADJH90 FLOAT, RIADJH91 FLOAT, RIADJH92 FLOAT, RIADJH93 FLOAT, RIADJH94 FLOAT, RIADJH95 FLOAT, RIADJH96 FLOAT, RIADJH97 FLOAT, RIADJH98 FLOAT, RIADJH99 FLOAT, RIADJJ00 FLOAT, RIADJJ01 FLOAT, RIADJJ02 FLOAT, RIADMG93 FLOAT, RIADMG94 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCN (RCFD1248 FLOAT, RCFD1249 FLOAT, RCFD1250 FLOAT, RCFD1251 FLOAT, RCFD1252 FLOAT, RCFD1253 FLOAT, RCFD1254 FLOAT, RCFD1255 FLOAT, RCFD1256 FLOAT, RCFD1257 VARCHAR, RCFD1258 VARCHAR, RCFD1259 VARCHAR, RCFD1271 VARCHAR, RCFD1272 VARCHAR, RCFD1403 FLOAT, RCFD1406 FLOAT, RCFD1407 FLOAT, RCFD1583 FLOAT, RCFD1594 FLOAT, RCFD1597 FLOAT, RCFD1658 VARCHAR, RCFD1659 VARCHAR, RCFD1661 VARCHAR, RCFD1791 VARCHAR, RCFD3505 FLOAT, RCFD3506 FLOAT, RCFD3507 FLOAT, RCFD3529 FLOAT, RCFD3530 FLOAT, RCFD5377 FLOAT, RCFD5378 FLOAT, RCFD5379 FLOAT, RCFD5380 FLOAT, RCFD5381 FLOAT, RCFD5382 FLOAT, RCFD5389 FLOAT, RCFD5390 FLOAT, RCFD5391 FLOAT, RCFD5459 FLOAT, RCFD5460 FLOAT, RCFD5461 FLOAT, RCFD5612 VARCHAR, RCFD5613 VARCHAR, RCFD5614 VARCHAR, RCFD5615 VARCHAR, RCFD5616 VARCHAR, RCFD5617 VARCHAR, RCFD6558 FLOAT, RCFD6559 FLOAT, RCFD6560 FLOAT, RCFDB575 FLOAT, RCFDB576 FLOAT, RCFDB577 FLOAT, RCFDB578 FLOAT, RCFDB579 FLOAT, RCFDB580 FLOAT, RCFDC226 FLOAT, RCFDC240 FLOAT, RCFDC241 FLOAT, RCFDC410 VARCHAR, RCFDC411 VARCHAR, RCFDF166 FLOAT, RCFDF167 FLOAT, RCFDF168 FLOAT, RCFDF169 FLOAT, RCFDF170 FLOAT, RCFDF171 FLOAT, RCFDHK26 FLOAT, RCFDHK27 FLOAT, RCFDHK28 FLOAT, RCFDK036 FLOAT, RCFDK037 FLOAT, RCFDK038 FLOAT, RCFDK039 FLOAT, RCFDK040 FLOAT, RCFDK041 FLOAT, RCFDK042 FLOAT, RCFDK043 FLOAT, RCFDK044 FLOAT, RCFDK102 FLOAT, RCFDK103 FLOAT, RCFDK104 FLOAT, RCFDK120 FLOAT, RCFDK121 FLOAT, RCFDK122 FLOAT, RCFDK123 FLOAT, RCFDK124 FLOAT, RCFDK125 FLOAT, RCFDK126 FLOAT, RCFDK127 FLOAT, RCFDK128 FLOAT, RCFDK138 FLOAT, RCFDK139 FLOAT, RCFDK140 FLOAT, RCFDK213 FLOAT, RCFDK214 FLOAT, RCFDK215 FLOAT, RCFDK216 FLOAT, RCFDK217 FLOAT, RCFDK218 FLOAT, RCFDK274 FLOAT, RCFDK275 FLOAT, RCFDK276 FLOAT, RCFDK277 FLOAT, RCFDK278 FLOAT, RCFDK279 FLOAT, RCFDK280 FLOAT, RCFDK281 FLOAT, RCFDK282 FLOAT, RCFDL183 VARCHAR, RCFDL184 VARCHAR, RCFDL185 VARCHAR, RCFDL186 VARCHAR, RCFDL187 VARCHAR, RCFDL188 VARCHAR, RCFNB572 FLOAT, RCFNB573 FLOAT, RCFNB574 FLOAT, RCON1226 FLOAT, RCON1227 FLOAT, RCON1228 FLOAT, RCON1403 FLOAT, RCON1406 FLOAT, RCON1407 FLOAT, RCON1583 FLOAT, RCON1594 FLOAT, RCON1597 FLOAT, RCON1606 FLOAT, RCON1607 FLOAT, RCON1608 FLOAT, RCON2759 VARCHAR, RCON2769 VARCHAR, RCON3492 VARCHAR, RCON3493 FLOAT, RCON3494 FLOAT, RCON3495 FLOAT, RCON3499 FLOAT, RCON3500 FLOAT, RCON3501 FLOAT, RCON3502 VARCHAR, RCON3503 VARCHAR, RCON3504 VARCHAR, RCON3505 FLOAT, RCON3506 FLOAT, RCON3507 FLOAT, RCON5398 FLOAT, RCON5399 FLOAT, RCON5400 FLOAT, RCON5459 FLOAT, RCON5460 FLOAT, RCON5461 FLOAT, RCON6558 FLOAT, RCON6559 FLOAT, RCON6560 FLOAT, RCONB575 FLOAT, RCONB576 FLOAT, RCONB577 FLOAT, RCONB834 FLOAT, RCONB835 FLOAT, RCONB836 FLOAT, RCONC226 FLOAT, RCONC229 FLOAT, RCONC230 FLOAT, RCONC236 FLOAT, RCONC237 FLOAT, RCONC238 FLOAT, RCONC239 FLOAT, RCONC240 FLOAT, RCONC241 FLOAT, RCONC410 FLOAT, RCONC411 FLOAT, RCONF172 FLOAT, RCONF173 FLOAT, RCONF174 FLOAT, RCONF175 FLOAT, RCONF176 FLOAT, RCONF177 FLOAT, RCONF178 FLOAT, RCONF179 FLOAT, RCONF180 FLOAT, RCONF181 FLOAT, RCONF182 FLOAT, RCONF183 FLOAT, RCONF661 FLOAT, RCONF662 FLOAT, RCONF663 FLOAT, RCONHK26 FLOAT, RCONHK27 FLOAT, RCONHK28 FLOAT, RCONK036 FLOAT, RCONK037 FLOAT, RCONK038 FLOAT, RCONK039 FLOAT, RCONK040 FLOAT, RCONK041 FLOAT, RCONK042 FLOAT, RCONK043 FLOAT, RCONK044 FLOAT, RCONK103 FLOAT, RCONK104 FLOAT, RCONK105 FLOAT, RCONK106 FLOAT, RCONK107 FLOAT, RCONK108 FLOAT, RCONK109 FLOAT, RCONK110 FLOAT, RCONK111 FLOAT, RCONK112 FLOAT, RCONK113 FLOAT, RCONK114 FLOAT, RCONK115 FLOAT, RCONK116 FLOAT, RCONK117 FLOAT, RCONK118 FLOAT, RCONK119 FLOAT, RCONK126 FLOAT, RCONK127 FLOAT, RCONK128 FLOAT, RCONK130 FLOAT, RCONK131 FLOAT, RCONK132 FLOAT, RCONK138 FLOAT, RCONK139 FLOAT, RCONK140 FLOAT, RCONK213 FLOAT, RCONK214 FLOAT, RCONK215 FLOAT, RCONK216 FLOAT, RCONK217 FLOAT, RCONK218 FLOAT, RCONK257 FLOAT, RCONK258 FLOAT, RCONK259 FLOAT, RCONK274 FLOAT, RCONK275 FLOAT, RCONK276 FLOAT, RCONK277 FLOAT, RCONK278 FLOAT, RCONK279 FLOAT, RCONK280 FLOAT, RCONK281 FLOAT, RCONK282 FLOAT, RCONL183 FLOAT, RCONL184 FLOA ...
# CREATE TABLE IF NOT EXISTS Schedule_RCT (RCFDA345 BOOLEAN, RCFDA346 BOOLEAN, RCFDB867 BOOLEAN, RCFDB868 FLOAT, RCFDB869 FLOAT, RCFDB870 FLOAT, RCFDB871 FLOAT, RCFDB872 FLOAT, RCFDB873 FLOAT, RCFDB874 FLOAT, RCFDB875 FLOAT, RCFDB876 FLOAT, RCFDB877 FLOAT, RCFDB878 FLOAT, RCFDB879 FLOAT, RCFDB880 FLOAT, RCFDB881 FLOAT, RCFDB882 FLOAT, RCFDB883 FLOAT, RCFDB884 FLOAT, RCFDB885 FLOAT, RCFDB886 FLOAT, RCFDB888 FLOAT, RCFDB890 FLOAT, RCFDB891 FLOAT, RCFDB892 FLOAT, RCFDB893 FLOAT, RCFDB894 FLOAT, RCFDB895 FLOAT, RCFDB896 FLOAT, RCFDB897 FLOAT, RCFDB898 FLOAT, RCFDB899 FLOAT, RCFDB927 FLOAT, RCFDB928 FLOAT, RCFDB929 VARCHAR, RCFDB931 FLOAT, RCFDB932 FLOAT, RCFDB933 FLOAT, RCFDB934 FLOAT, RCFDB935 FLOAT, RCFDB936 FLOAT, RCFDB937 FLOAT, RCFDB938 FLOAT, RCFDB939 FLOAT, RCFDB940 FLOAT, RCFDB941 FLOAT, RCFDB942 FLOAT, RCFDB943 FLOAT, RCFDB944 FLOAT, RCFDB945 FLOAT, RCFDB946 FLOAT, RCFDC001 FLOAT, RCFDC002 FLOAT, RCFDJ253 FLOAT, RCFDJ254 FLOAT, RCFDJ255 FLOAT, RCFDJ256 FLOAT, RCFDJ257 FLOAT, RCFDJ258 FLOAT, RCFDJ259 FLOAT, RCFDJ260 FLOAT, RCFDJ261 FLOAT, RCFDJ262 FLOAT, RCFDJ263 VARCHAR, RCFDJ264 FLOAT, RCFDJ265 FLOAT, RCFDJ266 VARCHAR, RCFDJ267 VARCHAR, RCFDJ268 VARCHAR, RCFDJ269 VARCHAR, RCFDJ270 VARCHAR, RCFDJ271 VARCHAR, RCFDJ272 VARCHAR, RCFDJ273 VARCHAR, RCFDJ274 VARCHAR, RCFDJ275 VARCHAR, RCFDJ276 VARCHAR, RCFDJ277 VARCHAR, RCFDJ278 VARCHAR, RCFDJ279 VARCHAR, RCFDJ280 VARCHAR, RCFDJ281 VARCHAR, RCFDJ282 VARCHAR, RCFDJ283 VARCHAR, RCFDJ284 VARCHAR, RCFDJ285 VARCHAR, RCFDJ286 VARCHAR, RCFDJ287 VARCHAR, RCFDJ288 VARCHAR, RCFDJ289 VARCHAR, RCFDJ290 VARCHAR, RCFDJ291 VARCHAR, RCFDJ292 FLOAT, RCFDJ293 VARCHAR, RCFDJ294 VARCHAR, RCFDJ295 FLOAT, RCFDJ296 VARCHAR, RCFDJ297 VARCHAR, RCFDJ298 FLOAT, RCFDJ299 VARCHAR, RCFDJ300 VARCHAR, RCFDJ301 VARCHAR, RCFDJ302 VARCHAR, RCFDJ303 VARCHAR, RCFDJ304 FLOAT, RCFDJ305 VARCHAR, RCFDJ306 FLOAT, RCFDJ307 VARCHAR, RCFDJ308 VARCHAR, RCFDJ309 VARCHAR, RCFDJ310 VARCHAR, RCFDJ311 FLOAT, RCFDJ312 FLOAT, RCFDJ313 VARCHAR, RCFDJ314 VARCHAR, RCFNB900 FLOAT, RCFNB901 FLOAT, RCFNB902 FLOAT, RCFNB903 FLOAT, RCONA345 BOOLEAN, RCONA346 BOOLEAN, RCONB867 BOOLEAN, RCONB868 FLOAT, RCONB869 FLOAT, RCONB870 FLOAT, RCONB871 FLOAT, RCONB872 FLOAT, RCONB873 FLOAT, RCONB874 FLOAT, RCONB875 FLOAT, RCONB876 FLOAT, RCONB877 FLOAT, RCONB878 FLOAT, RCONB879 FLOAT, RCONB880 FLOAT, RCONB881 FLOAT, RCONB882 FLOAT, RCONB883 FLOAT, RCONB884 FLOAT, RCONB885 FLOAT, RCONB886 FLOAT, RCONB888 FLOAT, RCONB890 FLOAT, RCONB891 FLOAT, RCONB892 FLOAT, RCONB893 FLOAT, RCONB894 FLOAT, RCONB895 FLOAT, RCONB896 FLOAT, RCONB897 FLOAT, RCONB898 FLOAT, RCONB899 FLOAT, RCONB927 VARCHAR, RCONB928 VARCHAR, RCONB929 FLOAT, RCONB931 FLOAT, RCONB932 FLOAT, RCONB933 FLOAT, RCONB934 FLOAT, RCONB935 FLOAT, RCONB936 FLOAT, RCONB937 FLOAT, RCONB938 FLOAT, RCONB939 FLOAT, RCONB940 FLOAT, RCONB941 FLOAT, RCONB942 FLOAT, RCONB943 FLOAT, RCONB944 FLOAT, RCONB945 FLOAT, RCONB946 FLOAT, RCONC001 FLOAT, RCONC002 FLOAT, RCONJ253 FLOAT, RCONJ254 FLOAT, RCONJ255 FLOAT, RCONJ256 FLOAT, RCONJ257 FLOAT, RCONJ258 FLOAT, RCONJ259 FLOAT, RCONJ260 FLOAT, RCONJ261 FLOAT, RCONJ262 FLOAT, RCONJ263 FLOAT, RCONJ264 FLOAT, RCONJ265 FLOAT, RCONJ266 FLOAT, RCONJ267 FLOAT, RCONJ268 FLOAT, RCONJ269 FLOAT, RCONJ270 FLOAT, RCONJ271 FLOAT, RCONJ272 FLOAT, RCONJ273 FLOAT, RCONJ274 FLOAT, RCONJ275 FLOAT, RCONJ276 FLOAT, RCONJ277 FLOAT, RCONJ278 FLOAT, RCONJ279 FLOAT, RCONJ280 FLOAT, RCONJ281 FLOAT, RCONJ282 FLOAT, RCONJ283 FLOAT, RCONJ284 FLOAT, RCONJ285 FLOAT, RCONJ286 FLOAT, RCONJ287 FLOAT, RCONJ288 FLOAT, RCONJ289 FLOAT, RCONJ290 FLOAT, RCONJ291 FLOAT, RCONJ292 FLOAT, RCONJ293 FLOAT, RCONJ294 FLOAT, RCONJ295 FLOAT, RCONJ296 FLOAT, RCONJ297 FLOAT, RCONJ298 FLOAT, RCONJ299 FLOAT, RCONJ300 FLOAT, RCONJ301 FLOAT, RCONJ302 FLOAT, RCONJ303 FLOAT, RCONJ304 FLOAT, RCONJ305 FLOAT, RCONJ306 FLOAT, RCONJ307 FLOAT, RCONJ308 FLOAT, RCONJ309 FLOAT, RCONJ310 FLOAT, RCONJ311 VARCHAR, RCONJ312 VARCHAR, RCONJ313 VARCHAR, RCONJ314 VARCHAR, RIADA479 FLOAT, RIADA480 FLOAT, RIADA488 FLOAT, RIADA491 FLOAT, RIADB90 ...
# CREATE TABLE IF NOT EXISTS Schedule_LEO (RCFD3561 VARCHAR, RCFD3562 VARCHAR, RCFD7701 FLOAT, RCFD7702 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RID (RIAD4097 VARCHAR, RIAD4235 VARCHAR, RIAD4239 VARCHAR, RIAD4341 VARCHAR, RIAD4797 VARCHAR, RIAD4843 VARCHAR, RIAD4844 VARCHAR, RIAD4845 VARCHAR, RIAD4846 VARCHAR, RIADB523 VARCHAR, RIADB524 VARCHAR, RIADB525 VARCHAR, RIADC899 FLOAT, RIADC900 FLOAT, RIADC902 FLOAT, RIADC903 FLOAT, RIADC904 FLOAT, RIADC905 FLOAT, RIADC907 FLOAT, RIADC908 FLOAT, RIADC909 FLOAT, RIADC911 FLOAT, RIADC913 FLOAT, RIADC914 FLOAT, RIADGW64 FLOAT, RIADJA28 FLOAT, RIADKW02 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCS (RCFDA249 VARCHAR, RCFDA591 FLOAT, RCFDB705 FLOAT, RCFDB706 FLOAT, RCFDB707 FLOAT, RCFDB708 FLOAT, RCFDB709 FLOAT, RCFDB710 FLOAT, RCFDB711 FLOAT, RCFDB726 FLOAT, RCFDB727 FLOAT, RCFDB728 FLOAT, RCFDB729 FLOAT, RCFDB730 FLOAT, RCFDB731 FLOAT, RCFDB732 FLOAT, RCFDB733 FLOAT, RCFDB734 FLOAT, RCFDB735 FLOAT, RCFDB736 FLOAT, RCFDB737 FLOAT, RCFDB738 FLOAT, RCFDB739 FLOAT, RCFDB740 FLOAT, RCFDB741 FLOAT, RCFDB742 FLOAT, RCFDB743 FLOAT, RCFDB744 FLOAT, RCFDB745 FLOAT, RCFDB746 FLOAT, RCFDB776 FLOAT, RCFDB779 FLOAT, RCFDB780 FLOAT, RCFDB781 FLOAT, RCFDB782 FLOAT, RCFDB783 FLOAT, RCFDB786 FLOAT, RCFDB787 FLOAT, RCFDB788 FLOAT, RCFDB789 FLOAT, RCFDB790 FLOAT, RCFDB796 FLOAT, RCFDB797 FLOAT, RCFDB803 FLOAT, RCFDB804 FLOAT, RCFDB805 FLOAT, RCFDB806 FLOAT, RCFDB807 FLOAT, RCFDB808 FLOAT, RCFDB809 FLOAT, RCFDC407 FLOAT, RCFDF699 FLOAT, RCFDHU09 FLOAT, RCFDHU10 FLOAT, RCFDHU11 FLOAT, RCFDHU12 FLOAT, RCFDHU13 FLOAT, RCFDHU14 FLOAT, RCFDHU15 FLOAT, RCFDHU16 FLOAT, RCFDHU17 FLOAT, RCFDHU18 FLOAT, RIADB747 FLOAT, RIADB748 FLOAT, RIADB749 FLOAT, RIADB750 FLOAT, RIADB751 FLOAT, RIADB752 FLOAT, RIADB753 FLOAT, RIADB754 FLOAT, RIADB755 FLOAT, RIADB756 FLOAT, RIADB757 FLOAT, RIADB758 FLOAT, RIADB759 FLOAT, RIADB760 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCK (RCFD3353 FLOAT, RCFD3355 FLOAT, RCFD3365 FLOAT, RCFD3368 FLOAT, RCFD3381 FLOAT, RCFD3401 FLOAT, RCFD3484 FLOAT, RCFDB558 FLOAT, RCFDB559 FLOAT, RCFDB560 FLOAT, RCFN3360 FLOAT, RCFN3404 FLOAT, RCON3353 FLOAT, RCON3355 FLOAT, RCON3360 FLOAT, RCON3365 FLOAT, RCON3368 FLOAT, RCON3381 FLOAT, RCON3385 FLOAT, RCON3386 FLOAT, RCON3387 FLOAT, RCON3465 FLOAT, RCON3466 FLOAT, RCON3484 FLOAT, RCON3485 FLOAT, RCONA514 VARCHAR, RCONA529 VARCHAR, RCONB558 FLOAT, RCONB559 FLOAT, RCONB560 FLOAT, RCONB561 FLOAT, RCONB562 FLOAT, RCONB563 FLOAT, RCONHK16 FLOAT, RCONHK17 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCA (RCFD0010 FLOAT, RCFD0022 FLOAT, RCFD0070 FLOAT, RCFD0073 VARCHAR, RCFD0074 VARCHAR, RCFD0082 FLOAT, RCFD0083 VARCHAR, RCFD0085 VARCHAR, RCFD0090 FLOAT, RCON0010 FLOAT, RCON0020 FLOAT, RCON0070 FLOAT, RCON0080 FLOAT, RCON0082 FLOAT, RCON0090 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCM (RCFD2143 FLOAT, RCFD2150 FLOAT, RCFD2651 FLOAT, RCFD3163 FLOAT, RCFD3164 FLOAT, RCFD3190 FLOAT, RCFD4088 BOOLEAN, RCFD5372 VARCHAR, RCFD5374 VARCHAR, RCFD5375 VARCHAR, RCFD5507 VARCHAR, RCFD6164 FLOAT, RCFD6165 FLOAT, RCFDA590 FLOAT, RCFDB026 VARCHAR, RCFDB565 VARCHAR, RCFDB566 VARCHAR, RCFDB567 VARCHAR, RCFDB568 VARCHAR, RCFDB569 BOOLEAN, RCFDB570 FLOAT, RCFDB571 FLOAT, RCFDF055 FLOAT, RCFDF056 FLOAT, RCFDF057 FLOAT, RCFDF058 FLOAT, RCFDF059 FLOAT, RCFDF060 FLOAT, RCFDF061 FLOAT, RCFDF062 FLOAT, RCFDF063 FLOAT, RCFDF065 FLOAT, RCFDJA29 FLOAT, RCFDJF76 FLOAT, RCFDK192 FLOAT, RCFDK193 FLOAT, RCFDK194 FLOAT, RCFN5513 FLOAT, RCON2143 FLOAT, RCON2150 FLOAT, RCON2651 FLOAT, RCON3163 FLOAT, RCON3164 FLOAT, RCON3190 FLOAT, RCON4088 BOOLEAN, RCON5508 FLOAT, RCON5509 FLOAT, RCON5510 FLOAT, RCON5511 FLOAT, RCON5512 FLOAT, RCON6164 FLOAT, RCON6165 FLOAT, RCONA590 FLOAT, RCONB569 BOOLEAN, RCONB570 FLOAT, RCONB571 FLOAT, RCONF055 FLOAT, RCONF056 FLOAT, RCONF057 FLOAT, RCONF058 FLOAT, RCONF059 FLOAT, RCONF060 FLOAT, RCONF061 FLOAT, RCONF062 FLOAT, RCONF063 FLOAT, RCONF064 FLOAT, RCONF065 FLOAT, RCONG463 BOOLEAN, RCONG464 BOOLEAN, RCONJA29 FLOAT, RCONJF76 FLOAT, RCONK193 FLOAT, RCONK194 FLOAT, RCONL133 FLOAT, RCONL135 BOOLEAN, RCONLG26 FLOAT, RCONLG27 FLOAT, RCONLG28 FLOAT, RCONLL57 FLOAT, RCONLL59 FLOAT, RCONLL60 FLOAT, RCONMM07 VARCHAR, RCONMQ52 VARCHAR, RCONN523 VARCHAR, RCONN524 VARCHAR, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCD (RCFD3531 FLOAT, RCFD3532 FLOAT, RCFD3533 FLOAT, RCFD3541 FLOAT, RCFD3545 FLOAT, RCFD3546 FLOAT, RCFD3548 FLOAT, RCFDF614 FLOAT, RCFDF618 FLOAT, RCFDF624 FLOAT, RCFDF632 FLOAT, RCFDF636 FLOAT, RCFDF639 FLOAT, RCFDF640 FLOAT, RCFDF643 FLOAT, RCFDF644 FLOAT, RCFDF645 FLOAT, RCFDF646 FLOAT, RCFDF647 FLOAT, RCFDF648 FLOAT, RCFDF652 FLOAT, RCFDF653 FLOAT, RCFDF654 FLOAT, RCFDF655 FLOAT, RCFDF656 FLOAT, RCFDF657 FLOAT, RCFDF658 FLOAT, RCFDF659 FLOAT, RCFDF660 FLOAT, RCFDG299 FLOAT, RCFDG332 FLOAT, RCFDG333 FLOAT, RCFDG334 FLOAT, RCFDG335 FLOAT, RCFDG379 FLOAT, RCFDG380 FLOAT, RCFDG381 FLOAT, RCFDG386 FLOAT, RCFDG387 FLOAT, RCFDG388 FLOAT, RCFDG651 FLOAT, RCFDG652 FLOAT, RCFDHT62 FLOAT, RCFDHT63 FLOAT, RCFDHT64 FLOAT, RCFDHT65 FLOAT, RCFDHT66 FLOAT, RCFDHT67 FLOAT, RCFDHT68 FLOAT, RCFDK197 FLOAT, RCFDK198 FLOAT, RCFN3542 VARCHAR, RCFN3543 FLOAT, RCON3531 FLOAT, RCON3532 FLOAT, RCON3533 FLOAT, RCON3534 VARCHAR, RCON3535 VARCHAR, RCON3536 VARCHAR, RCON3537 VARCHAR, RCON3541 FLOAT, RCON3543 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCV (RCFDHU20 FLOAT, RCFDHU21 FLOAT, RCFDHU22 FLOAT, RCFDHU23 FLOAT, RCFDJ981 FLOAT, RCFDJF77 FLOAT, RCFDJF78 FLOAT, RCFDJF84 FLOAT, RCFDJF85 FLOAT, RCFDJF86 FLOAT, RCFDJF87 FLOAT, RCFDJF88 FLOAT, RCFDJF89 FLOAT, RCFDJF90 FLOAT, RCFDJF91 FLOAT, RCFDJF92 FLOAT, RCFDJF93 FLOAT, RCFDK009 FLOAT, RCFDK030 FLOAT, RCFDK033 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_ENT (RCON9224 VARCHAR, RCON9999 DATE, RSSD9017 VARCHAR, RSSD9130 VARCHAR, RSSD9200 VARCHAR, RSSD9220 VARCHAR, IDRSSD VARCHAR, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCEII (RCFN2200 FLOAT, RCFN2625 FLOAT, RCFN2650 FLOAT, RCFNA245 FLOAT, RCFNB553 FLOAT, RCFNB554 FLOAT, RCFNB555 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCG (RCFD2930 FLOAT, RCFD2932 FLOAT, RCFD2938 FLOAT, RCFD3049 FLOAT, RCFD3066 FLOAT, RCFD3552 FLOAT, RCFD3553 FLOAT, RCFD3554 FLOAT, RCFD3646 FLOAT, RCFDB557 FLOAT, RCFDC011 FLOAT, RCFDC012 FLOAT, RCFDLB56 FLOAT, RCON2930 FLOAT, RCON2932 FLOAT, RCON2938 FLOAT, RCON3049 FLOAT, RCON3066 FLOAT, RCON3552 FLOAT, RCON3553 FLOAT, RCON3554 FLOAT, RCON3645 FLOAT, RCON3646 FLOAT, RCONB557 FLOAT, RCONC011 FLOAT, RCONC012 FLOAT, RCONLB56 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCQ (RCFD3543 FLOAT, RCFD3547 FLOAT, RCFDF240 FLOAT, RCFDF241 FLOAT, RCFDF242 FLOAT, RCFDF252 FLOAT, RCFDF253 FLOAT, RCFDF254 FLOAT, RCFDF261 FLOAT, RCFDF262 FLOAT, RCFDF263 FLOAT, RCFDF585 FLOAT, RCFDF589 FLOAT, RCFDF597 FLOAT, RCFDF601 FLOAT, RCFDF684 FLOAT, RCFDF686 FLOAT, RCFDF689 FLOAT, RCFDF692 FLOAT, RCFDF694 FLOAT, RCFDF697 FLOAT, RCFDG391 FLOAT, RCFDG392 FLOAT, RCFDG395 FLOAT, RCFDG396 FLOAT, RCFDG474 FLOAT, RCFDG475 FLOAT, RCFDG476 FLOAT, RCFDG477 FLOAT, RCFDG478 FLOAT, RCFDG479 FLOAT, RCFDG480 FLOAT, RCFDG481 FLOAT, RCFDG482 FLOAT, RCFDG483 FLOAT, RCFDG484 FLOAT, RCFDG485 FLOAT, RCFDG486 FLOAT, RCFDG487 FLOAT, RCFDG488 FLOAT, RCFDG489 FLOAT, RCFDG490 FLOAT, RCFDG491 FLOAT, RCFDG492 FLOAT, RCFDG493 FLOAT, RCFDG494 FLOAT, RCFDG495 FLOAT, RCFDG496 FLOAT, RCFDG497 FLOAT, RCFDG498 FLOAT, RCFDG499 FLOAT, RCFDG500 FLOAT, RCFDG501 FLOAT, RCFDG502 FLOAT, RCFDG503 FLOAT, RCFDG504 FLOAT, RCFDG505 FLOAT, RCFDG506 FLOAT, RCFDG507 FLOAT, RCFDG508 FLOAT, RCFDG509 FLOAT, RCFDG510 FLOAT, RCFDG511 FLOAT, RCFDG512 FLOAT, RCFDG513 FLOAT, RCFDG514 FLOAT, RCFDG515 FLOAT, RCFDG516 FLOAT, RCFDG517 FLOAT, RCFDG518 FLOAT, RCFDG519 FLOAT, RCFDG520 FLOAT, RCFDG521 FLOAT, RCFDG522 FLOAT, RCFDG523 FLOAT, RCFDG524 FLOAT, RCFDG525 FLOAT, RCFDG526 FLOAT, RCFDG527 FLOAT, RCFDG528 FLOAT, RCFDG529 FLOAT, RCFDG530 FLOAT, RCFDG531 FLOAT, RCFDG532 FLOAT, RCFDG533 FLOAT, RCFDG534 FLOAT, RCFDG535 FLOAT, RCFDG536 FLOAT, RCFDG537 FLOAT, RCFDG538 FLOAT, RCFDG539 FLOAT, RCFDG540 FLOAT, RCFDG541 FLOAT, RCFDG542 FLOAT, RCFDG543 FLOAT, RCFDG544 FLOAT, RCFDG545 FLOAT, RCFDG546 FLOAT, RCFDG547 FLOAT, RCFDG548 FLOAT, RCFDG549 FLOAT, RCFDG550 FLOAT, RCFDG551 FLOAT, RCFDG552 FLOAT, RCFDG553 FLOAT, RCFDG554 FLOAT, RCFDG555 FLOAT, RCFDG556 FLOAT, RCFDG557 FLOAT, RCFDG558 FLOAT, RCFDG559 FLOAT, RCFDG560 FLOAT, RCFDG561 FLOAT, RCFDG562 FLOAT, RCFDG563 FLOAT, RCFDG564 FLOAT, RCFDG565 FLOAT, RCFDG566 FLOAT, RCFDG567 FLOAT, RCFDG568 FLOAT, RCFDG569 FLOAT, RCFDG570 FLOAT, RCFDG571 FLOAT, RCFDG572 FLOAT, RCFDG573 FLOAT, RCFDG574 FLOAT, RCFDG575 FLOAT, RCFDG576 FLOAT, RCFDG577 FLOAT, RCFDG578 FLOAT, RCFDG579 FLOAT, RCFDG580 FLOAT, RCFDG581 FLOAT, RCFDG582 FLOAT, RCFDG583 FLOAT, RCFDG584 FLOAT, RCFDG585 FLOAT, RCFDG586 FLOAT, RCFDG587 FLOAT, RCFDG588 FLOAT, RCFDG589 FLOAT, RCFDG590 FLOAT, RCFDG804 FLOAT, RCFDG805 FLOAT, RCFDG806 FLOAT, RCFDG807 FLOAT, RCFDG808 FLOAT, RCFDG809 FLOAT, RCFDHT87 FLOAT, RCFDHT88 FLOAT, RCFDHT89 FLOAT, RCFDHT91 FLOAT, RCFDHT92 FLOAT, RCFDHT93 FLOAT, RCFDJA36 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCL (RCFD3411 FLOAT, RCFD3428 VARCHAR, RCFD3430 FLOAT, RCFD3432 FLOAT, RCFD3433 FLOAT, RCFD3434 FLOAT, RCFD3435 FLOAT, RCFD3450 FLOAT, RCFD3555 FLOAT, RCFD3556 FLOAT, RCFD3557 FLOAT, RCFD3814 FLOAT, RCFD3815 FLOAT, RCFD3816 FLOAT, RCFD3817 FLOAT, RCFD3818 FLOAT, RCFD3819 FLOAT, RCFD3820 FLOAT, RCFD3821 FLOAT, RCFD3822 FLOAT, RCFD3826 FLOAT, RCFD5591 FLOAT, RCFD5592 FLOAT, RCFD5593 FLOAT, RCFD5594 FLOAT, RCFD5595 FLOAT, RCFD6550 FLOAT, RCFD8693 FLOAT, RCFD8694 FLOAT, RCFD8695 FLOAT, RCFD8696 FLOAT, RCFD8697 FLOAT, RCFD8698 FLOAT, RCFD8699 FLOAT, RCFD8700 FLOAT, RCFD8701 FLOAT, RCFD8702 FLOAT, RCFD8703 FLOAT, RCFD8704 FLOAT, RCFD8705 FLOAT, RCFD8706 FLOAT, RCFD8707 FLOAT, RCFD8708 FLOAT, RCFD8709 FLOAT, RCFD8710 FLOAT, RCFD8711 FLOAT, RCFD8712 FLOAT, RCFD8713 FLOAT, RCFD8714 FLOAT, RCFD8715 FLOAT, RCFD8716 FLOAT, RCFD8719 FLOAT, RCFD8720 FLOAT, RCFD8723 FLOAT, RCFD8724 FLOAT, RCFD8725 FLOAT, RCFD8726 FLOAT, RCFD8727 FLOAT, RCFD8728 FLOAT, RCFD8733 FLOAT, RCFD8734 FLOAT, RCFD8735 FLOAT, RCFD8736 FLOAT, RCFD8737 FLOAT, RCFD8738 FLOAT, RCFD8739 FLOAT, RCFD8740 FLOAT, RCFD8741 FLOAT, RCFD8742 FLOAT, RCFD8743 FLOAT, RCFD8744 FLOAT, RCFD8745 FLOAT, RCFD8746 FLOAT, RCFD8747 FLOAT, RCFD8748 FLOAT, RCFD8765 FLOAT, RCFDA126 FLOAT, RCFDA127 FLOAT, RCFDA534 FLOAT, RCFDA535 FLOAT, RCFDA589 FLOAT, RCFDC219 FLOAT, RCFDC220 FLOAT, RCFDC221 FLOAT, RCFDC222 FLOAT, RCFDC223 VARCHAR, RCFDC224 VARCHAR, RCFDC968 FLOAT, RCFDC969 FLOAT, RCFDC970 FLOAT, RCFDC971 FLOAT, RCFDC972 FLOAT, RCFDC973 FLOAT, RCFDC974 FLOAT, RCFDC975 FLOAT, RCFDC978 FLOAT, RCFDF164 FLOAT, RCFDF165 FLOAT, RCFDG401 FLOAT, RCFDG402 FLOAT, RCFDG403 FLOAT, RCFDG404 FLOAT, RCFDG405 FLOAT, RCFDG406 FLOAT, RCFDG407 FLOAT, RCFDG408 FLOAT, RCFDG409 FLOAT, RCFDG410 FLOAT, RCFDG411 FLOAT, RCFDG412 FLOAT, RCFDG413 FLOAT, RCFDG414 FLOAT, RCFDG415 FLOAT, RCFDG416 FLOAT, RCFDG417 FLOAT, RCFDG418 FLOAT, RCFDG420 FLOAT, RCFDG421 FLOAT, RCFDG422 FLOAT, RCFDG423 FLOAT, RCFDG425 FLOAT, RCFDG426 FLOAT, RCFDG427 FLOAT, RCFDG428 FLOAT, RCFDG430 FLOAT, RCFDG431 FLOAT, RCFDG432 FLOAT, RCFDG433 FLOAT, RCFDG435 FLOAT, RCFDG436 FLOAT, RCFDG437 FLOAT, RCFDG438 FLOAT, RCFDG440 FLOAT, RCFDG441 FLOAT, RCFDG442 FLOAT, RCFDG443 FLOAT, RCFDG445 FLOAT, RCFDG446 FLOAT, RCFDG447 FLOAT, RCFDG448 FLOAT, RCFDG450 FLOAT, RCFDG451 FLOAT, RCFDG452 FLOAT, RCFDG453 FLOAT, RCFDG455 FLOAT, RCFDG456 FLOAT, RCFDG457 FLOAT, RCFDG458 FLOAT, RCFDG460 FLOAT, RCFDG461 FLOAT, RCFDG462 FLOAT, RCFDJ455 FLOAT, RCFDJ456 FLOAT, RCFDJ457 FLOAT, RCFDJ458 FLOAT, RCFDJ459 FLOAT, RCON3411 FLOAT, RCON3430 FLOAT, RCON3432 FLOAT, RCON3433 FLOAT, RCON3555 FLOAT, RCON3556 FLOAT, RCON3557 FLOAT, RCON3814 FLOAT, RCON3815 FLOAT, RCON3819 FLOAT, RCON3821 FLOAT, RCON5591 FLOAT, RCON5592 FLOAT, RCON5593 FLOAT, RCON5594 FLOAT, RCON5595 FLOAT, RCON6550 FLOAT, RCONC223 FLOAT, RCONC224 FLOAT, RCONC978 FLOAT, RCONF164 FLOAT, RCONF165 FLOAT, RCONHT72 FLOAT, RCONJ457 FLOAT, RCONJ458 FLOAT, RCONJ459 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RIC (RCONJJ04 FLOAT, RCONJJ05 FLOAT, RCONJJ06 FLOAT, RCONJJ07 FLOAT, RCONJJ08 FLOAT, RCONJJ09 FLOAT, RCONJJ11 FLOAT, RCONJJ12 FLOAT, RCONJJ13 FLOAT, RCONJJ14 FLOAT, RCONJJ15 FLOAT, RCONJJ16 FLOAT, RCONJJ17 FLOAT, RCONJJ18 FLOAT, RCONJJ19 FLOAT, RCONJJ20 FLOAT, RCONJJ21 FLOAT, RCONJJ23 FLOAT, RCONJJ24 FLOAT, RCONJJ25 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCCI (RCFD1410 FLOAT, RCFD1420 FLOAT, RCFD1460 FLOAT, RCFD1563 FLOAT, RCFD1590 FLOAT, RCFD1616 VARCHAR, RCFD1763 FLOAT, RCFD1764 FLOAT, RCFD1797 FLOAT, RCFD2011 FLOAT, RCFD2081 FLOAT, RCFD2107 FLOAT, RCFD2122 FLOAT, RCFD2123 FLOAT, RCFD2182 VARCHAR, RCFD2183 VARCHAR, RCFD2746 FLOAT, RCFD5367 FLOAT, RCFD5368 FLOAT, RCFDA247 FLOAT, RCFDA570 FLOAT, RCFDA571 FLOAT, RCFDA572 FLOAT, RCFDA573 FLOAT, RCFDA574 FLOAT, RCFDA575 FLOAT, RCFDB532 FLOAT, RCFDB533 FLOAT, RCFDB534 FLOAT, RCFDB536 FLOAT, RCFDB537 FLOAT, RCFDB538 FLOAT, RCFDB539 FLOAT, RCFDB837 FLOAT, RCFDC391 FLOAT, RCFDC779 FLOAT, RCFDC780 FLOAT, RCFDF158 FLOAT, RCFDF159 FLOAT, RCFDF160 FLOAT, RCFDF161 FLOAT, RCFDF162 FLOAT, RCFDF163 FLOAT, RCFDG091 VARCHAR, RCFDG092 VARCHAR, RCFDG093 VARCHAR, RCFDG094 VARCHAR, RCFDG095 VARCHAR, RCFDG096 VARCHAR, RCFDG097 VARCHAR, RCFDG098 VARCHAR, RCFDG099 VARCHAR, RCFDG100 VARCHAR, RCFDG101 VARCHAR, RCFDG102 VARCHAR, RCFDG378 FLOAT, RCFDHK25 FLOAT, RCFDK098 FLOAT, RCFDK137 FLOAT, RCFDK163 FLOAT, RCFDK164 FLOAT, RCFDK165 FLOAT, RCFDK168 FLOAT, RCFDK203 FLOAT, RCFDK204 FLOAT, RCFDK207 FLOAT, RCON1288 FLOAT, RCON1415 FLOAT, RCON1420 FLOAT, RCON1460 FLOAT, RCON1480 VARCHAR, RCON1545 FLOAT, RCON1564 VARCHAR, RCON1590 FLOAT, RCON1763 FLOAT, RCON1764 FLOAT, RCON1766 FLOAT, RCON1797 FLOAT, RCON2011 VARCHAR, RCON2081 FLOAT, RCON2107 FLOAT, RCON2122 FLOAT, RCON2123 FLOAT, RCON2165 FLOAT, RCON2746 FLOAT, RCON5367 FLOAT, RCON5368 FLOAT, RCON5370 FLOAT, RCONA247 FLOAT, RCONA564 FLOAT, RCONA565 FLOAT, RCONA566 FLOAT, RCONA567 FLOAT, RCONA568 FLOAT, RCONA569 FLOAT, RCONA570 FLOAT, RCONA571 FLOAT, RCONA572 FLOAT, RCONA573 FLOAT, RCONA574 FLOAT, RCONA575 FLOAT, RCONB531 FLOAT, RCONB534 FLOAT, RCONB535 FLOAT, RCONB538 FLOAT, RCONB539 FLOAT, RCONC779 VARCHAR, RCONC780 VARCHAR, RCONF158 FLOAT, RCONF159 FLOAT, RCONF160 FLOAT, RCONF161 FLOAT, RCONF230 FLOAT, RCONF231 FLOAT, RCONF232 FLOAT, RCONF576 FLOAT, RCONF577 FLOAT, RCONG376 FLOAT, RCONG378 FLOAT, RCONGW45 FLOAT, RCONGW46 FLOAT, RCONGW47 FLOAT, RCONHK25 FLOAT, RCONJ451 FLOAT, RCONJ454 FLOAT, RCONJ464 FLOAT, RCONK098 FLOAT, RCONK137 FLOAT, RCONK158 FLOAT, RCONK159 FLOAT, RCONK160 FLOAT, RCONK161 FLOAT, RCONK162 FLOAT, RCONK165 FLOAT, RCONK166 FLOAT, RCONK168 FLOAT, RCONK203 FLOAT, RCONK204 FLOAT, RCONK207 FLOAT, RCONK256 FLOAT, RCONLE75 FLOAT, RCONLG24 VARCHAR, RCONLG25 VARCHAR, RIADG377 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RICII (RCFDJJ04 FLOAT, RCFDJJ05 FLOAT, RCFDJJ06 FLOAT, RCFDJJ07 FLOAT, RCFDJJ08 FLOAT, RCFDJJ09 FLOAT, RCFDJJ11 FLOAT, RCFDJJ12 FLOAT, RCFDJJ13 FLOAT, RCFDJJ14 FLOAT, RCFDJJ15 FLOAT, RCFDJJ16 FLOAT, RCFDJJ17 FLOAT, RCFDJJ18 FLOAT, RCFDJJ19 FLOAT, RCFDJJ20 FLOAT, RCFDJJ21 FLOAT, RCFDJJ23 FLOAT, RCFDJJ24 FLOAT, RCFDJJ25 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCP (RCONFT04 FLOAT, RCONFT05 FLOAT, RCONHT81 FLOAT, RCONHT82 FLOAT, RCONHT86 FLOAT, RCONL191 VARCHAR, RCONL192 VARCHAR, RCONM288 FLOAT, RIADHT85 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCCII (RCON5562 FLOAT, RCON5563 FLOAT, RCON5564 FLOAT, RCON5565 FLOAT, RCON5566 FLOAT, RCON5567 FLOAT, RCON5568 FLOAT, RCON5569 FLOAT, RCON5570 FLOAT, RCON5571 FLOAT, RCON5572 FLOAT, RCON5573 FLOAT, RCON5574 FLOAT, RCON5575 FLOAT, RCON5576 FLOAT, RCON5577 FLOAT, RCON5578 FLOAT, RCON5579 FLOAT, RCON5580 FLOAT, RCON5581 FLOAT, RCON5582 FLOAT, RCON5583 FLOAT, RCON5584 FLOAT, RCON5585 FLOAT, RCON5586 FLOAT, RCON5587 FLOAT, RCON5588 FLOAT, RCON5589 FLOAT, RCON6860 BOOLEAN, RCON6999 BOOLEAN, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_Undefined (CALL8002 VARCHAR, CALL8786 VARCHAR, CALL8787 VARCHAR, CALL8798 VARCHAR, CALL8799 VARCHAR, CALL8898 VARCHAR, RCFAP845 VARCHAR, RCFAP851 VARCHAR, RCFAP853 VARCHAR, RCFAP854 VARCHAR, RCFAP855 VARCHAR, RCFAP856 VARCHAR, RCFAQ257 VARCHAR, RCFD0276 VARCHAR, RCFD0277 VARCHAR, RCFD0278 VARCHAR, RCFD0279 VARCHAR, RCFD0297 VARCHAR, RCFD0301 VARCHAR, RCFD0302 VARCHAR, RCFD0303 FLOAT, RCFD0305 VARCHAR, RCFD0343 VARCHAR, RCFD0344 VARCHAR, RCFD0345 VARCHAR, RCFD0346 VARCHAR, RCFD0347 VARCHAR, RCFD0348 VARCHAR, RCFD0349 VARCHAR, RCFD0356 VARCHAR, RCFD0357 VARCHAR, RCFD0358 VARCHAR, RCFD0390 VARCHAR, RCFD0391 FLOAT, RCFD0393 VARCHAR, RCFD0400 VARCHAR, RCFD0401 FLOAT, RCFD0402 VARCHAR, RCFD0403 FLOAT, RCFD0408 FLOAT, RCFD0409 FLOAT, RCFD0411 VARCHAR, RCFD0412 VARCHAR, RCFD0413 VARCHAR, RCFD0414 VARCHAR, RCFD0421 FLOAT, RCFD0422 FLOAT, RCFD0423 FLOAT, RCFD0424 FLOAT, RCFD0550 FLOAT, RCFD0555 FLOAT, RCFD0600 FLOAT, RCFD0601 FLOAT, RCFD0602 FLOAT, RCFD0603 FLOAT, RCFD0604 FLOAT, RCFD0605 FLOAT, RCFD1226 FLOAT, RCFD1227 FLOAT, RCFD1228 FLOAT, RCFD1245 VARCHAR, RCFD1246 VARCHAR, RCFD1247 VARCHAR, RCFD1288 FLOAT, RCFD1350 VARCHAR, RCFD1400 FLOAT, RCFD1404 VARCHAR, RCFD1425 VARCHAR, RCFD1426 VARCHAR, RCFD1427 VARCHAR, RCFD1428 VARCHAR, RCFD1429 VARCHAR, RCFD1431 VARCHAR, RCFD1479 VARCHAR, RCFD1489 FLOAT, RCFD1496 VARCHAR, RCFD1500 FLOAT, RCFD1505 FLOAT, RCFD1506 VARCHAR, RCFD1507 VARCHAR, RCFD1510 FLOAT, RCFD1513 VARCHAR, RCFD1516 VARCHAR, RCFD1517 VARCHAR, RCFD1546 VARCHAR, RCFD1547 VARCHAR, RCFD1548 VARCHAR, RCFD1549 VARCHAR, RCFD1551 VARCHAR, RCFD1552 VARCHAR, RCFD1553 VARCHAR, RCFD1554 VARCHAR, RCFD1556 VARCHAR, RCFD1557 VARCHAR, RCFD1558 VARCHAR, RCFD1559 VARCHAR, RCFD1561 VARCHAR, RCFD1562 VARCHAR, RCFD1586 VARCHAR, RCFD1587 VARCHAR, RCFD1588 VARCHAR, RCFD1600 FLOAT, RCFD1606 FLOAT, RCFD1607 FLOAT, RCFD1608 FLOAT, RCFD1613 VARCHAR, RCFD1615 VARCHAR, RCFD1665 VARCHAR, RCFD1676 VARCHAR, RCFD1677 VARCHAR, RCFD1678 VARCHAR, RCFD1679 VARCHAR, RCFD1681 VARCHAR, RCFD1686 VARCHAR, RCFD1687 VARCHAR, RCFD1689 VARCHAR, RCFD1690 VARCHAR, RCFD1691 VARCHAR, RCFD1694 VARCHAR, RCFD1695 VARCHAR, RCFD1696 VARCHAR, RCFD1697 VARCHAR, RCFD1727 VARCHAR, RCFD1747 VARCHAR, RCFD1748 VARCHAR, RCFD1749 VARCHAR, RCFD1751 VARCHAR, RCFD1753 VARCHAR, RCFD1755 FLOAT, RCFD1756 VARCHAR, RCFD1757 VARCHAR, RCFD1758 VARCHAR, RCFD1759 VARCHAR, RCFD1766 FLOAT, RCFD1774 FLOAT, RCFD1775 FLOAT, RCFD1776 FLOAT, RCFD1777 FLOAT, RCFD1789 VARCHAR, RCFD1790 VARCHAR, RCFD1803 VARCHAR, RCFD1804 VARCHAR, RCFD1805 VARCHAR, RCFD1806 VARCHAR, RCFD1807 VARCHAR, RCFD1808 VARCHAR, RCFD1812 VARCHAR, RCFD1813 VARCHAR, RCFD1815 VARCHAR, RCFD1816 VARCHAR, RCFD1817 VARCHAR, RCFD1819 VARCHAR, RCFD1823 VARCHAR, RCFD1824 VARCHAR, RCFD1825 VARCHAR, RCFD1827 VARCHAR, RCFD1828 VARCHAR, RCFD1829 VARCHAR, RCFD1833 VARCHAR, RCFD1834 VARCHAR, RCFD1835 VARCHAR, RCFD1836 VARCHAR, RCFD1837 VARCHAR, RCFD1838 VARCHAR, RCFD1842 VARCHAR, RCFD1843 VARCHAR, RCFD1844 VARCHAR, RCFD1845 VARCHAR, RCFD1846 VARCHAR, RCFD1847 VARCHAR, RCFD1851 VARCHAR, RCFD1852 VARCHAR, RCFD1853 VARCHAR, RCFD1855 VARCHAR, RCFD1856 VARCHAR, RCFD1857 VARCHAR, RCFD1861 VARCHAR, RCFD1863 VARCHAR, RCFD1864 VARCHAR, RCFD1865 VARCHAR, RCFD1866 VARCHAR, RCFD1867 VARCHAR, RCFD1871 VARCHAR, RCFD1872 VARCHAR, RCFD1873 VARCHAR, RCFD1875 VARCHAR, RCFD1876 VARCHAR, RCFD1879 VARCHAR, RCFD1880 VARCHAR, RCFD1881 VARCHAR, RCFD1883 VARCHAR, RCFD1904 VARCHAR, RCFD1905 VARCHAR, RCFD1906 VARCHAR, RCFD1907 VARCHAR, RCFD1908 VARCHAR, RCFD1909 VARCHAR, RCFD1936 VARCHAR, RCFD1937 VARCHAR, RCFD1948 VARCHAR, RCFD1975 FLOAT, RCFD1978 FLOAT, RCFD1979 FLOAT, RCFD1981 FLOAT, RCFD2008 VARCHAR, RCFD2033 VARCHAR, RCFD2079 VARCHAR, RCFD2080 FLOAT, RCFD2103 VARCHAR, RCFD2104 VARCHAR, RCFD2108 VARCHAR, RCFD2109 VARCHAR, RCFD2125 VARCHAR, RCFD2146 VARCHAR, RCFD2164 VARCHAR, RCFD2165 FLOAT, RCFD2190 FLOAT, RCFD2191 FLOAT, RCFD2200 FLOAT, RCFD2243 VARCHAR, RCFD2330 FLOAT, RCFD2332 VARCHAR, RCFD2333 VARCHAR, RCFD2492 VARCHAR, RCFD2493 VARCHA ...
# CREATE TABLE IF NOT EXISTS Schedule_RCE (RCON0352 FLOAT, RCON2202 FLOAT, RCON2203 FLOAT, RCON2210 FLOAT, RCON2213 FLOAT, RCON2215 FLOAT, RCON2216 FLOAT, RCON2236 FLOAT, RCON2365 FLOAT, RCON2377 FLOAT, RCON2385 FLOAT, RCON2520 FLOAT, RCON2530 FLOAT, RCON5590 FLOAT, RCON6648 FLOAT, RCON6810 FLOAT, RCON6835 FLOAT, RCONB549 FLOAT, RCONB550 FLOAT, RCONB551 FLOAT, RCONB552 FLOAT, RCONF233 FLOAT, RCONHK05 FLOAT, RCONHK06 FLOAT, RCONHK07 FLOAT, RCONHK08 FLOAT, RCONHK09 FLOAT, RCONHK10 FLOAT, RCONHK11 FLOAT, RCONHK12 FLOAT, RCONHK13 FLOAT, RCONHK14 FLOAT, RCONHK15 FLOAT, RCONJ473 FLOAT, RCONJ474 FLOAT, RCONJH83 FLOAT, RCONK220 FLOAT, RCONK222 FLOAT, RCONK223 FLOAT, RCONMT87 FLOAT, RCONMT89 FLOAT, RCONMT91 FLOAT, RCONMT93 FLOAT, RCONMT95 FLOAT, RCONP752 BOOLEAN, RCONP753 FLOAT, RCONP754 FLOAT, RCONP756 FLOAT, RCONP757 FLOAT, RCONP758 FLOAT, RCONP759 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCB (RCFD0211 FLOAT, RCFD0213 FLOAT, RCFD0416 FLOAT, RCFD1286 FLOAT, RCFD1287 FLOAT, RCFD1289 VARCHAR, RCFD1290 VARCHAR, RCFD1291 VARCHAR, RCFD1293 VARCHAR, RCFD1294 VARCHAR, RCFD1295 VARCHAR, RCFD1297 VARCHAR, RCFD1298 VARCHAR, RCFD1698 VARCHAR, RCFD1699 VARCHAR, RCFD1701 VARCHAR, RCFD1702 VARCHAR, RCFD1703 VARCHAR, RCFD1705 VARCHAR, RCFD1706 VARCHAR, RCFD1707 VARCHAR, RCFD1709 VARCHAR, RCFD1710 VARCHAR, RCFD1711 VARCHAR, RCFD1713 VARCHAR, RCFD1714 VARCHAR, RCFD1715 VARCHAR, RCFD1716 VARCHAR, RCFD1717 VARCHAR, RCFD1718 VARCHAR, RCFD1719 VARCHAR, RCFD1731 VARCHAR, RCFD1732 VARCHAR, RCFD1733 VARCHAR, RCFD1734 VARCHAR, RCFD1735 VARCHAR, RCFD1736 VARCHAR, RCFD1737 FLOAT, RCFD1738 FLOAT, RCFD1739 FLOAT, RCFD1741 FLOAT, RCFD1742 FLOAT, RCFD1743 FLOAT, RCFD1744 FLOAT, RCFD1746 FLOAT, RCFD1754 FLOAT, RCFD1771 FLOAT, RCFD1772 FLOAT, RCFD1773 FLOAT, RCFD1778 VARCHAR, RCFD8496 FLOAT, RCFD8497 FLOAT, RCFD8498 FLOAT, RCFD8499 FLOAT, RCFD8782 FLOAT, RCFD8783 FLOAT, RCFDA248 FLOAT, RCFDA510 VARCHAR, RCFDA511 VARCHAR, RCFDA549 FLOAT, RCFDA550 FLOAT, RCFDA551 FLOAT, RCFDA552 FLOAT, RCFDA553 FLOAT, RCFDA554 FLOAT, RCFDA555 FLOAT, RCFDA556 FLOAT, RCFDA557 FLOAT, RCFDA558 FLOAT, RCFDA559 FLOAT, RCFDA560 FLOAT, RCFDA561 FLOAT, RCFDA562 FLOAT, RCFDB838 FLOAT, RCFDB839 FLOAT, RCFDB840 FLOAT, RCFDB841 FLOAT, RCFDB842 FLOAT, RCFDB843 FLOAT, RCFDB844 FLOAT, RCFDB845 FLOAT, RCFDB846 FLOAT, RCFDB847 FLOAT, RCFDB848 FLOAT, RCFDB849 FLOAT, RCFDB850 FLOAT, RCFDB851 FLOAT, RCFDB852 FLOAT, RCFDB853 FLOAT, RCFDB854 FLOAT, RCFDB855 FLOAT, RCFDB856 FLOAT, RCFDB857 FLOAT, RCFDB858 FLOAT, RCFDB859 FLOAT, RCFDB860 FLOAT, RCFDB861 FLOAT, RCFDC026 FLOAT, RCFDC027 FLOAT, RCFDC988 FLOAT, RCFDC989 FLOAT, RCFDG300 FLOAT, RCFDG301 FLOAT, RCFDG302 FLOAT, RCFDG303 FLOAT, RCFDG304 FLOAT, RCFDG305 FLOAT, RCFDG306 FLOAT, RCFDG307 FLOAT, RCFDG308 FLOAT, RCFDG309 FLOAT, RCFDG310 FLOAT, RCFDG311 FLOAT, RCFDG312 FLOAT, RCFDG313 FLOAT, RCFDG314 FLOAT, RCFDG315 FLOAT, RCFDG316 FLOAT, RCFDG317 FLOAT, RCFDG318 FLOAT, RCFDG319 FLOAT, RCFDG320 FLOAT, RCFDG321 FLOAT, RCFDG322 FLOAT, RCFDG323 FLOAT, RCFDG348 FLOAT, RCFDG349 FLOAT, RCFDG350 FLOAT, RCFDG351 FLOAT, RCFDG352 FLOAT, RCFDG353 FLOAT, RCFDG354 FLOAT, RCFDG355 FLOAT, RCFDG356 FLOAT, RCFDG357 FLOAT, RCFDG358 FLOAT, RCFDG359 FLOAT, RCFDG360 FLOAT, RCFDG361 FLOAT, RCFDG362 FLOAT, RCFDG363 FLOAT, RCFDG364 FLOAT, RCFDG365 FLOAT, RCFDG366 FLOAT, RCFDG367 FLOAT, RCFDG368 FLOAT, RCFDG369 FLOAT, RCFDG370 FLOAT, RCFDG371 FLOAT, RCFDG372 FLOAT, RCFDG373 FLOAT, RCFDG374 FLOAT, RCFDG375 FLOAT, RCFDHT50 FLOAT, RCFDHT51 FLOAT, RCFDHT52 FLOAT, RCFDHT53 FLOAT, RCFDHT58 FLOAT, RCFDHT59 FLOAT, RCFDHT60 FLOAT, RCFDHT61 FLOAT, RCFDK142 FLOAT, RCFDK143 FLOAT, RCFDK144 FLOAT, RCFDK145 FLOAT, RCFDK146 FLOAT, RCFDK147 FLOAT, RCFDK148 FLOAT, RCFDK149 FLOAT, RCFDK150 FLOAT, RCFDK151 FLOAT, RCFDK152 FLOAT, RCFDK153 FLOAT, RCFDK154 FLOAT, RCFDK155 FLOAT, RCFDK156 FLOAT, RCFDK157 FLOAT, RCFDMG95 FLOAT, RCON0211 FLOAT, RCON0213 FLOAT, RCON0416 FLOAT, RCON1286 FLOAT, RCON1287 FLOAT, RCON1737 FLOAT, RCON1738 FLOAT, RCON1739 FLOAT, RCON1741 FLOAT, RCON1742 FLOAT, RCON1743 FLOAT, RCON1744 FLOAT, RCON1746 FLOAT, RCON1754 FLOAT, RCON1771 FLOAT, RCON1772 FLOAT, RCON1773 FLOAT, RCON1778 FLOAT, RCON8496 FLOAT, RCON8497 FLOAT, RCON8498 FLOAT, RCON8499 FLOAT, RCON8782 FLOAT, RCON8783 FLOAT, RCONA248 FLOAT, RCONA549 FLOAT, RCONA550 FLOAT, RCONA551 FLOAT, RCONA552 FLOAT, RCONA553 FLOAT, RCONA554 FLOAT, RCONA555 FLOAT, RCONA556 FLOAT, RCONA557 FLOAT, RCONA558 FLOAT, RCONA559 FLOAT, RCONA560 FLOAT, RCONA561 FLOAT, RCONA562 FLOAT, RCONC026 FLOAT, RCONC027 FLOAT, RCONC988 FLOAT, RCONC989 FLOAT, RCONG308 FLOAT, RCONG309 FLOAT, RCONG310 FLOAT, RCONG311 FLOAT, RCONG312 FLOAT, RCONG313 FLOAT, RCONG314 FLOAT, RCONG315 FLOAT, RCONG316 FLOAT, RCONG317 FLOAT, RCONG318 FLOAT, RCONG319 FLOAT, RCONG320 FLOAT, RCONG321 FLOAT, RCONG322 FLOAT, RCONG323 FLOAT, RCONHT50 FLOAT, RCONHT51 FLOAT, RCONHT52 FLOAT, RCONHT53 FLOAT, RCONHT54 FLOAT, RCONHT55 FLOAT, R ...
# CREATE TABLE IF NOT EXISTS Schedule_RI (RIAD0093 FLOAT, RIAD3196 FLOAT, RIAD3521 FLOAT, RIAD4010 FLOAT, RIAD4011 FLOAT, RIAD4012 FLOAT, RIAD4020 FLOAT, RIAD4024 FLOAT, RIAD4056 FLOAT, RIAD4058 FLOAT, RIAD4059 FLOAT, RIAD4060 FLOAT, RIAD4065 FLOAT, RIAD4069 FLOAT, RIAD4070 FLOAT, RIAD4073 FLOAT, RIAD4074 FLOAT, RIAD4079 FLOAT, RIAD4080 FLOAT, RIAD4092 FLOAT, RIAD4093 FLOAT, RIAD4107 FLOAT, RIAD4115 FLOAT, RIAD4135 FLOAT, RIAD4150 FLOAT, RIAD4172 FLOAT, RIAD4180 FLOAT, RIAD4185 FLOAT, RIAD4200 FLOAT, RIAD4217 FLOAT, RIAD4300 FLOAT, RIAD4301 FLOAT, RIAD4302 FLOAT, RIAD4313 FLOAT, RIAD4320 VARCHAR, RIAD4340 FLOAT, RIAD4435 FLOAT, RIAD4436 FLOAT, RIAD4507 FLOAT, RIAD4508 FLOAT, RIAD4513 FLOAT, RIAD4518 FLOAT, RIAD5415 FLOAT, RIAD5416 FLOAT, RIAD8431 FLOAT, RIAD8757 FLOAT, RIAD8758 FLOAT, RIAD8759 FLOAT, RIAD8760 FLOAT, RIAD8761 VARCHAR, RIAD8762 VARCHAR, RIAD8763 VARCHAR, RIAD9106 FLOAT, RIADA220 FLOAT, RIADA251 FLOAT, RIADA517 VARCHAR, RIADA518 VARCHAR, RIADA530 BOOLEAN, RIADB485 FLOAT, RIADB486 FLOAT, RIADB487 FLOAT, RIADB488 FLOAT, RIADB489 FLOAT, RIADB490 VARCHAR, RIADB491 FLOAT, RIADB492 FLOAT, RIADB493 FLOAT, RIADB496 FLOAT, RIADB497 FLOAT, RIADC216 FLOAT, RIADC232 FLOAT, RIADC386 FLOAT, RIADC387 FLOAT, RIADC886 FLOAT, RIADC887 FLOAT, RIADC888 FLOAT, RIADC889 FLOAT, RIADC890 FLOAT, RIADF186 FLOAT, RIADF551 FLOAT, RIADF552 FLOAT, RIADF553 FLOAT, RIADF554 FLOAT, RIADFT28 FLOAT, RIADFT36 FLOAT, RIADFT37 FLOAT, RIADFT38 FLOAT, RIADFT39 FLOAT, RIADFT40 FLOAT, RIADG103 FLOAT, RIADG104 FLOAT, RIADGW44 FLOAT, RIADH032 FLOAT, RIADH033 FLOAT, RIADH034 FLOAT, RIADH035 FLOAT, RIADHK03 FLOAT, RIADHK04 FLOAT, RIADHT69 FLOAT, RIADHT70 FLOAT, RIADHT73 FLOAT, RIADHT74 FLOAT, RIADJ321 FLOAT, RIADJJ33 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RICI (RCFDM708 FLOAT, RCFDM709 FLOAT, RCFDM710 FLOAT, RCFDM711 FLOAT, RCFDM712 FLOAT, RCFDM713 FLOAT, RCFDM714 FLOAT, RCFDM715 FLOAT, RCFDM716 FLOAT, RCFDM717 FLOAT, RCFDM719 FLOAT, RCFDM720 FLOAT, RCFDM721 FLOAT, RCFDM722 FLOAT, RCFDM723 FLOAT, RCFDM724 FLOAT, RCFDM725 FLOAT, RCFDM726 FLOAT, RCFDM727 FLOAT, RCFDM728 FLOAT, RCFDM729 FLOAT, RCFDM730 FLOAT, RCFDM731 FLOAT, RCFDM732 FLOAT, RCFDM733 FLOAT, RCFDM734 FLOAT, RCFDM735 FLOAT, RCFDM736 FLOAT, RCFDM737 FLOAT, RCFDM738 FLOAT, RCFDM739 FLOAT, RCFDM740 FLOAT, RCFDM741 FLOAT, RCFDM742 FLOAT, RCFDM743 FLOAT, RCFDM744 FLOAT, RCFDM745 FLOAT, RCFDM746 FLOAT, RCFDM747 FLOAT, RCFDM748 FLOAT, RCFDM749 FLOAT, RCFDM750 FLOAT, RCFDM751 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCR (RCFD1395 VARCHAR, RCFD1651 VARCHAR, RCFD2221 VARCHAR, RCFD3429 VARCHAR, RCFD3792 VARCHAR, RCFD3809 VARCHAR, RCFD3812 VARCHAR, RCFD3833 VARCHAR, RCFD4336 VARCHAR, RCFD5306 VARCHAR, RCFD5310 VARCHAR, RCFD5311 VARCHAR, RCFD5320 VARCHAR, RCFD5327 VARCHAR, RCFD5334 VARCHAR, RCFD5339 VARCHAR, RCFD5340 VARCHAR, RCFD5610 VARCHAR, RCFD7204 FLOAT, RCFD7205 FLOAT, RCFD7206 FLOAT, RCFD7273 FLOAT, RCFD7274 FLOAT, RCFD7275 FLOAT, RCFD8274 VARCHAR, RCFD8275 VARCHAR, RCFD8434 VARCHAR, RCFD8764 VARCHAR, RCFD8766 VARCHAR, RCFD8767 VARCHAR, RCFD8769 VARCHAR, RCFD8770 VARCHAR, RCFD8771 VARCHAR, RCFD8772 VARCHAR, RCFD8773 VARCHAR, RCFD8774 VARCHAR, RCFD8775 VARCHAR, RCFD8776 VARCHAR, RCFD8777 VARCHAR, RCFD8778 VARCHAR, RCFD8779 VARCHAR, RCFDA000 VARCHAR, RCFDA001 VARCHAR, RCFDA002 VARCHAR, RCFDA167 VARCHAR, RCFDA221 VARCHAR, RCFDA223 VARCHAR, RCFDA224 VARCHAR, RCFDA250 VARCHAR, RCFDB503 VARCHAR, RCFDB504 VARCHAR, RCFDB505 VARCHAR, RCFDB588 VARCHAR, RCFDB589 VARCHAR, RCFDB590 VARCHAR, RCFDB591 VARCHAR, RCFDB592 VARCHAR, RCFDB593 VARCHAR, RCFDB594 VARCHAR, RCFDB595 VARCHAR, RCFDB596 VARCHAR, RCFDB600 VARCHAR, RCFDB601 VARCHAR, RCFDB602 VARCHAR, RCFDB603 VARCHAR, RCFDB604 VARCHAR, RCFDB605 VARCHAR, RCFDB606 VARCHAR, RCFDB607 VARCHAR, RCFDB608 VARCHAR, RCFDB609 VARCHAR, RCFDB610 VARCHAR, RCFDB611 VARCHAR, RCFDB612 VARCHAR, RCFDB617 VARCHAR, RCFDB618 VARCHAR, RCFDB619 VARCHAR, RCFDB620 VARCHAR, RCFDB621 VARCHAR, RCFDB622 VARCHAR, RCFDB623 VARCHAR, RCFDB624 VARCHAR, RCFDB625 VARCHAR, RCFDB626 VARCHAR, RCFDB627 VARCHAR, RCFDB628 VARCHAR, RCFDB629 VARCHAR, RCFDB630 VARCHAR, RCFDB631 VARCHAR, RCFDB639 VARCHAR, RCFDB640 VARCHAR, RCFDB641 VARCHAR, RCFDB642 VARCHAR, RCFDB643 VARCHAR, RCFDB644 VARCHAR, RCFDB650 VARCHAR, RCFDB651 VARCHAR, RCFDB652 VARCHAR, RCFDB653 VARCHAR, RCFDB654 VARCHAR, RCFDB655 VARCHAR, RCFDB656 VARCHAR, RCFDB657 VARCHAR, RCFDB658 VARCHAR, RCFDB659 VARCHAR, RCFDB660 VARCHAR, RCFDB661 VARCHAR, RCFDB662 VARCHAR, RCFDB663 VARCHAR, RCFDB664 VARCHAR, RCFDB665 VARCHAR, RCFDB666 VARCHAR, RCFDB667 VARCHAR, RCFDB668 VARCHAR, RCFDB669 VARCHAR, RCFDB670 VARCHAR, RCFDB671 VARCHAR, RCFDB672 VARCHAR, RCFDB673 VARCHAR, RCFDB675 VARCHAR, RCFDB676 VARCHAR, RCFDB677 VARCHAR, RCFDB678 VARCHAR, RCFDB679 VARCHAR, RCFDB680 VARCHAR, RCFDB681 VARCHAR, RCFDB682 VARCHAR, RCFDB683 VARCHAR, RCFDB684 VARCHAR, RCFDB685 VARCHAR, RCFDB686 VARCHAR, RCFDB687 VARCHAR, RCFDB688 VARCHAR, RCFDB689 VARCHAR, RCFDB690 VARCHAR, RCFDB691 VARCHAR, RCFDB693 VARCHAR, RCFDB694 VARCHAR, RCFDB695 VARCHAR, RCFDB696 VARCHAR, RCFDB697 VARCHAR, RCFDB698 VARCHAR, RCFDB699 VARCHAR, RCFDB700 VARCHAR, RCFDB701 VARCHAR, RCFDB702 VARCHAR, RCFDB703 VARCHAR, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCI (RCFN2133 FLOAT, RCFN2898 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCEI (RCON0352 FLOAT, RCON2202 FLOAT, RCON2203 FLOAT, RCON2210 FLOAT, RCON2213 FLOAT, RCON2215 FLOAT, RCON2216 FLOAT, RCON2236 FLOAT, RCON2343 VARCHAR, RCON2344 VARCHAR, RCON2365 FLOAT, RCON2377 FLOAT, RCON2385 FLOAT, RCON2520 FLOAT, RCON2530 FLOAT, RCON2604 FLOAT, RCON5590 FLOAT, RCON6648 FLOAT, RCON6810 FLOAT, RCON6835 FLOAT, RCONA241 VARCHAR, RCONA242 VARCHAR, RCONA243 VARCHAR, RCONA244 VARCHAR, RCONA579 VARCHAR, RCONA580 VARCHAR, RCONA581 VARCHAR, RCONA582 VARCHAR, RCONA584 VARCHAR, RCONA585 VARCHAR, RCONA586 VARCHAR, RCONA587 VARCHAR, RCONB549 FLOAT, RCONB550 FLOAT, RCONB551 FLOAT, RCONB552 FLOAT, RCONHK05 FLOAT, RCONHK06 FLOAT, RCONHK07 FLOAT, RCONHK08 FLOAT, RCONHK09 FLOAT, RCONHK10 FLOAT, RCONHK11 FLOAT, RCONHK12 FLOAT, RCONHK13 FLOAT, RCONHK14 FLOAT, RCONHK15 FLOAT, RCONJ473 FLOAT, RCONJ474 FLOAT, RCONJH83 FLOAT, RCONK220 FLOAT, RCONK222 FLOAT, RCONK223 FLOAT, RCONMT87 FLOAT, RCONMT88 FLOAT, RCONMT89 FLOAT, RCONMT90 FLOAT, RCONMT91 FLOAT, RCONMT92 FLOAT, RCONMT93 FLOAT, RCONMT94 FLOAT, RCONMT95 FLOAT, RCONP752 BOOLEAN, RCONP753 FLOAT, RCONP754 FLOAT, RCONP756 FLOAT, RCONP757 FLOAT, RCONP758 FLOAT, RCONP759 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RIA (RIAD3210 FLOAT, RIAD3217 FLOAT, RIAD4356 FLOAT, RIAD4415 FLOAT, RIAD4460 FLOAT, RIAD4470 FLOAT, RIADB507 FLOAT, RIADB508 FLOAT, RIADB509 FLOAT, RIADB510 FLOAT, RIADB511 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RIBI (RIAD3582 FLOAT, RIAD3583 FLOAT, RIAD3584 FLOAT, RIAD3585 FLOAT, RIAD3588 FLOAT, RIAD3589 FLOAT, RIAD3590 FLOAT, RIAD3591 FLOAT, RIAD4266 FLOAT, RIAD4267 FLOAT, RIAD4608 FLOAT, RIAD4617 FLOAT, RIAD4618 FLOAT, RIAD4627 FLOAT, RIAD4628 FLOAT, RIAD4635 FLOAT, RIAD4638 FLOAT, RIAD4643 FLOAT, RIAD4644 FLOAT, RIAD4645 FLOAT, RIAD4646 FLOAT, RIAD4652 FLOAT, RIAD4653 VARCHAR, RIAD4654 VARCHAR, RIAD4655 FLOAT, RIAD4658 VARCHAR, RIAD4659 VARCHAR, RIAD4662 FLOAT, RIAD4663 VARCHAR, RIAD4664 VARCHAR, RIAD4665 FLOAT, RIAD4668 VARCHAR, RIAD4669 VARCHAR, RIAD5409 FLOAT, RIAD5410 FLOAT, RIAD5411 FLOAT, RIAD5412 FLOAT, RIADB512 FLOAT, RIADB513 FLOAT, RIADB514 FLOAT, RIADB515 FLOAT, RIADB516 VARCHAR, RIADB517 VARCHAR, RIADC217 FLOAT, RIADC218 FLOAT, RIADC234 FLOAT, RIADC235 FLOAT, RIADC388 FLOAT, RIADC880 FLOAT, RIADC891 FLOAT, RIADC892 FLOAT, RIADC893 FLOAT, RIADC894 FLOAT, RIADC895 FLOAT, RIADC896 FLOAT, RIADC897 FLOAT, RIADC898 FLOAT, RIADF185 FLOAT, RIADF187 FLOAT, RIADF188 FLOAT, RIADK129 FLOAT, RIADK133 FLOAT, RIADK205 FLOAT, RIADK206 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_NARR (RCON6979 BOOLEAN, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCF (RCFD1578 FLOAT, RCFD1752 FLOAT, RCFD2148 FLOAT, RCFD2160 FLOAT, RCFD2166 FLOAT, RCFD2168 FLOAT, RCFD3549 FLOAT, RCFD3550 FLOAT, RCFD3551 FLOAT, RCFDA519 VARCHAR, RCFDA520 VARCHAR, RCFDB556 FLOAT, RCFDC009 FLOAT, RCFDC010 FLOAT, RCFDFT33 FLOAT, RCFDFT34 FLOAT, RCFDFT35 FLOAT, RCFDHT80 FLOAT, RCFDK201 FLOAT, RCFDK202 FLOAT, RCFDK270 FLOAT, RCON1578 FLOAT, RCON1752 FLOAT, RCON2148 FLOAT, RCON2160 FLOAT, RCON2166 FLOAT, RCON2168 FLOAT, RCON3549 FLOAT, RCON3550 FLOAT, RCON3551 FLOAT, RCONB556 FLOAT, RCONC010 FLOAT, RCONFT33 FLOAT, RCONFT34 FLOAT, RCONFT35 FLOAT, RCONHT80 FLOAT, RCONK201 FLOAT, RCONK202 FLOAT, RCONK270 FLOAT, IDRSSD VARCHAR, RCON9999 DATE, primary key (IDRSSD, RCON9999));
# CREATE TABLE IF NOT EXISTS Schedule_RCRII (RCFD2170 FLOAT, RCFD3123 FLOAT, RCFD3128 FLOAT, RCFDA222 FLOAT, RCFDB704 FLOAT, RCFDD957 FLOAT, RCFDD958 FLOAT, RCFDD959 FLOAT, RCFDD960 FLOAT, RCFDD961 FLOAT, RCFDD962 FLOAT, RCFDD963 FLOAT, RCFDD964 FLOAT, RCFDD965 FLOAT, RCFDD967 FLOAT, RCFDD968 FLOAT, RCFDD969 FLOAT, RCFDD970 FLOAT, RCFDD976 FLOAT, RCFDD977 FLOAT, RCFDD978 FLOAT, RCFDD979 FLOAT, RCFDD980 FLOAT, RCFDD981 FLOAT, RCFDD982 FLOAT, RCFDD983 FLOAT, RCFDD984 FLOAT, RCFDD985 FLOAT, RCFDD987 FLOAT, RCFDD988 FLOAT, RCFDD989 FLOAT, RCFDD990 FLOAT, RCFDD991 FLOAT, RCFDD992 FLOAT, RCFDD993 FLOAT, RCFDD994 FLOAT, RCFDD995 FLOAT, RCFDD996 FLOAT, RCFDD997 FLOAT, RCFDD998 FLOAT, RCFDD999 FLOAT, RCFDG603 FLOAT, RCFDG604 FLOAT, RCFDG605 FLOAT, RCFDG606 FLOAT, RCFDG607 FLOAT, RCFDG608 FLOAT, RCFDG609 FLOAT, RCFDG610 FLOAT, RCFDG611 FLOAT, RCFDG612 FLOAT, RCFDG613 FLOAT, RCFDG614 FLOAT, RCFDG615 FLOAT, RCFDG616 FLOAT, RCFDG617 FLOAT, RCFDG618 FLOAT, RCFDG619 FLOAT, RCFDG620 FLOAT, RCFDG621 FLOAT, RCFDG622 FLOAT, RCFDG623 FLOAT, RCFDG624 FLOAT, RCFDG625 FLOAT, RCFDG626 FLOAT, RCFDG627 FLOAT, RCFDG628 FLOAT, RCFDG629 FLOAT, RCFDG630 FLOAT, RCFDG631 FLOAT, RCFDG632 FLOAT, RCFDG633 FLOAT, RCFDG634 FLOAT, RCFDG635 FLOAT, RCFDG636 FLOAT, RCFDG637 FLOAT, RCFDG641 FLOAT, RCFDG642 FLOAT, RCFDH171 FLOAT, RCFDH172 FLOAT, RCFDH173 FLOAT, RCFDH174 FLOAT, RCFDH175 FLOAT, RCFDH176 FLOAT, RCFDH177 FLOAT, RCFDH178 FLOAT, RCFDH179 FLOAT, RCFDH180 FLOAT, RCFDH181 FLOAT, RCFDH182 FLOAT, RCFDH185 FLOAT, RCFDH186 FLOAT, RCFDH187 FLOAT, RCFDH188 FLOAT, RCFDH191 FLOAT, RCFDH193 FLOAT, RCFDH194 FLOAT, RCFDH195 FLOAT, RCFDH196 FLOAT, RCFDH197 FLOAT, RCFDH198 FLOAT, RCFDH199 FLOAT, RCFDH200 FLOAT, RCFDH270 FLOAT, RCFDH271 FLOAT, RCFDH272 FLOAT, RCFDH273 FLOAT, RCFDH274 FLOAT, RCFDH275 FLOAT, RCFDH276 FLOAT, RCFDH277 FLOAT, RCFDH278 FLOAT, RCFDH279 FLOAT, RCFDH280 FLOAT, RCFDH281 FLOAT, RCFDH282 FLOAT, RCFDH283 FLOAT, RCFDH284 FLOAT, RCFDH285 FLOAT, RCFDH286 FLOAT, RCFDH287 FLOAT, RCFDH288 FLOAT, RCFDH289 FLOAT, RCFDH290 FLOAT, RCFDH291 FLOAT, RCFDH292 FLOAT, RCFDH293 FLOAT, RCFDH294 FLOAT, RCFDH295 FLOAT, RCFDH296 FLOAT, RCFDH297 FLOAT, RCFDH298 FLOAT, RCFDH299 FLOAT, RCFDH300 FLOAT, RCFDH301 FLOAT, RCFDH302 FLOAT, RCFDH303 FLOAT, RCFDH304 FLOAT, RCFDH307 FLOAT, RCFDH308 FLOAT, RCFDH309 FLOAT, RCFDH310 FLOAT, RCFDHJ74 FLOAT, RCFDHJ75 FLOAT, RCFDHJ76 FLOAT, RCFDHJ77 FLOAT, RCFDHJ78 FLOAT, RCFDHJ79 FLOAT, RCFDHJ80 FLOAT, RCFDHJ81 FLOAT, RCFDHJ82 FLOAT, RCFDHJ83 FLOAT, RCFDHJ84 FLOAT, RCFDHJ85 FLOAT, RCFDHJ86 FLOAT, RCFDHJ87 FLOAT, RCFDHJ88 FLOAT, RCFDHJ89 FLOAT, RCFDHJ90 FLOAT, RCFDHJ91 FLOAT, RCFDHJ92 FLOAT, RCFDHJ93 FLOAT, RCFDHJ94 FLOAT, RCFDHJ95 FLOAT, RCFDHJ96 FLOAT, RCFDHJ97 FLOAT, RCFDHJ98 FLOAT, RCFDHJ99 FLOAT, RCFDHK00 FLOAT, RCFDHK01 FLOAT, RCFDJA21 FLOAT, RCFDJJ30 FLOAT, RCFDJJ31 FLOAT, RCFDJJ32 FLOAT, RCFDS396 FLOAT, RCFDS397 FLOAT, RCFDS398 FLOAT, RCFDS399 FLOAT, RCFDS400 FLOAT, RCFDS402 FLOAT, RCFDS403 FLOAT, RCFDS405 FLOAT, RCFDS406 FLOAT, RCFDS413 FLOAT, RCFDS414 FLOAT, RCFDS415 FLOAT, RCFDS416 FLOAT, RCFDS417 FLOAT, RCFDS419 FLOAT, RCFDS420 FLOAT, RCFDS421 FLOAT, RCFDS423 FLOAT, RCFDS424 FLOAT, RCFDS425 FLOAT, RCFDS426 FLOAT, RCFDS427 FLOAT, RCFDS428 FLOAT, RCFDS429 FLOAT, RCFDS431 FLOAT, RCFDS432 FLOAT, RCFDS433 FLOAT, RCFDS434 FLOAT, RCFDS435 FLOAT, RCFDS436 FLOAT, RCFDS437 FLOAT, RCFDS439 FLOAT, RCFDS440 FLOAT, RCFDS441 FLOAT, RCFDS442 FLOAT, RCFDS443 FLOAT, RCFDS445 FLOAT, RCFDS446 FLOAT, RCFDS447 FLOAT, RCFDS449 FLOAT, RCFDS450 FLOAT, RCFDS451 FLOAT, RCFDS452 FLOAT, RCFDS453 FLOAT, RCFDS454 FLOAT, RCFDS455 FLOAT, RCFDS457 FLOAT, RCFDS458 FLOAT, RCFDS459 FLOAT, RCFDS460 FLOAT, RCFDS461 FLOAT, RCFDS462 FLOAT, RCFDS463 FLOAT, RCFDS466 FLOAT, RCFDS467 FLOAT, RCFDS469 FLOAT, RCFDS470 FLOAT, RCFDS471 FLOAT, RCFDS475 FLOAT, RCFDS476 FLOAT, RCFDS477 FLOAT, RCFDS478 FLOAT, RCFDS479 FLOAT, RCFDS480 FLOAT, RCFDS481 FLOAT, RCFDS482 FLOAT, RCFDS483 FLOAT, RCFDS484 FLOAT, RCFDS485 FLOAT, RCFDS486 FLOAT, RCFDS487 FLOAT, RCFDS488 FLOAT, RCFDS489 FLOAT, RCFDS ...
# CREATE TABLE IF NOT EXISTS Schedule_RCO (RCFDF236 FLOAT, RCFDF237 FLOAT, RCFDG465 FLOAT, RCFDG466 FLOAT, RCFDG467 FLOAT, RCFDG468 FLOAT, RCFDG469 FLOAT, RCFDG470 FLOAT, RCFDG471 FLOAT, RCFDG472 FLOAT, RCFDK652 FLOAT, RCFDK653 FLOAT, RCFDK654 FLOAT, RCFDK655 FLOAT, RCFDK656 BOOLEAN, RCFDK657 VARCHAR, RCFDK658 VARCHAR, RCFDK659 BOOLEAN, RCFDK660 FLOAT, RCFDK661 FLOAT, RCFDK663 VARCHAR, RCFDK664 VARCHAR, RCFDK665 VARCHAR, RCFDK666 VARCHAR, RCFDK669 FLOAT, RCFDK673 VARCHAR, RCFDK674 VARCHAR, RCFDK676 FLOAT, RCFDK677 FLOAT, RCFDL189 FLOAT, RCFDL194 FLOAT, RCFDL195 FLOAT, RCFDL196 FLOAT, RCFDM963 FLOAT, RCFDM964 VARCHAR, RCFDM965 VARCHAR, RCFDM966 VARCHAR, RCFDM967 VARCHAR, RCFDM968 VARCHAR, RCFDM969 VARCHAR, RCFDM970 VARCHAR, RCFDM971 VARCHAR, RCFDM972 VARCHAR, RCFDM973 VARCHAR, RCFDM974 VARCHAR, RCFDM975 VARCHAR, RCFDM976 VARCHAR, RCFDM977 VARCHAR, RCFDM978 VARCHAR, RCFDM979 VARCHAR, RCFDM980 VARCHAR, RCFDM981 VARCHAR, RCFDM982 VARCHAR, RCFDM983 VARCHAR, RCFDM984 VARCHAR, RCFDM985 VARCHAR, RCFDM986 VARCHAR, RCFDM987 VARCHAR, RCFDM988 VARCHAR, RCFDM989 VARCHAR, RCFDM990 VARCHAR, RCFDM991 VARCHAR, RCFDM992 VARCHAR, RCFDM993 VARCHAR, RCFDM994 VARCHAR, RCFDM995 VARCHAR, RCFDM996 VARCHAR, RCFDM997 VARCHAR, RCFDM998 VARCHAR, RCFDM999 VARCHAR, RCFDMW53 FLOAT, RCFDN001 VARCHAR, RCFDN002 VARCHAR, RCFDN003 VARCHAR, RCFDN004 VARCHAR, RCFDN005 VARCHAR, RCFDN006 VARCHAR, RCFDN007 VARCHAR, RCFDN008 VARCHAR, RCFDN009 VARCHAR, RCFDN010 VARCHAR, RCFDN011 VARCHAR, RCFDN012 VARCHAR, RCFDN013 VARCHAR, RCFDN014 VARCHAR, RCFDN015 VARCHAR, RCFDN016 VARCHAR, RCFDN017 VARCHAR, RCFDN018 VARCHAR, RCFDN019 VARCHAR, RCFDN020 VARCHAR, RCFDN021 VARCHAR, RCFDN022 VARCHAR, RCFDN023 VARCHAR, RCFDN024 VARCHAR, RCFDN025 VARCHAR, RCFDN026 VARCHAR, RCFDN027 VARCHAR, RCFDN028 VARCHAR, RCFDN029 VARCHAR, RCFDN030 VARCHAR, RCFDN040 VARCHAR, RCFDN041 VARCHAR, RCFDN042 VARCHAR, RCFDN043 VARCHAR, RCFDN044 VARCHAR, RCFDN045 VARCHAR, RCFDN046 VARCHAR, RCFDN047 VARCHAR, RCFDN048 VARCHAR, RCFDN049 VARCHAR, RCFDN050 VARCHAR, RCFDN051 VARCHAR, RCFDN052 VARCHAR, RCFDN053 VARCHAR, RCFDN054 VARCHAR, RCFDN055 VARCHAR, RCFDN056 VARCHAR, RCFDN057 VARCHAR, RCFDN058 VARCHAR, RCFDN059 VARCHAR, RCFDN060 VARCHAR, RCFDN061 VARCHAR, RCFDN062 VARCHAR, RCFDN063 VARCHAR, RCFDN064 VARCHAR, RCFDN065 VARCHAR, RCFDN066 VARCHAR, RCFDN067 VARCHAR, RCFDN068 VARCHAR, RCFDN069 VARCHAR, RCFDN070 VARCHAR, RCFDN071 VARCHAR, RCFDN072 VARCHAR, RCFDN073 VARCHAR, RCFDN074 VARCHAR, RCFDN075 VARCHAR, RCFDN076 VARCHAR, RCFDN077 VARCHAR, RCFDN078 VARCHAR, RCFDN079 VARCHAR, RCFDN080 VARCHAR, RCFDN081 VARCHAR, RCFDN082 VARCHAR, RCFDN083 VARCHAR, RCFDN084 VARCHAR, RCFDN085 VARCHAR, RCFDN086 VARCHAR, RCFDN087 VARCHAR, RCFDN088 VARCHAR, RCFDN089 VARCHAR, RCFDN090 VARCHAR, RCFDN091 VARCHAR, RCFDN092 VARCHAR, RCFDN093 VARCHAR, RCFDN094 VARCHAR, RCFDN095 VARCHAR, RCFDN096 VARCHAR, RCFDN097 VARCHAR, RCFDN098 VARCHAR, RCFDN099 VARCHAR, RCFDN100 VARCHAR, RCFDN101 VARCHAR, RCFDN102 VARCHAR, RCFDN103 VARCHAR, RCFDN104 VARCHAR, RCFDN105 VARCHAR, RCFDN106 VARCHAR, RCFDN107 VARCHAR, RCFDN108 VARCHAR, RCFDN109 VARCHAR, RCFDN110 VARCHAR, RCFDN111 VARCHAR, RCFDN112 VARCHAR, RCFDN113 VARCHAR, RCFDN114 VARCHAR, RCFDN115 VARCHAR, RCFDN116 VARCHAR, RCFDN117 VARCHAR, RCFDN118 VARCHAR, RCFDN119 VARCHAR, RCFDN120 VARCHAR, RCFDN121 VARCHAR, RCFDN122 VARCHAR, RCFDN123 VARCHAR, RCFDN124 VARCHAR, RCFDN125 VARCHAR, RCFDN126 VARCHAR, RCFDN127 VARCHAR, RCFDN128 VARCHAR, RCFDN177 FLOAT, RCFDN178 FLOAT, RCFDN179 FLOAT, RCFDN180 FLOAT, RCFDN181 FLOAT, RCFDN182 FLOAT, RCFDN183 FLOAT, RCFNF234 FLOAT, RCFNGW43 FLOAT, RCON0030 VARCHAR, RCON0031 VARCHAR, RCON0032 VARCHAR, RCON2211 VARCHAR, RCON2229 VARCHAR, RCON2314 VARCHAR, RCON2315 VARCHAR, RCON2351 VARCHAR, RCON2383 VARCHAR, RCON2702 VARCHAR, RCON2710 VARCHAR, RCON2722 VARCHAR, RCON3510 VARCHAR, RCON3512 VARCHAR, RCON3514 VARCHAR, RCON3520 VARCHAR, RCON3779 VARCHAR, RCON5514 VARCHAR, RCON5515 VARCHAR, RCON5516 VARCHAR, RCON5517 VARCHAR, RCON5596 VARCHAR, RCON5597 FLOAT, RCON8432 VARCHAR, RCON8785 VARCHA ...

# %%
conn= snow.connect(user="WALKERHILLS", password="h!123@iLLs#", account="lrlwqdb-yib23397")

# %%
def main(conn, full_query_list):
    cur = conn.cursor()
    sql = "USE ROLE ACCOUNTADMIN"
    cur.execute(sql)
    sql = "USE WAREHOUSE COMPUTE_WH"
    cur.execute(sql)
    sql = "ALTER WAREHOUSE COMPUTE_WH RESUME IF SUSPENDED"
    cur.execute(sql)
    sql = "CREATE DATABASE IF NOT EXISTS CALLREPORTDB"
    cur.execute(sql)
    sql = "USE DATABASE CALLREPORTDB"
    cur.execute(sql)
    sql = "CREATE SCHEMA IF NOT EXISTS PUBLIC"
    cur.execute(sql)
    sql = "USE SCHEMA PUBLIC"
    cur.execute(sql)
    for query in full_query_list:
        cur.execute(query)
    sql = "ALTER WAREHOUSE COMPUTE_WH SUSPEND"
    cur.execute(sql)
    cur.close()
    conn.close()

# %%
if __name__ == "__main__":
    main(conn,full_query_list)

# %%
def main(session: snowpark.Session): 
    # CREATE TABLE
    create_table_query  = f"""
       CREATE OR REPLACE TABLE TEST_DB.TEST_SCHEMA.CALL_CENTER_COPY AS
       SELECT 
              CC_CALL_CENTER_ID
             ,CC_REC_START_DATE 
             ,CC_REC_END_DATE
       FROM TEST_DB.TEST_SCHEMA.CALL_CENTER;
    """
    session.sql(create_table_query).collect()
    # SELECT TABLE
    create_table_query  = f"""
       SELECT 
              *
       FROM TEST_DB.TEST_SCHEMA.CALL_CENTER_COPY;
    """
    call_center_table = session.sql(create_table_query).collect()
    return call_center_table

# %%
mdrm_filtered = filter_mdrm(path="C:\\Users\\whill\\call-report-database\\MDRM_CSV.csv")

# %%
filers = methods.collect_filers_on_reporting_period(
    session=conn,
    creds=creds,
    reporting_period="9/30/2023",
    output_type='pandas'
)
filers
# Out:
#       id_rssd fdic_cert_number occ_chart_number ots_dock_number  \
# 0          37            10057             None           16553
# 1         242             3850             None            None
# 2         279            28868             None            2523
# 3         354            14083             None            None
# 4         457            10202             None            None
# ...       ...              ...              ...             ...
# 4664  5805479            59346            25287            None
# 4665  5805488            59349            25275            None
# 4666  5805817            59337            25237            None
# 4667  5859511            59344            25288            None
# 4668  5860740            59305             None            None
#
#      primary_aba_rout_number  \
# 0                   61107146
# 1                   81220537
# 2                  311972526
# 3                  101107475
# 4                   91208332
# ...                      ...
# 4664               122402463
# 4665               121202457
# 4666                91018470
# 4667                53012977
# 4668                72414514
#
#                                                    name state         city  \
# 0                                BANK OF HANCOCK COUNTY    GA       SPARTA
# 1                      FIRST COMMUNITY BANK XENIA-FLORA    IL        XENIA
# 2                           MINEOLA COMMUNITY BANK, SSB    TX      MINEOLA
# 3                                      BISON STATE BANK    KS        BISON
# 4                                      LOWRY STATE BANK    MN        LOWRY
# ...                                                 ...   ...          ...
# 4664  BESSEMER TRUST COMPANY OF NEVADA, NATIONAL ASS...    NV    LAS VEGAS
# 4665        INSPIRE TRUST COMPANY, NATIONAL ASSOCIATION    NV         RENO
# 4666                       CERIDIAN NATIONAL TRUST BANK    MN  BLOOMINGTON
# 4667                   TIAA TRUST, NATIONAL ASSOCIATION    NC    CHARLOTTE
# 4668                               COMMUNITY UNITY BANK    MI   BIRMINGHAM
#
#                                                 address filing_type  \
# 0                                    12855 BROAD STREET         051
# 1                                      260 FRONT STREET         051
# 2                                           215 W BROAD         051
# 3                                       223 MAIN STREET         051
# 4                                     400 FLORENCE AVE.         051
# ...                                                 ...         ...
# 4664  1700 SOUTH PAVILION CENTER DRIVE         SUITE...         051
# 4665                         241 RIDGE STREET SUITE 310         041
# 4666                        3311 EAST OLD SHAKOPEE ROAD         051
# 4667                     8500 ANDREW CARNEGIE BOULEVARD         051
# 4668                              34040 WOODWARD AVENUE         051
#
#       has_filed_for_reporting_period
# 0                               True
# 1                               True
# 2                               True
# 3                               True
# 4                               True
# ...                              ...
# 4664                            True
# 4665                            True
# 4666                            True
# 4667                            True
# 4668                            True
#
# [4669 rows x 11 columns]

# %%
time_series = methods.collect_data(
                session=conn,
                creds=creds,
                rssd_id=37,
                reporting_period="9/30/2023",
                series="call",
                output_type='pandas'
                )
time_series[time_series['mdrm']=='RSSD9017']
# Out:
#         mdrm rssd    quarter  int_data  float_data bool_data  \
# 53  RSSD9017   37  9/30/2023       NaN         NaN      None
#
#                   str_data data_type
# 53  BANK OF HANCOCK COUNTY       str

# %%
id_rssd_set = set(filers['id_rssd'])

# %%
len(id_rssd_set)
# Out:
# 4669

# %%
for id_rssd in id_rssd_set:
    print(str(id_rssd))
# Out:
# 2986407
# 987231
# 2806840
# 143952
# 835378
# 701857
# 753052
# 5805488
# 506922
# 686459
# 687830
# 3952904
# 358112
# 568135
# 37341
# 2921211
# 527954
# 959630
# 21658
# 175609
# 397559
# 754246
# 785950
# 109453
# 823478
# 764151
# 2533119
# 2193616
# 147679
# 498148
# 717232
# 757452
# 399357
# 786555
# 920733
# 692946
# 680055
# 152253
# 482156
# 624778
# 1188772
# 189129
# 233358
# 106452
# 141677
# 547251
# 88950
# 956956
# 126012
# 463650
# 228000
# 814074
# 814711
# 3153233
# 719030
# 960560
# 760939
# 568377
# 733054
# 3268249
# 176464
# 3214059
# 573036
# 166849
# 280558
# 479268
# 179335
# 90047
# 118156
# 910079
# 505
# 965789
# 22048
# 333650
# 584377
# 837653
# 1879016
# 2719810
# 44741
# 37051
# 282226
# 459671
# 724744
# 775773
# 43052
# 904845
# 550635
# 999935
# 207470
# 655839
# 578116
# 3216316
# 5069
# 83834
# 354057
# 470050
# 739832
# 2916534
# 384018
# 33370
# 311603
# 1391778
# 331076
# 776369
# 627854
# 128258
# 325141
# 738143
# 208459
# 916745
# 3476192
# 820879
# 235174
# 513340
# 33259
# 336147
# 145554
# 720157
# 768476
# 2819242
# 732954
# 98351
# 68671
# 875132
# 581237
# 432058
# 924553
# 919568
# 921178
# 252452
# 715470
# 771140
# 137205
# 112332
# 780049
# 319047
# 411576
# 135836
# 5205819
# 64150
# 744854
# 1006513
# 12647
# 2915461
# 564838
# 28013
# 518354
# 1017564
# 814551
# 142049
# 202907
# 973252
# 1014853
# 634544
# 742056
# 220974
# 262237
# 989730
# 378044
# 1015832
# 242257
# 357777
# 933975
# 560830
# 651354
# 46941
# 805876
# 3310287
# 267652
# 311658
# 41825
# 384652
# 760649
# 768953
# 758851
# 871769
# 773742
# 228279
# 89032
# 738040
# 994770
# 133971
# 2610784
# 177443
# 407645
# 966731
# 976703
# 284752
# 2037185
# 2536633
# 157744
# 490955
# 1011656
# 413673
# 552974
# 43856
# 263627
# 678557
# 956134
# 595944
# 898579
# 2232757
# 277736
# 148715
# 206156
# 630555
# 765877
# 646471
# 861658
# 923855
# 2649177
# 7009
# 779360
# 1008553
# 621151
# 3374234
# 79855
# 457060
# 877350
# 3485420
# 885225
# 2508751
# 594433
# 61953
# 3254297
# 961400
# 843542
# 520003
# 521158
# 4845861
# 937843
# 924236
# 770451
# 290922
# 251978
# 236706
# 2916963
# 419947
# 273662
# 328058
# 708379
# 3320781
# 675079
# 968744
# 332756
# 108269
# 5312593
# 841472
# 24949
# 219044
# 772008
# 1016857
# 1440117
# 233442
# 480246
# 546544
# 918132
# 1008209
# 224954
# 3374382
# 265407
# 59754
# 449430
# 135854
# 665146
# 601443
# 292850
# 258379
# 79042
# 375379
# 376947
# 233031
# 484057
# 528102
# 602842
# 748441
# 237954
# 803658
# 982348
# 663656
# 2354985
# 3090833
# 366658
# 178244
# 991621
# 815156
# 50461
# 2354323
# 126553
# 1402384
# 3391718
# 3487947
# 421539
# 503547
# 235950
# 946555
# 2815879
# 598132
# 3284445
# 1001639
# 926650
# 323204
# 3180136
# 3341393
# 400767
# 775054
# 660927
# 304913
# 141556
# 138051
# 965051
# 243414
# 1003455
# 1003839
# 212018
# 592448
# 169653
# 327435
# 473930
# 2901558
# 840019
# 305237
# 660655
# 594853
# 923707
# 1397471
# 502849
# 344852
# 839572
# 932978
# 3419416
# 852544
# 450856
# 780218
# 773443
# 364850
# 634955
# 712648
# 67209
# 677970
# 1016558
# 91754
# 317342
# 423636
# 664756
# 516873
# 780263
# 450959
# 100357
# 840363
# 953852
# 263243
# 139553
# 354552
# 580548
# 811457
# 863362
# 428547
# 761954
# 2914727
# 285852
# 234355
# 379470
# 2861317
# 753641
# 823450
# 3594797
# 3869123
# 221775
# 435077
# 2621940
# 502111
# 305077
# 557317
# 474245
# 421445
# 583071
# 773171
# 700252
# 272302
# 906410
# 3623110
# 865759
# 355559
# 154770
# 711801
# 885430
# 430036
# 192651
# 414652
# 3437157
# 5758436
# 932633
# 309655
# 785473
# 412452
# 5210
# 445674
# 790271
# 819855
# 944047
# 809379
# 720858
# 738013
# 591357
# 805250
# 3296859
# 120476
# 582971
# 645625
# 43351
# 457220
# 837448
# 474254
# 350750
# 3048487
# 918150
# 3623969
# 612878
# 475653
# 2652092
# 5777549
# 670878
# 770639
# 477349
# 852254
# 3412417
# 479370
# 919344
# 2107341
# 664176
# 2482824
# 605610
# 402873
# 749840
# 56258
# 204237
# 83375
# 565844
# 55970
# 911339
# 719610
# 2140348
# 250430
# 3595271
# 5382514
# 1018927
# 3719648
# 457
# 141958
# 763677
# 1006148
# 1016259
# 3286999
# 959443
# 499743
# 685676
# 5427684
# 2855866
# 280138
# 76153
# 963945
# 3229875
# 5472880
# 102333
# 432432
# 236957
# 863746
# 61757
# 274548
# 536349
# 63050
# 580874
# 68831
# 594451
# 274052
# 3153297
# 271341
# 544652
# 991854
# 2809373
# 82257
# 515979
# 715050
# 214722
# 497851
# 969059
# 3357077
# 123075
# 939249
# 333203
# 969639
# 1429028
# 371849
# 2333140
# 678052
# 926959
# 22543
# 382742
# 3235410
# 879439
# 108652
# 850054
# 1003950
# 262358
# 2044820
# 3076453
# 937553
# 469250
# 347956
# 848248
# 858528
# 31134
# 2791085
# 3145797
# 418436
# 2651899
# 497404
# 3547131
# 912756
# 3428258
# 646743
# 67656
# 561659
# 923949
# 3089752
# 425818
# 786948
# 3531176
# 921655
# 747257
# 129479
# 167453
# 399517
# 759045
# 830748
# 497655
# 498942
# 162337
# 741068
# 897237
# 406059
# 2643595
# 3485215
# 72351
# 477321
# 2989006
# 300009
# 867650
# 247355
# 1011852
# 208244
# 2858960
# 331375
# 925055
# 453147
# 651541
# 765662
# 120953
# 901741
# 609645
# 3138146
# 39756
# 739355
# 916857
# 750051
# 677354
# 1444021
# 3150205
# 413646
# 724940
# 1010574
# 955753
# 149150
# 972406
# 422059
# 900306
# 565750
# 2903123
# 351131
# 304520
# 2182786
# 1404883
# 3308574
# 45038
# 289515
# 485139
# 3224580
# 2907439
# 32766
# 2597223
# 273859
# 144913
# 907444
# 493152
# 208347
# 272058
# 518037
# 1011432
# 201254
# 616540
# 959304
# 2800491
# 2390929
# 836656
# 5592340
# 176101
# 617079
# 785923
# 735441
# 711472
# 63733
# 3070545
# 729310
# 900678
# 386450
# 459130
# 934329
# 1007734
# 3447576
# 34555
# 786733
# 3223305
# 164153
# 168571
# 3459207
# 284958
# 289225
# 111979
# 270504
# 1008450
# 339607
# 65205
# 857875
# 915065
# 287922
# 2562137
# 10250
# 291611
# 882952
# 109154
# 3285778
# 392778
# 67151
# 1191352
# 186744
# 2920773
# 482053
# 933621
# 12311
# 936426
# 228345
# 483537
# 394259
# 979151
# 706450
# 2730431
# 51356
# 603232
# 313577
# 367543
# 682143
# 382649
# 3202702
# 172859
# 760854
# 3052813
# 677756
# 406022
# 17110
# 822051
# 825753
# 358756
# 436953
# 501767
# 3629420
# 289739
# 363778
# 716851
# 931159
# 139133
# 231279
# 306337
# 524766
# 2724766
# 5342974
# 591366
# 2970657
# 282824
# 238250
# 1015560
# 170275
# 812436
# 799359
# 548472
# 737548
# 497954
# 172251
# 498362
# 180537
# 416339
# 565143
# 575133
# 654047
# 783161
# 877958
# 389358
# 510330
# 923752
# 3016347
# 197254
# 364430
# 147923
# 4231
# 1016174
# 856748
# 619877
# 711520
# 198149
# 472045
# 33857
# 794653
# 3465226
# 716374
# 122546
# 632410
# 866251
# 112837
# 494654
# 903950
# 345756
# 718538
# 83955
# 254849
# 470434
# 2007991
# 514048
# 989758
# 3049729
# 317258
# 3015939
# 98717
# 269058
# 782306
# 783349
# 3438958
# 527749
# 94522
# 901358
# 413758
# 185448
# 1492817
# 687054
# 54973
# 2700984
# 2847142
# 199351
# 540551
# 901974
# 624246
# 1459799
# 615253
# 2716088
# 370833
# 403870
# 811747
# 855563
# 669555
# 534466
# 767732
# 897451
# 340144
# 356752
# 206950
# 1842065
# 329952
# 608844
# 329149
# 338646
# 234841
# 42354
# 179148
# 332224
# 818652
# 954251
# 140634
# 35301
# 214414
# 400057
# 2044811
# 2642598
# 5518023
# 918776
# 3309393
# 681249
# 472250
# 529659
# 567240
# 610164
# 614256
# 277240
# 930358
# 646444
# 782016
# 2726050
# 539032
# 257653
# 538754
# 591320
# 825847
# 167752
# 794149
# 3010363
# 857576
# 1459735
# 207872
# 596455
# 316840
# 806958
# 2797162
# 586072
# 113601
# 2747466
# 554268
# 339456
# 856944
# 773032
# 88259
# 976552
# 5349218
# 765505
# 824738
# 980951
# 61122
# 173959
# 284556
# 331713
# 522034
# 891226
# 3020447
# 3349241
# 268136
# 353546
# 786340
# 1010015
# 566243
# 370347
# 507349
# 114149
# 657459
# 845573
# 2451240
# 622774
# 3470154
# 280352
# 3633173
# 357526
# 606176
# 875655
# 273336
# 644842
# 692450
# 2344753
# 182951
# 1394676
# 382050
# 719964
# 365950
# 490450
# 861854
# 3383665
# 94858
# 323651
# 3411773
# 4368351
# 23456
# 143859
# 653778
# 316859
# 245016
# 1015850
# 2860271
# 555256
# 536554
# 294827
# 33147
# 311050
# 514132
# 535931
# 1856
# 179700
# 597041
# 220059
# 748254
# 62147
# 791072
# 931355
# 1001059
# 3388482
# 163857
# 164331
# 306908
# 3268173
# 987848
# 154154
# 2753917
# 1000641
# 339773
# 2236821
# 30052
# 169354
# 601416
# 754068
# 570558
# 102342
# 24659
# 795548
# 3347911
# 762045
# 94755
# 377850
# 3370357
# 452739
# 2218443
# 931207
# 5332603
# 750444
# 537449
# 936136
# 925411
# 637170
# 695349
# 1852569
# 657365
# 2963266
# 307679
# 722544
# 3938186
# 104971
# 5193989
# 830542
# 73554
# 958727
# 163549
# 687009
# 610913
# 3346633
# 859002
# 767255
# 5192496
# 952257
# 159636
# 1228034
# 5582846
# 227656
# 623548
# 1872941
# 487357
# 255547
# 631570
# 609476
# 3122994
# 352745
# 367431
# 667346
# 760210
# 534877
# 419675
# 860334
# 670430
# 177751
# 185859
# 858818
# 791353
# 2705895
# 5784921
# 343958
# 266244
# 885869
# 2391588
# 303701
# 731247
# 974558
# 531157
# 311265
# 1892154
# 3645840
# 411549
# 60545
# 689759
# 217059
# 229173
# 2797359
# 835659
# 37640
# 688079
# 888552
# 480059
# 609609
# 314444
# 981453
# 513546
# 2580243
# 278751
# 286251
# 592550
# 606653
# 2860039
# 729842
# 733559
# 255556
# 127224
# 124830
# 1863097
# 541642
# 58243
# 3109146
# 2791517
# 663245
# 746942
# 2949970
# 633378
# 516855
# 129732
# 899642
# 960047
# 927479
# 422116
# 695947
# 796451
# 2694681
# 5751
# 3468450
# 682563
# 746157
# 246947
# 601041
# 6039
# 442011
# 505550
# 1001853
# 2820604
# 2939001
# 163343
# 59316
# 3309571
# 2887399
# 17978
# 222558
# 552161
# 858854
# 333940
# 330873
# 398051
# 993250
# 1005851
# 2337335
# 597313
# 3320576
# 343051
# 637554
# 152057
# 580155
# 164975
# 800134
# 860147
# 32971
# 526452
# 140362
# 2736714
# 3435948
# 24006
# 307334
# 356659
# 434539
# 3447820
# 734248
# 477639
# 867070
# 531250
# 707354
# 5514409
# 222754
# 5686324
# 815754
# 654579
# 962966
# 73116
# 729011
# 87047
# 420644
# 229913
# 37659
# 473042
# 831941
# 647218
# 1002373
# 677176
# 305059
# 550952
# 188449
# 177500
# 215710
# 249612
# 158741
# 232847
# 413208
# 450632
# 129358
# 447557
# 608358
# 603540
# 497570
# 420877
# 598048
# 587677
# 656658
# 3224478
# 5543735
# 952677
# 285151
# 228158
# 476539
# 863607
# 433550
# 986935
# 1187001
# 880855
# 2897633
# 186717
# 103134
# 131717
# 109136
# 424156
# 700430
# 782548
# 528849
# 113003
# 3538009
# 498531
# 524953
# 581358
# 538802
# 287342
# 819172
# 922559
# 2641827
# 541231
# 413543
# 244158
# 2948058
# 171759
# 197759
# 451068
# 489548
# 925354
# 1470150
# 295646
# 828473
# 644646
# 3128923
# 1014376
# 909756
# 431350
# 597546
# 522753
# 976954
# 181963
# 69333
# 672537
# 1015270
# 1017854
# 129853
# 534756
# 474058
# 614948
# 643658
# 777870
# 552545
# 898627
# 2992547
# 324340
# 839817
# 389376
# 1216826
# 208570
# 932745
# 3786435
# 740249
# 477648
# 332345
# 995517
# 275479
# 326979
# 810544
# 853251
# 387671
# 803649
# 351878
# 274829
# 770853
# 742944
# 1014554
# 884442
# 123374
# 466240
# 379649
# 819556
# 593940
# 1351
# 803256
# 131940
# 1014059
# 427858
# 874050
# 717924
# 357937
# 2747279
# 888002
# 498317
# 2921622
# 5859511
# 653433
# 553038
# 892205
# 582953
# 997847
# 343248
# 661072
# 1016941
# 72678
# 554857
# 3110197
# 2785477
# 349343
# 624648
# 1000856
# 286840
# 612159
# 5805451
# 527600
# 864471
# 718275
# 808260
# 556936
# 542854
# 870650
# 788559
# 86675
# 126834
# 544447
# 124344
# 146056
# 596062
# 489155
# 604033
# 813853
# 205542
# 835257
# 200435
# 397755
# 832546
# 2705112
# 30650
# 3487433
# 876157
# 3816163
# 3596250
# 37949
# 24378
# 685023
# 183668
# 875057
# 755252
# 314257
# 338851
# 3281510
# 513322
# 928618
# 907547
# 92902
# 796657
# 278555
# 1386251
# 366247
# 823133
# 2687487
# 729945
# 42420
# 985451
# 1011553
# 361167
# 357553
# 3165357
# 2960555
# 886624
# 644141
# 788652
# 3720608
# 308836
# 864378
# 148470
# 402846
# 200378
# 361279
# 561864
# 77150
# 576608
# 3224375
# 735414
# 715872
# 408307
# 5528880
# 2164111
# 276645
# 856243
# 2594419
# 768458
# 275255
# 597452
# 4149037
# 853671
# 918954
# 822042
# 509857
# 517441
# 643340
# 888271
# 279954
# 4536084
# 5412457
# 723158
# 3262788
# 384830
# 770545
# 858443
# 289702
# 831875
# 25357
# 534073
# 3463875
# 837970
# 2805535
# 420653
# 129910
# 574949
# 100777
# 833851
# 116741
# 860053
# 3217957
# 5136959
# 2531562
# 283737
# 13103
# 844455
# 881900
# 958558
# 564557
# 659855
# 576354
# 141350
# 49241
# 71859
# 526519
# 724904
# 890078
# 346566
# 311256
# 114774
# 343903
# 328656
# 90337
# 121642
# 960551
# 427353
# 865450
# 936855
# 79145
# 984351
# 2107181
# 460556
# 1015841
# 2619714
# 579636
# 5805228
# 493077
# 660253
# 813572
# 2661861
# 5805817
# 804150
# 209858
# 19936
# 5050028
# 936583
# 207050
# 638131
# 542528
# 761244
# 649632
# 501815
# 329345
# 2533043
# 414102
# 493844
# 587752
# 691042
# 742542
# 12946
# 611031
# 3134399
# 543945
# 429487
# 2743244
# 561145
# 309851
# 379920
# 1225798
# 227151
# 286457
# 649342
# 207845
# 786612
# 986551
# 3213333
# 406974
# 513256
# 918356
# 2758613
# 453446
# 283867
# 735067
# 3588424
# 3212149
# 518877
# 578741
# 411174
# 904359
# 2997748
# 956554
# 2489805
# 3350724
# 325534
# 797140
# 137456
# 255350
# 248455
# 539872
# 651158
# 613839
# 2471239
# 541754
# 28732
# 659556
# 49054
# 454975
# 815277
# 401906
# 66154
# 7456
# 414764
# 189950
# 295011
# 431172
# 295057
# 661157
# 65559
# 428462
# 416357
# 449832
# 785147
# 655530
# 5538937
# 140157
# 83638
# 61832
# 382854
# 302030
# 689357
# 2835103
# 3851427
# 1414819
# 694146
# 2265456
# 3404506
# 1458608
# 410944
# 785857
# 787141
# 229070
# 492650
# 1007958
# 251558
# 979375
# 3252
# 835613
# 987259
# 972769
# 895055
# 425845
# 3448162
# 1225761
# 481627
# 435255
# 549862
# 663955
# 706236
# 127055
# 125154
# 215662
# 971379
# 362717
# 750846
# 107570
# 667757
# 723653
# 557858
# 5475452
# 23755
# 564052
# 235558
# 427241
# 439356
# 745347
# 253730
# 327556
# 316934
# 686570
# 3588312
# 624956
# 991359
# 187947
# 3567269
# 702117
# 269571
# 75446
# 435666
# 817824
# 948531
# 2913702
# 804860
# 476810
# 233554
# 966722
# 1493319
# 2759629
# 519445
# 561574
# 247908
# 403151
# 193537
# 465672
# 729570
# 160360
# 771047
# 942539
# 276551
# 447100
# 546320
# 779016
# 396253
# 646873
# 535753
# 724230
# 738769
# 944337
# 735049
# 2465881
# 333034
# 571135
# 285777
# 3627109
# 2764212
# 858452
# 701062
# 371755
# 424633
# 525549
# 212522
# 274856
# 839068
# 792453
# 111157
# 1883321
# 3270046
# 668053
# 809070
# 1007417
# 429021
# 568470
# 601658
# 194440
# 677448
# 906241
# 1014125
# 3103591
# 3287660
# 110413
# 807432
# 173557
# 989851
# 339072
# 647245
# 870856
# 259442
# 296559
# 2325882
# 113441
# 823638
# 172475
# 1218446
# 141211
# 3248849
# 3271986
# 789051
# 915935
# 3783948
# 243955
# 439338
# 42457
# 276850
# 755458
# 3120897
# 171768
# 292908
# 715032
# 805335
# 883351
# 20857
# 508355
# 950141
# 3357219
# 148920
# 306159
# 3939240
# 213958
# 85931
# 1015458
# 132938
# 206174
# 1016718
# 538473
# 116554
# 672573
# 727174
# 577128
# 659341
# 982553
# 1445943
# 278733
# 944627
# 862057
# 270652
# 5398627
# 821643
# 193649
# 18050
# 391557
# 514655
# 3635029
# 307361
# 3344321
# 26765
# 521970
# 958231
# 702966
# 369453
# 498456
# 772446
# 879747
# 3688548
# 456755
# 713926
# 816256
# 1462986
# 92144
# 2068107
# 975153
# 3545258
# 411062
# 491224
# 472979
# 519360
# 675042
# 3816154
# 365325
# 877752
# 501655
# 252658
# 247551
# 714978
# 651121
# 712059
# 593333
# 998657
# 100562
# 733755
# 997155
# 49148
# 166652
# 491402
# 651756
# 700458
# 741358
# 975452
# 190956
# 460033
# 756848
# 2877831
# 245351
# 830645
# 303747
# 552059
# 814476
# 1005552
# 794475
# 771458
# 2877840
# 3213735
# 23504
# 1011638
# 408875
# 618807
# 935719
# 688453
# 666059
# 875048
# 74403
# 261360
# 856869
# 508270
# 3139321
# 274025
# 723550
# 93244
# 340256
# 2735146
# 1008674
# 209559
# 401072
# 371924
# 1820979
# 3277241
# 940021
# 294779
# 384353
# 3472859
# 320119
# 73956
# 18854
# 474656
# 635907
# 2631846
# 485054
# 808653
# 5210989
# 571957
# 625140
# 832528
# 915056
# 936462
# 443625
# 3187630
# 81175
# 1016848
# 4146830
# 2747587
# 350572
# 52951
# 499752
# 284154
# 589158
# 2684552
# 778738
# 780722
# 837149
# 2953418
# 962890
# 3189063
# 869346
# 995674
# 861153
# 614368
# 901451
# 424240
# 174321
# 795968
# 3377235
# 5448915
# 35057
# 244149
# 541307
# 40855
# 830113
# 887854
# 5401273
# 107758
# 5758445
# 847157
# 44929
# 761459
# 667551
# 867856
# 174367
# 762474
# 509950
# 2850722
# 338945
# 2597232
# 101671
# 490348
# 696430
# 754853
# 488756
# 330239
# 835743
# 760331
# 3688623
# 3387140
# 644954
# 788773
# 970055
# 2998576
# 697231
# 14977
# 783844
# 2529176
# 426758
# 3599804
# 116358
# 366078
# 380533
# 428060
# 424352
# 621357
# 373601
# 93543
# 799939
# 507068
# 1940747
# 3116519
# 1007752
# 444677
# 741956
# 544335
# 672247
# 582878
# 916259
# 2733263
# 657271
# 855303
# 840251
# 247476
# 3455227
# 94139
# 242444
# 824242
# 2262718
# 526854
# 5691319
# 260831
# 666844
# 390840
# 815772
# 382256
# 940731
# 387055
# 2881445
# 904171
# 3067929
# 604640
# 138556
# 242976
# 3437148
# 958204
# 1494482
# 191935
# 315656
# 463605
# 393355
# 667029
# 258146
# 800853
# 774235
# 333856
# 214106
# 2756909
# 374130
# 44750
# 504535
# 258539
# 3448425
# 2796277
# 3617856
# 820477
# 8462
# 829032
# 426057
# 859552
# 19356
# 192857
# 2857600
# 82033
# 3821037
# 97457
# 256553
# 352772
# 613400
# 49951
# 99536
# 868956
# 921936
# 2596646
# 5728916
# 3353154
# 280110
# 3340725
# 218878
# 220844
# 767152
# 888833
# 3812147
# 467144
# 34742
# 568126
# 391575
# 425108
# 741974
# 1012457
# 240954
# 145059
# 472616
# 852218
# 370020
# 3630323
# 3325759
# 607146
# 5660146
# 76854
# 1015252
# 637451
# 504647
# 4156
# 1002458
# 446877
# 902645
# 5316920
# 746429
# 3025929
# 761851
# 3610718
# 980531
# 666358
# 898458
# 828651
# 714839
# 1404481
# 211114
# 396954
# 382537
# 164957
# 3040418
# 78241
# 660570
# 195157
# 783648
# 579364
# 3285246
# 949154
# 1459717
# 117775
# 214807
# 2877484
# 572655
# 2634191
# 1211371
# 944748
# 534859
# 629746
# 849076
# 3306598
# 941541
# 507152
# 1222948
# 321152
# 159953
# 818559
# 351560
# 1155
# 458544
# 225942
# 950356
# 903240
# 875879
# 2209553
# 2807173
# 2806877
# 799948
# 2849801
# 859655
# 914545
# 480330
# 457426
# 119872
# 495419
# 579319
# 865142
# 2667939
# 440857
# 509811
# 443205
# 532042
# 550448
# 70955
# 296456
# 360777
# 275657
# 372444
# 418100
# 641449
# 2914268
# 990642
# 3378773
# 3721605
# 5724226
# 777366
# 374653
# 2602828
# 758842
# 2833882
# 229342
# 709639
# 959715
# 186221
# 575348
# 876634
# 517049
# 969844
# 950758
# 494261
# 616036
# 215345
# 14753
# 241607
# 45458
# 270531
# 22552
# 499501
# 3308529
# 300353
# 485456
# 647777
# 858153
# 630041
# 1481745
# 451965
# 527057
# 2051127
# 702836
# 3440803
# 35646
# 173306
# 786256
# 572347
# 980960
# 3637685
# 654300
# 844138
# 289757
# 324975
# 1387605
# 211338
# 479839
# 285928
# 972750
# 870539
# 932642
# 219679
# 256076
# 5591633
# 742636
# 118736
# 38740
# 848453
# 246451
# 863652
# 830252
# 2708122
# 597658
# 2871558
# 511832
# 188917
# 122854
# 437044
# 603559
# 2497181
# 375566
# 835079
# 147857
# 476445
# 117074
# 42037
# 753856
# 621441
# 310754
# 665865
# 414858
# 606046
# 821559
# 321947
# 439730
# 1009354
# 648251
# 89854
# 58355
# 651149
# 933041
# 693345
# 278818
# 591209
# 767246
# 522454
# 3342671
# 961624
# 1014657
# 345877
# 702612
# 3446225
# 1443266
# 1718188
# 430054
# 3690635
# 51842
# 761806
# 91950
# 3597211
# 114840
# 864846
# 3636428
# 910239
# 6329
# 998358
# 641579
# 1356768
# 444556
# 1014255
# 1945247
# 697156
# 34434
# 619701
# 820842
# 326344
# 596277
# 276579
# 2771694
# 266945
# 269759
# 847979
# 586027
# 2577739
# 927134
# 117458
# 994435
# 3042234
# 908861
# 1009242
# 300933
# 930853
# 749635
# 301574
# 609010
# 521064
# 1163283
# 3437456
# 516154
# 913856
# 14650
# 60554
# 989347
# 291732
# 82350
# 566056
# 718145
# 495558
# 180845
# 439404
# 345309
# 105026
# 362043
# 214843
# 2316714
# 3076248
# 31826
# 264772
# 203043
# 313009
# 365848
# 89135
# 1917301
# 2713920
# 3816190
# 583352
# 826451
# 2505451
# 75259
# 1435092
# 2686211
# 826648
# 1369870
# 783246
# 510947
# 288152
# 824671
# 872579
# 472148
# 897853
# 433608
# 741152
# 2905761
# 3548567
# 225157
# 144034
# 706656
# 3347603
# 423449
# 410560
# 767611
# 403179
# 101738
# 587800
# 749943
# 3047659
# 767572
# 851631
# 930442
# 31255
# 397540
# 978622
# 91615
# 62110
# 392152
# 2634351
# 1867983
# 548351
# 790543
# 385547
# 766052
# 3804535
# 3131400
# 723112
# 673440
# 412667
# 706254
# 36456
# 535575
# 528241
# 675051
# 433859
# 2787770
# 903754
# 55635
# 25647
# 255659
# 101439
# 618647
# 256058
# 955548
# 2505460
# 490179
# 986757
# 925037
# 598543
# 601032
# 101037
# 173342
# 145545
# 1436204
# 3832127
# 747051
# 817477
# 239556
# 991078
# 198251
# 86349
# 920975
# 475756
# 1454
# 2631172
# 3650808
# 539340
# 472531
# 2362458
# 1009840
# 2736451
# 3068579
# 298049
# 514356
# 750341
# 464853
# 990053
# 960935
# 1008432
# 67254
# 828174
# 223751
# 911759
# 2694944
# 416245
# 604024
# 3019982
# 31657
# 238737
# 61476
# 632607
# 3614837
# 191355
# 439132
# 642437
# 874845
# 882701
# 609467
# 574976
# 242
# 375502
# 991555
# 2729677
# 133579
# 347022
# 711753
# 3272956
# 3394278
# 176437
# 496845
# 812379
# 2353595
# 481579
# 741648
# 205458
# 943675
# 213912
# 617051
# 764030
# 613978
# 578554
# 808345
# 399973
# 3284397
# 19972
# 809771
# 749242
# 961446
# 867632
# 613156
# 919456
# 524579
# 573335
# 352370
# 442057
# 673244
# 62044
# 546535
# 2328285
# 815147
# 768074
# 2539960
# 609832
# 852713
# 30810
# 885252
# 760340
# 721949
# 259956
# 297051
# 3049635
# 2385514
# 743950
# 593771
# 643274
# 886204
# 254504
# 363648
# 807348
# 120542
# 242949
# 601153
# 715630
# 419460
# 585235
# 955940
# 702911
# 2750
# 962313
# 3607062
# 680813
# 577137
# 197302
# 774132
# 381026
# 855741
# 1006652
# 104234
# 100843
# 534242
# 644776
# 470452
# 7634
# 368933
# 437914
# 478195
# 537560
# 3029589
# 474450
# 97055
# 3561771
# 342362
# 662369
# 3459216
# 5047505
# 261940
# 725741
# 1009756
# 681043
# 3466988
# 527178
# 449935
# 248240
# 626101
# 2732565
# 110972
# 173641
# 696645
# 58225
# 346379
# 917555
# 514066
# 777254
# 2891622
# 850036
# 161602
# 235530
# 475354
# 3075474
# 849432
# 197478
# 622037
# 507509
# 700140
# 917500
# 145741
# 941804
# 373553
# 3715444
# 1008076
# 943273
# 2119773
# 3282012
# 954653
# 39327
# 58757
# 22730
# 165758
# 803265
# 828110
# 951102
# 469737
# 504311
# 1293078
# 3646397
# 165628
# 579140
# 988452
# 17259
# 109574
# 171656
# 596978
# 699253
# 639633
# 45430
# 519146
# 36933
# 327305
# 667252
# 1216321
# 991135
# 3470930
# 455945
# 3410141
# 95677
# 168357
# 956152
# 136655
# 3350658
# 349129
# 406666
# 1007873
# 593007
# 646556
# 66275
# 441359
# 671053
# 631422
# 138257
# 2009605
# 1387203
# 731957
# 3619216
# 446149
# 748964
# 283157
# 326858
# 2880019
# 260055
# 834175
# 985479
# 3357947
# 1008151
# 352651
# 605571
# 237066
# 853952
# 479071
# 764058
# 3637706
# 763211
# 829050
# 90579
# 332671
# 677644
# 475345
# 436159
# 567679
# 223322
# 947776
# 309150
# 869663
# 924937
# 2697963
# 980661
# 18836
# 229454
# 856346
# 988144
# 2963275
# 401951
# 420578
# 554343
# 560353
# 660879
# 412845
# 851060
# 568359
# 11837
# 966973
# 2838207
# 187648
# 156970
# 220527
# 391977
# 59352
# 446176
# 471057
# 572459
# 1836701
# 2483438
# 2667957
# 765354
# 499453
# 320052
# 619859
# 955959
# 270148
# 930965
# 426945
# 382069
# 881852
# 954279
# 293053
# 2693264
# 2858492
# 751254
# 1002878
# 5135
# 958763
# 703552
# 865151
# 328777
# 1412712
# 46053
# 460770
# 613558
# 72258
# 218261
# 257345
# 317650
# 968155
# 2929392
# 355120
# 675341
# 2938198
# 151957
# 3614958
# 3482045
# 3720336
# 144155
# 330949
# 467658
# 2339795
# 3160978
# 1929247
# 185251
# 276074
# 126049
# 922344
# 253468
# 288376
# 618777
# 980438
# 3592047
# 5805424
# 268976
# 1007154
# 3529315
# 139478
# 321273
# 364131
# 369659
# 1017555
# 285740
# 77253
# 648242
# 29878
# 90177
# 657954
# 1447639
# 722777
# 403946
# 177555
# 67870
# 2850768
# 631178
# 518176
# 3303944
# 540056
# 454658
# 710859
# 723756
# 2912750
# 2967796
# 434203
# 667524
# 174572
# 550279
# 842460
# 896155
# 947749
# 822631
# 3357385
# 366359
# 827560
# 899343
# 945071
# 2702764
# 237619
# 574079
# 697950
# 567736
# 656377
# 175140
# 87579
# 133850
# 3807880
# 112556
# 811541
# 3579589
# 412555
# 538222
# 83151
# 244037
# 660271
# 908553
# 2960788
# 3199811
# 283438
# 648130
# 324854
# 919773
# 474919
# 97943
# 956376
# 3271799
# 45047
# 57040
# 945053
# 653947
# 552956
# 334264
# 481944
# 3591004
# 239659
# 2748502
# 771748
# 1190476
# 183958
# 857811
# 754826
# 440978
# 934271
# 177920
# 644057
# 3288452
# 502652
# 839246
# 900502
# 147651
# 1014451
# 273840
# 292234
# 990352
# 119779
# 326054
# 633640
# 342054
# 212344
# 736206
# 29636
# 359472
# 578862
# 675248
# 3398623
# 760957
# 938354
# 961343
# 311845
# 451246
# 441078
# 625056
# 372640
# 584724
# 3546862
# 441470
# 148340
# 989534
# 2687133
# 2736219
# 2882983
# 245276
# 5760662
# 519874
# 956527
# 3185896
# 216230
# 3223408
# 60648
# 480433
# 340135
# 803957
# 751852
# 663834
# 594947
# 35879
# 1007051
# 296755
# 139843
# 137652
# 382274
# 441256
# 853112
# 216164
# 2873598
# 3449066
# 812614
# 2834759
# 502746
# 2132594
# 397858
# 60143
# 175458
# 259330
# 310950
# 625850
# 225054
# 837608
# 922157
# 171133
# 902672
# 1176881
# 3637247
# 590976
# 3125315
# 56717
# 401755
# 2502656
# 866000
# 646145
# 938550
# 23643
# 2502825
# 3146150
# 940852
# 920359
# 2754222
# 455150
# 178851
# 670654
# 911973
# 2745529
# 732178
# 3280625
# 474357
# 823553
# 540850
# 564324
# 805045
# 652959
# 987651
# 840354
# 364270
# 70638
# 3385744
# 553944
# 784430
# 732758
# 577230
# 137447
# 723868
# 563934
# 837158
# 305442
# 300942
# 47500
# 894272
# 964250
# 257756
# 931038
# 441630
# 725077
# 479446
# 248352
# 264455
# 3140822
# 423159
# 3470239
# 2757205
# 829041
# 41629
# 252041
# 678744
# 722227
# 502447
# 548267
# 857745
# 972732
# 3368925
# 533535
# 564678
# 825454
# 372538
# 501105
# 145844
# 398668
# 739346
# 856542
# 63069
# 56351
# 246956
# 278256
# 757377
# 3158546
# 271529
# 11145
# 791821
# 849357
# 918655
# 1002953
# 482370
# 2298995
# 3633016
# 661223
# 684455
# 972862
# 761833
# 685779
# 504713
# 897170
# 651448
# 821157
# 556011
# 2797210
# 591740
# 3402913
# 536527
# 709451
# 2805928
# 3532641
# 196752
# 2760232
# 779968
# 188720
# 2666400
# 942847
# 2941068
# 3274709
# 404943
# 944739
# 813059
# 794345
# 859141
# 822275
# 645540
# 2615190
# 801654
# 812164
# 5398355
# 258771
# 442655
# 940311
# 353957
# 532752
# 540739
# 44433
# 603755
# 136048
# 479754
# 3445901
# 359744
# 363442
# 613679
# 686758
# 227777
# 67142
# 823656
# 101952
# 472018
# 3374412
# 3322468
# 448554
# 815053
# 353555
# 378110
# 1004256
# 2010722
# 180144
# 522605
# 839974
# 5479478
# 909055
# 297761
# 857941
# 879457
# 236256
# 27070
# 502559
# 2734729
# 986159
# 160454
# 604547
# 129349
# 884376
# 210256
# 3317192
# 253646
# 955977
# 376273
# 2958972
# 2860459
# 207452
# 4397164
# 541857
# 2845755
# 176642
# 412153
# 80374
# 400365
# 327855
# 302656
# 639567
# 680457
# 783910
# 956255
# 3022610
# 556459
# 535034
# 924058
# 188430
# 578255
# 827458
# 1918344
# 974754
# 673909
# 856458
# 984258
# 1001152
# 3303953
# 203052
# 488653
# 134156
# 389826
# 693073
# 933966
# 467470
# 298245
# 666974
# 1011526
# 790703
# 764816
# 956750
# 2746245
# 18827
# 5752005
# 465243
# 2358769
# 183770
# 660066
# 648550
# 976534
# 3594087
# 392255
# 869953
# 717737
# 87234
# 350657
# 713252
# 37435
# 709956
# 2823221
# 90328
# 583905
# 367150
# 33839
# 532453
# 855844
# 3267738
# 99376
# 917050
# 342410
# 548771
# 239613
# 905356
# 250476
# 125855
# 37
# 166111
# 418856
# 473266
# 652070
# 417710
# 544951
# 779351
# 1016231
# 2877345
# 45056
# 388744
# 822556
# 529341
# 20053
# 470032
# 14865
# 2774707
# 895448
# 159971
# 31835
# 595430
# 27614
# 371232
# 356239
# 444350
# 311939
# 631150
# 284239
# 2343167
# 666554
# 84046
# 3185579
# 456045
# 2002222
# 456344
# 855143
# 636771
# 277679
# 688556
# 716954
# 3166699
# 445955
# 496434
# 931270
# 142955
# 377663
# 2608754
# 368054
# 629522
# 756343
# 879336
# 3134698
# 2161
# 293352
# 580847
# 203575
# 473501
# 201834
# 3253834
# 41553
# 353238
# 3614846
# 386825
# 32234
# 764142
# 871648
# 318974
# 113740
# 9955
# 211851
# 142179
# 285544
# 2735137
# 2775692
# 599643
# 3404467
# 3472046
# 285553
# 242958
# 995955
# 5805479
# 306056
# 216922
# 625953
# 918918
# 198961
# 3284070
# 3348468
# 324863
# 3465392
# 337340
# 627377
# 1187551
# 678454
# 998844
# 177135
# 77851
# 776547
# 380878
# 324229
# 396057
# 268677
# 636753
# 401559
# 276654
# 625065
# 44040
# 54058
# 961576
# 860352
# 114859
# 3843392
# 3489035
# 3636446
# 170257
# 479567
# 625159
# 809276
# 2614344
# 92706
# 283652
# 2372774
# 2398701
# 2756730
# 584920
# 671147
# 575375
# 991340
# 157379
# 407168
# 780955
# 879550
# 1013744
# 3614976
# 884648
# 427960
# 921039
# 833404
# 3340903
# 492810
# 2849463
# 442244
# 74449
# 416272
# 661474
# 461058
# 478140
# 450753
# 291059
# 3608751
# 144856
# 1456501
# 3290240
# 98463
# 528960
# 631039
# 928056
# 728948
# 975751
# 131436
# 5461
# 55336
# 477844
# 854753
# 2339599
# 2317672
# 501132
# 937834
# 20633
# 311144
# 946274
# 115146
# 230610
# 2826017
# 652874
# 157155
# 173575
# 835770
# 576952
# 921879
# 257233
# 693224
# 820301
# 381932
# 595869
# 448040
# 524971
# 10849
# 194570
# 653134
# 715340
# 548052
# 477303
# 757779
# 2567123
# 957757
# 3150447
# 310978
# 610539
# 53051
# 1176920
# 435059
# 195111
# 2332910
# 371362
# 703039
# 678070
# 404653
# 920210
# 924357
# 651952
# 130345
# 656032
# 675855
# 497039
# 2980209
# 396244
# 753324
# 375043
# 585749
# 694771
# 276953
# 282075
# 833749
# 143662
# 983158
# 818540
# 3343146
# 302133
# 339353
# 410917
# 805755
# 594938
# 3284490
# 243375
# 113030
# 233246
# 308256
# 115575
# 948250
# 48150
# 658924
# 3655933
# 931944
# 533227
# 670748
# 630340
# 1169650
# 132107
# 340443
# 870913
# 988256
# 1216022
# 134848
# 233527
# 508346
# 750127
# 874452
# 375650
# 3356191
# 155759
# 557438
# 411231
# 312356
# 697763
# 675659
# 850456
# 322449
# 2788656
# 972648
# 234739
# 206772
# 969255
# 894834
# 1006157
# 190563
# 652043
# 963002
# 4210227
# 13251
# 842853
# 398837
# 50144
# 676151
# 137915
# 678258
# 3041358
# 564463
# 205346
# 588348
# 139740
# 175056
# 1494914
# 261146
# 906652
# 625654
# 892223
# 759625
# 837354
# 2356091
# 299868
# 3358270
# 121651
# 615851
# 328357
# 277277
# 99442
# 706030
# 256179
# 917630
# 915878
# 3783313
# 814458
# 837000
# 14155
# 325459
# 2785646
# 1864197
# 997557
# 51253
# 57451
# 340742
# 21256
# 2328137
# 523161
# 772754
# 4125778
# 647955
# 2732
# 63201
# 321330
# 3397233
# 3401970
# 529275
# 262741
# 336361
# 296474
# 324256
# 380346
# 443353
# 13457
# 540542
# 545604
# 588245
# 961259
# 787459
# 1006559
# 382443
# 659734
# 496957
# 2132941
# 2745426
# 905673
# 981350
# 623052
# 51459
# 491934
# 354851
# 411651
# 595270
# 150727
# 673477
# 937759
# 984856
# 551016
# 5650923
# 929978
# 339858
# 975555
# 467733
# 61355
# 122153
# 28152
# 85052
# 998648
# 346771
# 188056
# 229801
# 563457
# 804338
# 166531
# 371559
# 487142
# 513854
# 137643
# 2059990
# 78157
# 674849
# 202514
# 977250
# 676049
# 2718596
# 342634
# 393953
# 481748
# 424437
# 968070
# 2434113
# 209362
# 714165
# 952172
# 2917317
# 614313
# 800657
# 931458
# 423739
# 468673
# 250850
# 482446
# 935250
# 1474309
# 193809
# 407506
# 546003
# 767974
# 304762
# 754929
# 2668598
# 806846
# 361055
# 2836306
# 560438
# 293437
# 42448
# 2598396
# 936837
# 2921659
# 979629
# 3102893
# 3317932
# 416656
# 78559
# 701839
# 2594240
# 662949
# 247140
# 872047
# 178356
# 370721
# 774253
# 2775179
# 258306
# 639857
# 824653
# 5787418
# 842376
# 2696180
# 501459
# 340751
# 2847085
# 963730
# 74140
# 895710
# 775241
# 488318
# 827355
# 671464
# 589523
# 841753
# 873259
# 913753
# 230759
# 1000959
# 485559
# 933023
# 799751
# 226949
# 276159
# 385686
# 422657
# 287959
# 106676
# 463735
# 60330
# 628356
# 96553
# 933340
# 1007015
# 1225752
# 308340
# 63573
# 517674
# 766164
# 2123930
# 670560
# 679451
# 262956
# 2819167
# 3039636
# 132451
# 457752
# 876700
# 121914
# 71457
# 433943
# 441050
# 485214
# 696168
# 734613
# 5620869
# 188739
# 657758
# 599764
# 613950
# 5574430
# 635840
# 565170
# 76443
# 3370133
# 598002
# 3337097
# 9357
# 845247
# 825146
# 363657
# 320070
# 3636259
# 355858
# 703767
# 713476
# 481159
# 851239
# 934673
# 851172
# 3034695
# 3407084
# 451273
# 2621285
# 134455
# 816751
# 2907019
# 391959
# 572374
# 3346268
# 705378
# 2808602
# 144678
# 623454
# 809650
# 43959
# 977951
# 354
# 386731
# 796572
# 151546
# 184759
# 390372
# 804374
# 898850
# 673851
# 777441
# 8631
# 865852
# 3316739
# 648345
# 210238
# 199137
# 208972
# 2839790
# 5336928
# 3303298
# 232856
# 208440
# 210434
# 588478
# 75651
# 1396764
# 40033
# 291376
# 464255
# 48057
# 291330
# 979759
# 3729124
# 725732
# 108072
# 319551
# 875936
# 466044
# 840747
# 2667920
# 556815
# 944355
# 656470
# 559179
# 192558
# 255574
# 900379
# 936640
# 269049
# 329550
# 736158
# 361439
# 436542
# 466932
# 3386536
# 510871
# 662350
# 199463
# 859712
# 265676
# 368522
# 983550
# 204826
# 198073
# 235446
# 218850
# 430344
# 106359
# 709143
# 795249
# 246657
# 2531991
# 882242
# 525053
# 2769570
# 271136
# 846132
# 972143
# 56548
# 58971
# 854847
# 694904
# 899651
# 600419
# 613343
# 698144
# 779650
# 3221468
# 34537
# 301800
# 483751
# 691556
# 838155
# 928421
# 52719
# 207041
# 1008955
# 908450
# 967952
# 3690701
# 2163477
# 697147
# 615879
# 726953
# 853747
# 2142155
# 3603961
# 251352
# 215653
# 481177
# 393252
# 92676
# 830355
# 820048
# 1012251
# 1000276
# 2576134
# 303952
# 884657
# 498625
# 3386264
# 70218
# 84541
# 194936
# 212577
# 605656
# 721350
# 887827
# 2723376
# 476472
# 170332
# 984454
# 1001648
# 3224302
# 3390627
# 711548
# 371942
# 110936
# 374774
# 132778
# 610557
# 458946
# 852973
# 3482111
# 693952
# 771609
# 254317
# 715144
# 2793593
# 3593307
# 293754
# 1017939
# 2997216
# 102874
# 884358
# 3437483
# 1017957
# 571265
# 386432
# 866121
# 5143788
# 388155
# 646042
# 2849285
# 935308
# 3276543
# 69678
# 130541
# 696047
# 2794732
# 126375
# 249658
# 852704
# 279105
# 2562164
# 2920287
# 403656
# 1394621
# 30502
# 425050
# 500256
# 3314119
# 890957
# 292467
# 307062
# 995571
# 798512
# 2371816
# 341310
# 449038
# 550354
# 683449
# 647759
# 632858
# 738255
# 871358
# 945950
# 583754
# 983457
# 3393851
# 204004
# 388753
# 273550
# 701222
# 111942
# 933377
# 251745
# 45551
# 610128
# 372855
# 547550
# 615217
# 58551
# 746755
# 758703
# 800442
# 856159
# 910118
# 947525
# 290249
# 1479470
# 1885932
# 3027763
# 45560
# 93619
# 617145
# 213538
# 835444
# 144052
# 499855
# 505916
# 47247
# 791942
# 2625724
# 3547896
# 153054
# 236603
# 241559
# 698546
# 3109043
# 879644
# 265452
# 380944
# 65858
# 623874
# 691743
# 980773
# 3835454
# 385350
# 2618780
# 193162
# 77422
# 287007
# 565536
# 645465
# 883959
# 601050
# 3626858
# 595337
# 11640
# 712956
# 890050
# 3404999
# 209148
# 949453
# 956938
# 814430
# 2769954
# 459372
# 3219269
# 3479018
# 855264
# 382658
# 702359
# 474544
# 2568063
# 348159
# 285348
# 270353
# 223845
# 699105
# 948278
# 222156
# 3243282
# 304173
# 312244
# 317379
# 455972
# 265340
# 211271
# 400141
# 2917184
# 1003558
# 394156
# 3678857
# 576644
# 843953
# 293651
# 639549
# 658072
# 917854
# 917742
# 480853
# 935577
# 841838
# 3596894
# 3688043
# 3148613
# 983055
# 715975
# 458142
# 83852
# 3220863
# 590640
# 245557
# 268006
# 410748
# 2889227
# 108746
# 108951
# 5561001
# 645157
# 1013650
# 1013070
# 4165907
# 65513
# 548829
# 411240
# 617275
# 161273
# 628039
# 807955
# 728957
# 4032791
# 159645
# 5227101
# 117038
# 418249
# 764067
# 68756
# 589943
# 3141726
# 107244
# 417626
# 944935
# 593249
# 452841
# 466754
# 964157
# 524757
# 979133
# 819453
# 431323
# 570651
# 3297490
# 860231
# 945026
# 816603
# 347639
# 3306280
# 627108
# 272272
# 288853
# 465038
# 536059
# 553926
# 2605566
# 638355
# 922924
# 836843
# 411624
# 412751
# 937339
# 289056
# 819154
# 831576
# 5397639
# 460332
# 480723
# 246022
# 855956
# 671334
# 2239288
# 520777
# 762773
# 21359
# 230423
# 266066
# 474759
# 797775
# 9553
# 884303
# 956358
# 1469677
# 890649
# 683814
# 943143
# 978118
# 969956
# 294023
# 150035
# 152440
# 143372
# 720746
# 729057
# 939070
# 881012
# 977045
# 1014246
# 54656
# 354310
# 709602
# 2233875
# 801056
# 373272
# 302553
# 767554
# 774347
# 2811086
# 80431
# 324153
# 658474
# 513920
# 668147
# 691958
# 923257
# 88231
# 760434
# 3821626
# 640956
# 698649
# 2947556
# 478533
# 483274
# 899008
# 942454
# 3216017
# 362856
# 490843
# 645577
# 717670
# 2938769
# 380458
# 109659
# 447070
# 543262
# 593052
# 975854
# 412872
# 499154
# 114260
# 2737980
# 520423
# 900146
# 3194692
# 66677
# 268828
# 489249
# 296858
# 422433
# 550653
# 617743
# 17147
# 705556
# 948036
# 5278251
# 398248
# 28675
# 371223
# 640442
# 376237
# 710176
# 2607412
# 2973041
# 3348888
# 563336
# 105473
# 642549
# 271275
# 2867337
# 3045383
# 1160509
# 313223
# 682648
# 927077
# 770657
# 136338
# 3475083
# 853804
# 741844
# 407850
# 689209
# 988153
# 2615220
# 112163
# 259059
# 831008
# 821036
# 2624400
# 746979
# 636276
# 971959
# 575254
# 2919898
# 5760439
# 3446784
# 564977
# 257578
# 937740
# 1012671
# 3943210
# 3029253
# 743679
# 560214
# 3390337
# 367178
# 3555248
# 190648
# 656779
# 2806635
# 3537897
# 97804
# 419406
# 450669
# 381950
# 765318
# 981275
# 459644
# 195456
# 244251
# 575759
# 613008
# 629353
# 202541
# 792659
# 331544
# 95051
# 818401
# 575834
# 865544
# 975256
# 938859
# 987576
# 71073
# 362155
# 3667132
# 2304636
# 197142
# 213471
# 455552
# 880332
# 433505
# 1418255
# 1188987
# 730745
# 716833
# 754536
# 388874
# 864855
# 3394380
# 3488579
# 3626184
# 671558
# 735973
# 887340
# 134437
# 158376
# 644963
# 562058
# 275358
# 148238
# 2948423
# 2845782
# 29476
# 114457
# 839255
# 734350
# 2736291
# 148171
# 995076
# 1000052
# 3125557
# 139656
# 901938
# 5788705
# 55653
# 416674
# 643078
# 27847
# 663638
# 792640
# 995272
# 48374
# 869551
# 379050
# 164377
# 761543
# 659640
# 661308
# 236153
# 925653
# 535940
# 571920
# 929352
# 235231
# 966272
# 563233
# 2939391
# 893855
# 156457
# 901134
# 517357
# 629148
# 3017081
# 336576
# 583268
# 199436
# 837046
# 435750
# 664206
# 868059
# 384278
# 510938
# 16551
# 5755510
# 664653
# 646172
# 75455
# 674344
# 578237
# 491653
# 227357
# 860259
# 736550
# 542667
# 5303724
# 70414
# 894544
# 539377
# 303653
# 653611
# 425911
# 304575
# 719656
# 733540
# 971070
# 489623
# 3174920
# 950178
# 266851
# 100236
# 790918
# 128904
# 857259
# 592644
# 2943615
# 3404373
# 196800
# 914648
# 923350
# 327220
# 80150
# 238139
# 208057
# 773247
# 3217331
# 436739
# 319458
# 977616
# 1017425
# 40499
# 687951
# 706058
# 875758
# 935559
# 3480069
# 943853
# 837840
# 3076604
# 1007819
# 3470097
# 300960
# 3282692
# 169756
# 541101
# 657178
# 897330
# 2587916
# 3451050
# 410159
# 3212402
# 79127
# 446130
# 952846
# 582654
# 738657
# 5673191
# 645317
# 321255
# 3429219
# 796152
# 816304
# 368951
# 118660
# 775456
# 769156
# 102557
# 298218
# 157650
# 330855
# 547840
# 911160
# 85472
# 1718469
# 454676
# 5313312
# 3458
# 397456
# 787842
# 630658
# 73152
# 366854
# 811550
# 826956
# 894348
# 97279
# 982142
# 465524
# 3793714
# 862141
# 343770
# 721752
# 899428
# 403067
# 628552
# 262059
# 172457
# 74056
# 391418
# 3184228
# 484776
# 5230790
# 3690121
# 89957
# 2006024
# 731050
# 722816
# 385471
# 799854
# 48440
# 3374403
# 3404207
# 294751
# 493741
# 503640
# 105530
# 586335
# 914853
# 837541
# 49858
# 3821822
# 2925620
# 514936
# 277820
# 769334
# 804422
# 586960
# 176325
# 924254
# 800479
# 688257
# 388258
# 2883971
# 320034
# 395238
# 468806
# 3034257
# 1890525
# 3223417
# 5692473
# 3247589
# 27548
# 248745
# 207555
# 208655
# 885579
# 1007930
# 843476
# 1162017
# 3354599
# 638850
# 732253
# 2329200
# 272030
# 443148
# 640246
# 647414
# 184656
# 99853
# 2973386
# 1005655
# 825940
# 125873
# 989141
# 881441
# 111205
# 455459
# 1005075
# 953535
# 3228908
# 504142
# 773470
# 1157415
# 3971
# 452159
# 540775
# 697035
# 3368635
# 5686089
# 88455
# 621245
# 738303
# 3232204
# 825548
# 733951
# 234506
# 279842
# 568939
# 926632
# 739560
# 2954497
# 58636
# 3232370
# 790150
# 3629484
# 3384952
# 455253
# 576578
# 157856
# 931047
# 1893049
# 2515320
# 920854
# 192147
# 881478
# 763930
# 811046
# 779641
# 2797724
# 160959
# 933256
# 2654911
# 366238
# 426141
# 7072
# 64730
# 714437
# 3357620
# 846945
# 3066025
# 2490285
# 996260
# 953843
# 3076220
# 119153
# 413141
# 3293540
# 3408728
# 75633
# 651859
# 720344
# 45775
# 190947
# 7045
# 456054
# 460350
# 473257
# 882541
# 891253
# 3517590
# 87476
# 831642
# 854173
# 1004470
# 246134
# 345747
# 99143
# 348720
# 722432
# 940674
# 954671
# 361354
# 916343
# 2297998
# 454546
# 592439
# 918477
# 913436
# 2122997
# 290838
# 1011955
# 3120646
# 110945
# 2775151
# 225559
# 868572
# 59370
# 2954059
# 3314043
# 755421
# 602543
# 465618
# 112510
# 279
# 614751
# 694847
# 734538
# 801047
# 837952
# 542153
# 897648
# 733661
# 536853
# 602048
# 529958
# 205243
# 853934
# 888141
# 266655
# 2467670
# 397531
# 913146
# 5860740
# 979357
# 542340
# 249416
# 2963864
# 146663
# 500658
# 178150
# 590220
# 618740
# 413347
# 362940
# 368344
# 890742
# 370954
# 537551
# 977652
# 408642
# 388557
# 992851
# 2396592
# 5435988
# 153353
# 428855
# 640143
# 967046
# 137559
# 223452
# 692704
# 472951
# 596156
# 258874
# 399731
# 206473
# 42372
# 313157
# 344647
# 849348
# 814355
# 12142
# 186548
# 241157
# 539452
# 3635551
# 262844
# 709554
# 510648
# 615954
# 3032833
# 3594005
# 900034
# 670467
# 104542
# 79257
# 943974
# 537243
# 3671997
# 266253
# 9807
# 469559
# 871956
# 961811
# 628123
# 729178
# 2505424
# 2600039
# 358448
# 3636914
# 2305969
# 522669
# 2396604
# 49652
# 272151
# 771878
# 335346
# 253356
# 3489071
# 88352
# 726458
# 441135
# 3664588
# 2869162
# 680130
# 823076
# 248633
# 732918
# 968249
# 514057
# 852320
# 857455
# 918879
# 2121196
# 3720
# 786210
# 12030
# 807656
# 376442
# 943152
# 365745
# 278872
# 300063
# 954158
# 72454
# 844567
# 2871099
# 403254
# 379153
# 354253
# 218131
# 823142
# 120609
# 273653
# 1669
# 543459
# 844053
# 330248
# 458665
# 812557
# 751656
# 685649
# 533124
# 480228
# 426534
# 64552
# 625757
# 741330
# 150044
# 1629903
# 481430
# 784159
# 488420
# 443634
# 460275
# 665258
# 241009
# 748357
# 530655
# 732637
# 752831
# 762447
# 3548763
# 1222519
# 188177
# 2925666
# 322551
# 795959
# 929932
# 3005097
# 219651
# 409265
# 345345
# 530851
# 672238
# 17950

# %%
result_df = pd.DataFrame(columns=df['mdrm'].unique())

# Iterate through each row in the original DataFrame
for index, row in df.iterrows():
    mdrm = row['mdrm']
    data_type = row['data_type']

    # Depending on the 'data_type', select the corresponding value
    if data_type == 'str':
        value = row['str_data']
    elif data_type == 'bool':
        value = row['bool_data']
    elif data_type == 'float':
        value = row['float_data']
    elif data_type == 'int':
        value = row['int_data']
    else:
        value = None

    # Set the value in the result DataFrame
    result_df.at[0, mdrm] = value

# Transpose the result DataFrame to have one row and 583 columns
#result_df = result_df.T

# Reset the index and rename columns
#result_df = result_df.reset_index()
#result_df.columns = ['mdrm', 0]

# Display the resulting DataFrame
print(result_df)

# %%
datetime.datetime(9999,12,31)
# Out:
# datetime.datetime(9999, 12, 31, 0, 0)

# %%
not_mnemonic= ['TEXT', 'TE01', 'TE02', 'TE03','TE04','TE05','TE06','TE07','TE08','TE09','TE10','TE11','TE12']
in_report = ['FFIEC 031', 'FFIEC041','FFIEC 051']

# %%
mdrm_csv = pd.read_csv("C:\\Users\\whill\\call-report-database\\MDRM_CSV.csv", skiprows=1)
mdrm_csv.insert(2, 'mdrm_code', mdrm_csv['Mnemonic'] + mdrm_csv['Item Code'])
mdrm_csv
# Out:
#       Mnemonic Item Code mdrm_code      Start Date         End Date  \
# 0         AAAA      2170  AAAA2170  9/30/2016 0:00  12/31/9999 0:00
# 1         AAAA      5310  AAAA5310  3/31/2014 0:00  12/31/9999 0:00
# 2         AAAA      7205  AAAA7205  3/31/2014 0:00  12/31/9999 0:00
# 3         AAAA      7206  AAAA7206  3/31/2014 0:00  12/31/9999 0:00
# 4         AAAA      8274  AAAA8274  9/30/2016 0:00  12/31/9999 0:00
# ...        ...       ...       ...             ...              ...
# 88145     XMTA      9191  XMTA9191   2/1/2010 0:00  12/31/9999 0:00
# 88146     XMTA      9200  XMTA9200   5/4/2015 0:00  12/31/9999 0:00
# 88147     XMTA      9220  XMTA9220   5/4/2015 0:00  12/31/9999 0:00
# 88148     XMTA      9912  XMTA9912   5/4/2015 0:00  12/31/9999 0:00
# 88149     XMTA      9999  XMTA9999   5/4/2015 0:00  12/31/9999 0:00
#
#                                                Item Name Confidentiality  \
# 0                                           TOTAL ASSETS               N
# 1            GENERAL LOAN AND LEASE VALUATION ALLOWANCES               N
# 2                         TOTAL RISK-BASED CAPITAL RATIO               N
# 3                        TIER 1 RISK-BASED CAPITAL RATIO               N
# 4      TIER 1 CAPITAL ALLOWABLE UNDER THE RISK-BASED ...               N
# ...                                                  ...             ...
# 88145                                PROCESSING DISTRICT               Y
# 88146                             ABBREVIATED STATE NAME               Y
# 88147                  PHYSICAL ZIP/FOREIGN MAILING CODE               Y
# 88148                                       DATE OF LOAN               Y
# 88149                       REPORTING DATE (CC;YR;MO;DA)               Y
#
#       ItemType Reporting Form  \
# 0            F      FFIEC 101
# 1            F      FFIEC 101
# 2            P      FFIEC 101
# 3            P      FFIEC 101
# 4            F      FFIEC 101
# ...        ...            ...
# 88145        S     FR 2028a/s
# 88146        F     FR 2028a/s
# 88147        F     FR 2028a/s
# 88148        F     FR 2028a/s
# 88149        F     FR 2028a/s
#
#                                              Description  \
# 0      The sum of all asset items. This item must equ...
# 1       Includes general loan and lease valuation all...
# 2      This ratio includes total risk-based capital d...
# 3      This ratio includes Tier 1 (core) capital; les...
# 4       Includes the amount of Tier 1 capital less de...
# ...                                                  ...
# 88145  Effective 10/24/2011; the FR 2572 information ...
# 88146  Two character state abbreviation as assigned t...
# 88147  The zip code or foreign mailing code of the ph...
# 88148  Includes the calendar date the funds reported ...
# 88149  Effective 10/24/2011; the FR 2572 information ...
#
#                                           SeriesGlossary
# 0                 Advanced Approaches Regulatory Capital
# 1                 Advanced Approaches Regulatory Capital
# 2                 Advanced Approaches Regulatory Capital
# 3                 Advanced Approaches Regulatory Capital
# 4                 Advanced Approaches Regulatory Capital
# ...                                                  ...
# 88145   NOTE: \r\n\r\nThe mnemonic prefixes in this f...
# 88146   NOTE: \r\n\r\nThe mnemonic prefixes in this f...
# 88147   NOTE: \r\n\r\nThe mnemonic prefixes in this f...
# 88148   NOTE: \r\n\r\nThe mnemonic prefixes in this f...
# 88149   NOTE: \r\n\r\nThe mnemonic prefixes in this f...
#
# [88150 rows x 11 columns]

# %%
mdrm_filtered = mdrm_csv[(mdrm_csv['Reporting Form'].isin(in_report)) & (~mdrm_csv['Mnemonic'].isin(not_mnemonic))]
mdrm_filtered.rename(columns={"Reporting Form": "form_type"},inplace=True)
mdrm_filtered
# Out:
# C:\Users\whill\AppData\Local\Temp\ipykernel_3188\2873219326.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mdrm_filtered.rename(columns={"Reporting Form": "form_type"},inplace=True)
#       Mnemonic Item Code mdrm_code       Start Date         End Date  \
# 10710     CALL      8002  CALL8002   3/31/1984 0:00   3/31/2006 0:00
# 10714     CALL      8786  CALL8786   3/31/1984 0:00  12/31/9999 0:00
# 10716     CALL      8787  CALL8787  12/31/1959 0:00  12/31/9999 0:00
# 10717     CALL      8798  CALL8798  12/31/1959 0:00  12/31/9999 0:00
# 10718     CALL      8799  CALL8799  12/31/1959 0:00  12/31/2000 0:00
# ...        ...       ...       ...              ...              ...
# 69998     RSSD      9130  RSSD9130   3/31/2017 0:00  12/31/9999 0:00
# 70063     RSSD      9200  RSSD9200   9/30/2005 0:00  12/31/9999 0:00
# 70065     RSSD      9200  RSSD9200   3/31/2017 0:00  12/31/9999 0:00
# 70084     RSSD      9220  RSSD9220   9/30/2005 0:00  12/31/9999 0:00
# 70086     RSSD      9220  RSSD9220   3/31/2017 0:00  12/31/9999 0:00
#
#                                Item Name Confidentiality ItemType  form_type  \
# 10710          REPORTING STATUS (W-CODE)               N        F  FFIEC 031
# 10714               REPORTING LEVEL CODE               N        S  FFIEC 031
# 10716           REPORTING EXCEPTION CODE               N        F  FFIEC 031
# 10717                     FDR TIME STAMP               Y        F  FFIEC 031
# 10718                ARCHIVAL DATE STAMP               Y        F  FFIEC 031
# ...                                  ...             ...      ...        ...
# 69998                CITY/TOWN TEXT NAME               N        S  FFIEC 051
# 70063             ABBREVIATED STATE NAME               N        S  FFIEC 031
# 70065             ABBREVIATED STATE NAME               N        S  FFIEC 051
# 70084  PHYSICAL ZIP/FOREIGN MAILING CODE               N        S  FFIEC 031
# 70086  PHYSICAL ZIP/FOREIGN MAILING CODE               N        S  FFIEC 051
#
#                                              Description  \
# 10710  This item is an asset threshold used to determ...
# 10714  Effective 10/24/2011; the FR 2572 information ...
# 10716  Effective 10/24/2011; the FR 2572 information ...
# 10717  Effective 10/24/2011; the FR 2572 information ...
# 10718  The date (ccyymmdd) the data were last updated...
# ...                                                  ...
# 69998  The name of the city or town in which the enti...
# 70063  Two character state abbreviation as assigned t...
# 70065  Two character state abbreviation as assigned t...
# 70084  The zip code or foreign mailing code of the ph...
# 70086  The zip code or foreign mailing code of the ph...
#
#                                           SeriesGlossary
# 10710  \r\nThe following items may be accessed by the...
# 10714  \r\nThe following items may be accessed by the...
# 10716  \r\nThe following items may be accessed by the...
# 10717  \r\nThe following items may be accessed by the...
# 10718  \r\nThe following items may be accessed by the...
# ...                                                  ...
# 69998
# 70063
# 70065
# 70084
# 70086
#
# [6062 rows x 11 columns]

# %%
df1 = extract_taxonomy_data(pd.read_json("C:\\Users\\whill\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\example\\031_2023-09-30.json"),'FFIEC 031')
df2 = extract_taxonomy_data(pd.read_json("C:\\Users\\whill\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\example\\041_2023-09-30.json"),'FFIEC 041')
df3 = extract_taxonomy_data(pd.read_json("C:\\Users\\whill\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\example\\051_2023-09-30.json"),'FFIEC 051')
merged_df = pd.concat([df1,df2,df3]).reset_index(drop=True)
df1 = extract_taxonomy_data(pd.read_json("C:\\Users\\whill\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\example\\031_2001-03-31.json"),'FFIEC 031')
df2 = extract_taxonomy_data(pd.read_json("C:\\Users\\whill\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\example\\041_2001-03-31.json"),'FFIEC 041')
older_df = pd.concat([df1,df2]).reset_index(drop=True)
df_2000_2023 = pd.concat([merged_df,older_df]).reset_index(drop=True)
df_2000_2023.drop_duplicates(subset=['mdrm_code', 'form_type'],keep='first',inplace=True,ignore_index=True)
rows_to_drop = np.where(df_2000_2023['mdrm_code'].str.contains('TE', regex=True))
df_2000_2023.drop(index=rows_to_drop[0],inplace =True)
result_df = mdrm_filtered.join(df_2000_2023.set_index(['mdrm_code', 'form_type']), on=['mdrm_code','form_type'],how='left')
#result_df[~result_df['schedule_type'].isnull()]
master_data_type_list = match_data_type(id_rssd_set,set(result_df['mdrm_code']))
datatype_df = pd.DataFrame(master_data_type_list,columns=['mdrm_code', 'data_type'])
final_df = result_df.join(datatype_df.set_index(['mdrm_code']), on=['mdrm_code'],how='left')
final_df

# %% [markdown]
# # code merged together and written above

# %%
final_df = pd.read_csv("C:\\Users\\whill\\call-report-database\\MDRM_CSV_Filtered_Schedules_Data_Types.csv")
final_df
# Out:
#      Mnemonic Item Code mdrm_code       Start Date         End Date  \
# 0        CALL      8002  CALL8002   3/31/1984 0:00   3/31/2006 0:00
# 1        CALL      8786  CALL8786   3/31/1984 0:00  12/31/9999 0:00
# 2        CALL      8787  CALL8787  12/31/1959 0:00  12/31/9999 0:00
# 3        CALL      8798  CALL8798  12/31/1959 0:00  12/31/9999 0:00
# 4        CALL      8799  CALL8799  12/31/1959 0:00  12/31/2000 0:00
# ...       ...       ...       ...              ...              ...
# 6057     RSSD      9130  RSSD9130   3/31/2017 0:00  12/31/9999 0:00
# 6058     RSSD      9200  RSSD9200   9/30/2005 0:00  12/31/9999 0:00
# 6059     RSSD      9200  RSSD9200   3/31/2017 0:00  12/31/9999 0:00
# 6060     RSSD      9220  RSSD9220   9/30/2005 0:00  12/31/9999 0:00
# 6061     RSSD      9220  RSSD9220   3/31/2017 0:00  12/31/9999 0:00
#
#                               Item Name Confidentiality ItemType  form_type  \
# 0             REPORTING STATUS (W-CODE)               N        F  FFIEC 031
# 1                  REPORTING LEVEL CODE               N        S  FFIEC 031
# 2              REPORTING EXCEPTION CODE               N        F  FFIEC 031
# 3                        FDR TIME STAMP               Y        F  FFIEC 031
# 4                   ARCHIVAL DATE STAMP               Y        F  FFIEC 031
# ...                                 ...             ...      ...        ...
# 6057                CITY/TOWN TEXT NAME               N        S  FFIEC 051
# 6058             ABBREVIATED STATE NAME               N        S  FFIEC 031
# 6059             ABBREVIATED STATE NAME               N        S  FFIEC 051
# 6060  PHYSICAL ZIP/FOREIGN MAILING CODE               N        S  FFIEC 031
# 6061  PHYSICAL ZIP/FOREIGN MAILING CODE               N        S  FFIEC 051
#
#                                             Description  \
# 0     This item is an asset threshold used to determ...
# 1     Effective 10/24/2011; the FR 2572 information ...
# 2     Effective 10/24/2011; the FR 2572 information ...
# 3     Effective 10/24/2011; the FR 2572 information ...
# 4     The date (ccyymmdd) the data were last updated...
# ...                                                 ...
# 6057  The name of the city or town in which the enti...
# 6058  Two character state abbreviation as assigned t...
# 6059  Two character state abbreviation as assigned t...
# 6060  The zip code or foreign mailing code of the ph...
# 6061  The zip code or foreign mailing code of the ph...
#
#                                          SeriesGlossary schedule_type  \
# 0     \r\nThe following items may be accessed by the...           NaN
# 1     \r\nThe following items may be accessed by the...           NaN
# 2     \r\nThe following items may be accessed by the...           NaN
# 3     \r\nThe following items may be accessed by the...           NaN
# 4     \r\nThe following items may be accessed by the...           NaN
# ...                                                 ...           ...
# 6057                                                              ENT
# 6058                                                              ENT
# 6059                                                              ENT
# 6060                                                              ENT
# 6061                                                              ENT
#
#                                      schedule_label          mdrm_label  \
# 0                                               NaN                 NaN
# 1                                               NaN                 NaN
# 2                                               NaN                 NaN
# 3                                               NaN                 NaN
# 4                                               NaN                 NaN
# ...                                             ...                 ...
# 6057  Bank Demographic Information(Form Type - 051)                City
# 6058  Bank Demographic Information(Form Type - 031)  State abbreviation
# 6059  Bank Demographic Information(Form Type - 051)  State abbreviation
# 6060  Bank Demographic Information(Form Type - 031)            Zip code
# 6061  Bank Demographic Information(Form Type - 051)            Zip code
#
#      data_type
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 6057       str
# 6058       str
# 6059       str
# 6060       str
# 6061       str
#
# [6062 rows x 15 columns]

# %% [markdown]
# ## lets define the last of our data types based on the item types provided for us R- rate stored as a decimal so obviously we need float, for easy we are going to define D and R as float, I went and checked the 443 remaining blank for D and checked that they would be mostly numerical. Then we will set everything to str for remain F and S codes, finally we will set the last schedule as undefined!

# %%
final_df.loc[(final_df['data_type'].isnull()) & ((final_df['ItemType']=='D') | (final_df['ItemType']=='R')), 'data_type']='float'
final_df.loc[(final_df['data_type'].isnull()) & ((final_df['ItemType']=='F') | (final_df['ItemType']=='S')), 'data_type']='str'
final_df.loc[final_df['schedule_type'].isnull(),'schedule_type']='Undefined'

# %%
schedule_dict_list = {sd['mdrm_code']: sd['data_type'] for sd in final_df.loc[final_df['schedule_type'].isin(['ENT']), ['mdrm_code', 'data_type']].to_dict(orient='records')}
bank_id = 'IDRSSD'
bank_id_data_type = 'VARCHAR'
report_date = 'RCON9999'
report_date_data_type= 'DATE'
for key,item in schedule_dict_list.items():
    if item == 'str':
        schedule_dict_list[key] = 'VARCHAR'
    elif item in ['float','int']:
        schedule_dict_list[key] = 'NUMBER'
    elif item == 'bool':
        schedule_dict_list[key] = 'BOOLEAN'   
if bank_id in schedule_dict_list:
    my_dict[bank_id] = bank_id_data_type
else:
    schedule_dict_list[bank_id] = bank_id_data_type
if report_date in schedule_dict_list:
    schedule_dict_list[report_date] = report_date_data_type
else:
    schedule_dict_list[report_date] = report_date_data_type
schedule_dict_list
# Out:
# {'RCON9224': 'VARCHAR',
#  'RCON9999': 'DATE',
#  'RSSD9017': 'VARCHAR',
#  'RSSD9130': 'VARCHAR',
#  'RSSD9200': 'VARCHAR',
#  'RSSD9220': 'VARCHAR',
#  'IDRSSD': 'VARCHAR'}

# %%
create_table_query('Schedule ENT', schedule_dict_list)
# Out:
# 'CREATE TABLE Schedule ENT (RCON9224 VARCHAR, RCON9999 DATE, RSSD9017 VARCHAR, RSSD9130 VARCHAR, RSSD9200 VARCHAR, RSSD9220 VARCHAR, IDRSSD VARCHAR), primary key (IDRSSD, RCON9999));'

# %%
start_list = [('IDRSSD','VARCHAR'), ('RCON9999','DATE')]
start_list.extend(final_df['mdrm_code'][final_df['schedule_type'].isin(['ENT'])].to_list())
columns_set = set(start_list)
columns_set
# Out:
#      Mnemonic Item Code mdrm_code       Start Date         End Date  \
# 0        CALL      8002  CALL8002   3/31/1984 0:00   3/31/2006 0:00
# 1        CALL      8786  CALL8786   3/31/1984 0:00  12/31/9999 0:00
# 2        CALL      8787  CALL8787  12/31/1959 0:00  12/31/9999 0:00
# 3        CALL      8798  CALL8798  12/31/1959 0:00  12/31/9999 0:00
# 4        CALL      8799  CALL8799  12/31/1959 0:00  12/31/2000 0:00
# ...       ...       ...       ...              ...              ...
# 6057     RSSD      9130  RSSD9130   3/31/2017 0:00  12/31/9999 0:00
# 6058     RSSD      9200  RSSD9200   9/30/2005 0:00  12/31/9999 0:00
# 6059     RSSD      9200  RSSD9200   3/31/2017 0:00  12/31/9999 0:00
# 6060     RSSD      9220  RSSD9220   9/30/2005 0:00  12/31/9999 0:00
# 6061     RSSD      9220  RSSD9220   3/31/2017 0:00  12/31/9999 0:00
#
#                               Item Name Confidentiality ItemType  form_type  \
# 0             REPORTING STATUS (W-CODE)               N        F  FFIEC 031
# 1                  REPORTING LEVEL CODE               N        S  FFIEC 031
# 2              REPORTING EXCEPTION CODE               N        F  FFIEC 031
# 3                        FDR TIME STAMP               Y        F  FFIEC 031
# 4                   ARCHIVAL DATE STAMP               Y        F  FFIEC 031
# ...                                 ...             ...      ...        ...
# 6057                CITY/TOWN TEXT NAME               N        S  FFIEC 051
# 6058             ABBREVIATED STATE NAME               N        S  FFIEC 031
# 6059             ABBREVIATED STATE NAME               N        S  FFIEC 051
# 6060  PHYSICAL ZIP/FOREIGN MAILING CODE               N        S  FFIEC 031
# 6061  PHYSICAL ZIP/FOREIGN MAILING CODE               N        S  FFIEC 051
#
#                                             Description  \
# 0     This item is an asset threshold used to determ...
# 1     Effective 10/24/2011; the FR 2572 information ...
# 2     Effective 10/24/2011; the FR 2572 information ...
# 3     Effective 10/24/2011; the FR 2572 information ...
# 4     The date (ccyymmdd) the data were last updated...
# ...                                                 ...
# 6057  The name of the city or town in which the enti...
# 6058  Two character state abbreviation as assigned t...
# 6059  Two character state abbreviation as assigned t...
# 6060  The zip code or foreign mailing code of the ph...
# 6061  The zip code or foreign mailing code of the ph...
#
#                                          SeriesGlossary schedule_type  \
# 0     \r\nThe following items may be accessed by the...     Undefined
# 1     \r\nThe following items may be accessed by the...     Undefined
# 2     \r\nThe following items may be accessed by the...     Undefined
# 3     \r\nThe following items may be accessed by the...     Undefined
# 4     \r\nThe following items may be accessed by the...     Undefined
# ...                                                 ...           ...
# 6057                                                              ENT
# 6058                                                              ENT
# 6059                                                              ENT
# 6060                                                              ENT
# 6061                                                              ENT
#
#                                      schedule_label          mdrm_label  \
# 0                                               NaN                 NaN
# 1                                               NaN                 NaN
# 2                                               NaN                 NaN
# 3                                               NaN                 NaN
# 4                                               NaN                 NaN
# ...                                             ...                 ...
# 6057  Bank Demographic Information(Form Type - 051)                City
# 6058  Bank Demographic Information(Form Type - 031)  State abbreviation
# 6059  Bank Demographic Information(Form Type - 051)  State abbreviation
# 6060  Bank Demographic Information(Form Type - 031)            Zip code
# 6061  Bank Demographic Information(Form Type - 051)            Zip code
#
#      data_type
# 0          str
# 1          str
# 2          str
# 3          str
# 4          str
# ...        ...
# 6057       str
# 6058       str
# 6059       str
# 6060       str
# 6061       str
#
# [6062 rows x 15 columns]

# %% [markdown]
# # break

# %%
df1 = extract_taxonomy_data(pd.read_json("C:\\Users\\whill\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\example\\031_2023-09-30.json"),'FFIEC 031')
df2 = extract_taxonomy_data(pd.read_json("C:\\Users\\whill\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\example\\041_2023-09-30.json"),'FFIEC 041')
df3 = extract_taxonomy_data(pd.read_json("C:\\Users\\whill\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\example\\051_2023-09-30.json"),'FFIEC 051')
merged_df = pd.concat([df1,df2,df3]).reset_index(drop=True)
merged_df
# Out:
#      mdrm_code schedule_type  \
# 0     RCFA2170          RCRI
# 1     RCFA3128          RCRI
# 2     RCFA3792          RCRI
# 3     RCFA5310          RCRI
# 4     RCFA5311          RCRI
# ...        ...           ...
# 5933  TEXTFT31           RIE
# 5934  TEXTFT42            CI
# 5935  TEXTFT43            CI
# 5936  TEXTFT44            CI
# 5937  TEXTFT45            CI
#
#                                          schedule_label  \
# 0     Schedule RC-R Part I - Regulatory Capital Comp...
# 1     Schedule RC-R Part I - Regulatory Capital Comp...
# 2     Schedule RC-R Part I - Regulatory Capital Comp...
# 3     Schedule RC-R Part I - Regulatory Capital Comp...
# 4     Schedule RC-R Part I - Regulatory Capital Comp...
# ...                                                 ...
# 5933     Schedule RI-E - Explanations (Form Type - 051)
# 5934               Contact Information(Form Type - 051)
# 5935               Contact Information(Form Type - 051)
# 5936               Contact Information(Form Type - 051)
# 5937               Contact Information(Form Type - 051)
#
#                                              mdrm_label  form_type
# 0     Total assets (Schedule RC, item 12); (must be ...  FFIEC 031
# 1                       Allocated transfer risk reserve  FFIEC 031
# 2     Total capitalTotal capital (sum of items 26 an...  FFIEC 031
# 3     Allowance for loan and lease losses and eligib...  FFIEC 031
# 4     Tier 2 capitalTier 2 capital (greater of item ...  FFIEC 031
# ...                                                 ...        ...
# 5933  Discontinued operations and applicable income ...  FFIEC 051
# 5934  Chief Executive Officer Contact InformationChi...  FFIEC 051
# 5935  Chief Executive Officer Contact InformationChi...  FFIEC 051
# 5936  Chief Executive Officer Contact InformationChi...  FFIEC 051
# 5937  Chief Executive Officer Contact InformationChi...  FFIEC 051
#
# [5938 rows x 5 columns]

# %%
df1 = extract_taxonomy_data(pd.read_json("C:\\Users\\whill\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\example\\031_2001-03-31.json"),'FFIEC 031')
df2 = extract_taxonomy_data(pd.read_json("C:\\Users\\whill\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\example\\041_2001-03-31.json"),'FFIEC 041')
older_df = pd.concat([df1,df2]).reset_index(drop=True)
older_df
# Out:
#      mdrm_code schedule_type  \
# 0     RCFD0010           RCR
# 1     RCFD0022           RCA
# 2     RCFD0071            RC
# 3     RCFD0073           RCA
# 4     RCFD0074           RCA
# ...        ...           ...
# 1716  TEXT8902            CI
# 1717  TEXT9116            CI
# 1718  TEXTA545           RCO
# 1719  TEXTB526           RIE
# 1720  TEXTB527           RIE
#
#                                          schedule_label  \
# 0                    Schedule RC-R - Regulatory Capital
# 1     Schedule RC-A - Cash and Balances Due From Dep...
# 2                           Schedule RC - Balance Sheet
# 3     Schedule RC-A - Cash and Balances Due From Dep...
# 4     Schedule RC-A - Cash and Balances Due From Dep...
# ...                                                 ...
# 1716                                Contact Information
# 1717                                Contact Information
# 1718  Schedule RC-O - Other Data for Deposit Insuran...
# 1719                       Schedule RI-E - Explanations
# 1720                       Schedule RI-E - Explanations
#
#                                              mdrm_label  form_type
# 0     Cash and balances due from depository institut...  FFIEC 031
# 1     Cash items in process of collection, unposted ...  FFIEC 031
# 2     Cash and balances due from depository institut...  FFIEC 031
# 3     Balances due from banks in foreign countries a...  FFIEC 031
# 4     Balances due from banks in foreign countries a...  FFIEC 031
# ...                                                 ...        ...
# 1716  Person to whom questions about the Reports of ...  FFIEC 041
# 1717  Person to whom questions about the Reports of ...  FFIEC 041
# 1718  Has the reporting institution been consolidate...  FFIEC 041
# 1719  Restatements due to corrections of material ac...  FFIEC 041
# 1720  Restatements due to corrections of material ac...  FFIEC 041
#
# [1721 rows x 5 columns]

# %%
df_2000_2023 = pd.concat([merged_df,older_df]).reset_index(drop=True)
df_2000_2023
# Out:
#      mdrm_code schedule_type  \
# 0     RCFA2170          RCRI
# 1     RCFA3128          RCRI
# 2     RCFA3792          RCRI
# 3     RCFA5310          RCRI
# 4     RCFA5311          RCRI
# ...        ...           ...
# 7654  TEXT8902            CI
# 7655  TEXT9116            CI
# 7656  TEXTA545           RCO
# 7657  TEXTB526           RIE
# 7658  TEXTB527           RIE
#
#                                          schedule_label  \
# 0     Schedule RC-R Part I - Regulatory Capital Comp...
# 1     Schedule RC-R Part I - Regulatory Capital Comp...
# 2     Schedule RC-R Part I - Regulatory Capital Comp...
# 3     Schedule RC-R Part I - Regulatory Capital Comp...
# 4     Schedule RC-R Part I - Regulatory Capital Comp...
# ...                                                 ...
# 7654                                Contact Information
# 7655                                Contact Information
# 7656  Schedule RC-O - Other Data for Deposit Insuran...
# 7657                       Schedule RI-E - Explanations
# 7658                       Schedule RI-E - Explanations
#
#                                              mdrm_label  form_type
# 0     Total assets (Schedule RC, item 12); (must be ...  FFIEC 031
# 1                       Allocated transfer risk reserve  FFIEC 031
# 2     Total capitalTotal capital (sum of items 26 an...  FFIEC 031
# 3     Allowance for loan and lease losses and eligib...  FFIEC 031
# 4     Tier 2 capitalTier 2 capital (greater of item ...  FFIEC 031
# ...                                                 ...        ...
# 7654  Person to whom questions about the Reports of ...  FFIEC 041
# 7655  Person to whom questions about the Reports of ...  FFIEC 041
# 7656  Has the reporting institution been consolidate...  FFIEC 041
# 7657  Restatements due to corrections of material ac...  FFIEC 041
# 7658  Restatements due to corrections of material ac...  FFIEC 041
#
# [7659 rows x 5 columns]

# %%
df_2000_2023.drop_duplicates(subset=['mdrm_code', 'form_type'],keep='first',inplace=True,ignore_index=True)

# %%
rows_to_drop = np.where(df_2000_2023['mdrm_code'].str.contains('TE', regex=True))
df_2000_2023.drop(index=rows_to_drop[0],inplace =True)

# %%
df_2000_2023
# Out:
#      mdrm_code schedule_type  \
# 0     RCFA2170          RCRI
# 1     RCFA3128          RCRI
# 2     RCFA3792          RCRI
# 3     RCFA5310          RCRI
# 4     RCFA5311          RCRI
# ...        ...           ...
# 6621  RIADA517            RI
# 6622  RIADA518            RI
# 6623  RIADB490            RI
# 6624  RIADB516          RIBI
# 6625  RIADB517          RIBI
#
#                                          schedule_label  \
# 0     Schedule RC-R Part I - Regulatory Capital Comp...
# 1     Schedule RC-R Part I - Regulatory Capital Comp...
# 2     Schedule RC-R Part I - Regulatory Capital Comp...
# 3     Schedule RC-R Part I - Regulatory Capital Comp...
# 4     Schedule RC-R Part I - Regulatory Capital Comp...
# ...                                                 ...
# 6621                     Schedule RI - Income Statement
# 6622                     Schedule RI - Income Statement
# 6623                     Schedule RI - Income Statement
# 6624  Schedule RI-B, Part I - Charge-offs and Recove...
# 6625  Schedule RI-B, Part I - Charge-offs and Recove...
#
#                                              mdrm_label  form_type
# 0     Total assets (Schedule RC, item 12); (must be ...  FFIEC 031
# 1                       Allocated transfer risk reserve  FFIEC 031
# 2     Total capitalTotal capital (sum of items 26 an...  FFIEC 031
# 3     Allowance for loan and lease losses and eligib...  FFIEC 031
# 4     Tier 2 capitalTier 2 capital (greater of item ...  FFIEC 031
# ...                                                 ...        ...
# 6621  Interest expense:Interest on deposits:Nontrans...  FFIEC 041
# 6622  Interest expense:Interest on deposits:Nontrans...  FFIEC 041
# 6623  Noninterest income:Investment banking, advisor...  FFIEC 041
# 6624  Loans to individuals for household, family, an...  FFIEC 041
# 6625  Loans to individuals for household, family, an...  FFIEC 041
#
# [6329 rows x 5 columns]

# %%
df_2000_2023['schedule_type'][df_2000_2023['mdrm_code']=='RCFA2170'].values[0]
# Out:
# 'RCRI'

# %%
if 'RCFA2170' in df_2000_2023['mdrm_code'].values:
    print (True)
# Out:
# True

# %%
result_df = mdrm_filtered.join(df_2000_2023.set_index(['mdrm_code', 'form_type']), on=['mdrm_code','form_type'],how='left')
result_df[~result_df['schedule_type'].isnull()]
# Out:
#       Mnemonic Item Code mdrm_code      Start Date         End Date  \
# 50643     RCFA      2170  RCFA2170  3/31/2020 0:00  12/31/9999 0:00
# 50644     RCFA      3128  RCFA3128  3/31/2020 0:00  12/31/9999 0:00
# 50645     RCFA      3792  RCFA3792  3/31/2014 0:00  12/31/9999 0:00
# 50646     RCFA      5310  RCFA5310  3/31/2014 0:00  12/31/9999 0:00
# 50647     RCFA      5311  RCFA5311  3/31/2014 0:00  12/31/9999 0:00
# ...        ...       ...       ...             ...              ...
# 69998     RSSD      9130  RSSD9130  3/31/2017 0:00  12/31/9999 0:00
# 70063     RSSD      9200  RSSD9200  9/30/2005 0:00  12/31/9999 0:00
# 70065     RSSD      9200  RSSD9200  3/31/2017 0:00  12/31/9999 0:00
# 70084     RSSD      9220  RSSD9220  9/30/2005 0:00  12/31/9999 0:00
# 70086     RSSD      9220  RSSD9220  3/31/2017 0:00  12/31/9999 0:00
#
#                                                Item Name Confidentiality  \
# 50643                                       TOTAL ASSETS               N
# 50644                   ALLOCATED TRANSFER RISK RESERVES               N
# 50645  TOTAL QUALIFYING CAPITAL ALLOWABLE UNDER THE R...               N
# 50646        GENERAL LOAN AND LEASE VALUATION ALLOWANCES               N
# 50647                     TIER 2 (SUPPLEMENTARY) CAPITAL               N
# ...                                                  ...             ...
# 69998                                CITY/TOWN TEXT NAME               N
# 70063                             ABBREVIATED STATE NAME               N
# 70065                             ABBREVIATED STATE NAME               N
# 70084                  PHYSICAL ZIP/FOREIGN MAILING CODE               N
# 70086                  PHYSICAL ZIP/FOREIGN MAILING CODE               N
#
#       ItemType  form_type                                        Description  \
# 50643        F  FFIEC 031  The sum of all asset items. This item must equ...
# 50644        F  FFIEC 031   Section 905 of the International Lending Supe...
# 50645        F  FFIEC 031  Includes the amount of the bank's total risk-b...
# 50646        F  FFIEC 031   Includes general loan and lease valuation all...
# 50647        F  FFIEC 031  Includes the sum of 'Qualifying Subordinated D...
# ...        ...        ...                                                ...
# 69998        S  FFIEC 051  The name of the city or town in which the enti...
# 70063        S  FFIEC 031  Two character state abbreviation as assigned t...
# 70065        S  FFIEC 051  Two character state abbreviation as assigned t...
# 70084        S  FFIEC 031  The zip code or foreign mailing code of the ph...
# 70086        S  FFIEC 051  The zip code or foreign mailing code of the ph...
#
#                                           SeriesGlossary schedule_type  \
# 50643   Regulatory Capital Components and Ratios for ...          RCRI
# 50644   Regulatory Capital Components and Ratios for ...          RCRI
# 50645   Regulatory Capital Components and Ratios for ...          RCRI
# 50646   Regulatory Capital Components and Ratios for ...          RCRI
# 50647   Regulatory Capital Components and Ratios for ...          RCRI
# ...                                                  ...           ...
# 69998                                                              ENT
# 70063                                                              ENT
# 70065                                                              ENT
# 70084                                                              ENT
# 70086                                                              ENT
#
#                                           schedule_label  \
# 50643  Schedule RC-R Part I - Regulatory Capital Comp...
# 50644  Schedule RC-R Part I - Regulatory Capital Comp...
# 50645  Schedule RC-R Part I - Regulatory Capital Comp...
# 50646  Schedule RC-R Part I - Regulatory Capital Comp...
# 50647  Schedule RC-R Part I - Regulatory Capital Comp...
# ...                                                  ...
# 69998      Bank Demographic Information(Form Type - 051)
# 70063      Bank Demographic Information(Form Type - 031)
# 70065      Bank Demographic Information(Form Type - 051)
# 70084      Bank Demographic Information(Form Type - 031)
# 70086      Bank Demographic Information(Form Type - 051)
#
#                                               mdrm_label
# 50643  Total assets (Schedule RC, item 12); (must be ...
# 50644                    Allocated transfer risk reserve
# 50645  Total capitalTotal capital (sum of items 26 an...
# 50646  Allowance for loan and lease losses and eligib...
# 50647  Tier 2 capitalTier 2 capital (greater of item ...
# ...                                                  ...
# 69998                                               City
# 70063                                 State abbreviation
# 70065                                 State abbreviation
# 70084                                           Zip code
# 70086                                           Zip code
#
# [4051 rows x 14 columns]

# %%
master_data_type_list = match_data_type(id_rssd_set,set(result_df['mdrm_code']))
datatype_df = pd.DataFrame(master_data_type_list,columns=['mdrm_code', 'data_type'])
datatype_df
# Out:
# The time of code execution begin is :  Wed Nov 29 15:50:42 2023
# The time of code execution end was :  Wed Nov 29 18:07:37 2023
#      mdrm_code data_type
# 0     RCONA565       int
# 1     RIADJJ28       int
# 2     RIAD3217       int
# 3     RCON3049       int
# 4     RCONA575       int
# ...        ...       ...
# 2990  RCONL197       int
# 2991  RCFDL194       int
# 2992  RCFDL196       int
# 2993  RCFDK194       int
# 2994  RCFDK193       int
#
# [2995 rows x 2 columns]

# %%
datatype_df[datatype_df['data_type']=='bool']
# Out:
#      mdrm_code data_type
# 34    RCONFT07      bool
# 40    RCONFT03      bool
# 46    RCONA346      bool
# 48    RIADA530      bool
# 51    RCONFT06      bool
# 93    RCONFT11      bool
# 98    RCONB867      bool
# 195   RCONFT00      bool
# 209   RCONFT09      bool
# 223   RCONKX18      bool
# 281   RCONFT16      bool
# 304   RCONK656      bool
# 311   RCON6979      bool
# 341   RCONPG75      bool
# 407   RCONK659      bool
# 425   RIAD4769      bool
# 448   RCONA345      bool
# 507   RCONFT13      bool
# 646   RCONG463      bool
# 953   RCONB569      bool
# 1006  RCON6860      bool
# 1053  RCON6999      bool
# 1176  RCONP752      bool
# 1209  RCONG464      bool
# 1521  RCFDA345      bool
# 1606  RCFDB867      bool
# 1679  RCFDK659      bool
# 2391  RCFDB569      bool
# 2463  RCFDK656      bool
# 2544  RCFDA346      bool
# 2667  RCONL135      bool
# 2791  RCON4088      bool
# 2844  RCFD4088      bool

# %%
id_rssd_set.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3188\617788397.py in <module>
# ----> 1 id_rssd_set[0:1000]
#
# TypeError: 'set' object is not subscriptable

# %%
master_data_type_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3188\1707360210.py in <module>
# ----> 1 master_data_type_list
#
# NameError: name 'master_data_type_list' is not defined

# %%
final_df = result_df.join(datatype_df.set_index(['mdrm_code']), on=['mdrm_code'],how='left')
final_df
# Out:
#       Mnemonic Item Code mdrm_code       Start Date         End Date  \
# 10710     CALL      8002  CALL8002   3/31/1984 0:00   3/31/2006 0:00
# 10714     CALL      8786  CALL8786   3/31/1984 0:00  12/31/9999 0:00
# 10716     CALL      8787  CALL8787  12/31/1959 0:00  12/31/9999 0:00
# 10717     CALL      8798  CALL8798  12/31/1959 0:00  12/31/9999 0:00
# 10718     CALL      8799  CALL8799  12/31/1959 0:00  12/31/2000 0:00
# ...        ...       ...       ...              ...              ...
# 69998     RSSD      9130  RSSD9130   3/31/2017 0:00  12/31/9999 0:00
# 70063     RSSD      9200  RSSD9200   9/30/2005 0:00  12/31/9999 0:00
# 70065     RSSD      9200  RSSD9200   3/31/2017 0:00  12/31/9999 0:00
# 70084     RSSD      9220  RSSD9220   9/30/2005 0:00  12/31/9999 0:00
# 70086     RSSD      9220  RSSD9220   3/31/2017 0:00  12/31/9999 0:00
#
#                                Item Name Confidentiality ItemType  form_type  \
# 10710          REPORTING STATUS (W-CODE)               N        F  FFIEC 031
# 10714               REPORTING LEVEL CODE               N        S  FFIEC 031
# 10716           REPORTING EXCEPTION CODE               N        F  FFIEC 031
# 10717                     FDR TIME STAMP               Y        F  FFIEC 031
# 10718                ARCHIVAL DATE STAMP               Y        F  FFIEC 031
# ...                                  ...             ...      ...        ...
# 69998                CITY/TOWN TEXT NAME               N        S  FFIEC 051
# 70063             ABBREVIATED STATE NAME               N        S  FFIEC 031
# 70065             ABBREVIATED STATE NAME               N        S  FFIEC 051
# 70084  PHYSICAL ZIP/FOREIGN MAILING CODE               N        S  FFIEC 031
# 70086  PHYSICAL ZIP/FOREIGN MAILING CODE               N        S  FFIEC 051
#
#                                              Description  \
# 10710  This item is an asset threshold used to determ...
# 10714  Effective 10/24/2011; the FR 2572 information ...
# 10716  Effective 10/24/2011; the FR 2572 information ...
# 10717  Effective 10/24/2011; the FR 2572 information ...
# 10718  The date (ccyymmdd) the data were last updated...
# ...                                                  ...
# 69998  The name of the city or town in which the enti...
# 70063  Two character state abbreviation as assigned t...
# 70065  Two character state abbreviation as assigned t...
# 70084  The zip code or foreign mailing code of the ph...
# 70086  The zip code or foreign mailing code of the ph...
#
#                                           SeriesGlossary schedule_type  \
# 10710  \r\nThe following items may be accessed by the...           NaN
# 10714  \r\nThe following items may be accessed by the...           NaN
# 10716  \r\nThe following items may be accessed by the...           NaN
# 10717  \r\nThe following items may be accessed by the...           NaN
# 10718  \r\nThe following items may be accessed by the...           NaN
# ...                                                  ...           ...
# 69998                                                              ENT
# 70063                                                              ENT
# 70065                                                              ENT
# 70084                                                              ENT
# 70086                                                              ENT
#
#                                       schedule_label          mdrm_label  \
# 10710                                            NaN                 NaN
# 10714                                            NaN                 NaN
# 10716                                            NaN                 NaN
# 10717                                            NaN                 NaN
# 10718                                            NaN                 NaN
# ...                                              ...                 ...
# 69998  Bank Demographic Information(Form Type - 051)                City
# 70063  Bank Demographic Information(Form Type - 031)  State abbreviation
# 70065  Bank Demographic Information(Form Type - 051)  State abbreviation
# 70084  Bank Demographic Information(Form Type - 031)            Zip code
# 70086  Bank Demographic Information(Form Type - 051)            Zip code
#
#       data_type
# 10710       NaN
# 10714       NaN
# 10716       NaN
# 10717       NaN
# 10718       NaN
# ...         ...
# 69998       str
# 70063       str
# 70065       str
# 70084       str
# 70086       str
#
# [6062 rows x 15 columns]

# %%
final_df.to_csv("C:\\Users\\whill\\call-report-database\\MDRM_CSV_Filtered_Schedules_Data_Types.csv")

# %%
len(final_df[~final_df['data_type'].isnull()])
# Out:
# 3525

# %%
match_df = result_df[(result_df['schedule_type'].isnull()) & (result_df['End Date'] == '12/31/9999 0:00')]
result_df[result_df['Item Code']=='G813']
# Out:
#       Mnemonic Item Code mdrm_code      Start Date         End Date  \
# 54086     RCFD      G813  RCFDG813  6/30/2009 0:00  12/31/9999 0:00
#
#                                                Item Name Confidentiality  \
# 54086  ALL HOLDINGS OF MBS:RESIDENTIAL MORTGAGE PASS-...               N
#
#       ItemType  form_type                                        Description  \
# 54086        D  FFIEC 031  FFIEC031 RC-B -Securities Derived Formula: SUM...
#
#       SeriesGlossary schedule_type schedule_label mdrm_label
# 54086            NaN           NaN            NaN        NaN

# %% [markdown]
# # just set things to 'Missing' Schedule Name, work on developing the code for creating the tables and setting up a new snowflake instance, then work on code for pulling the data merging it together by bank and then looping through the mdrm_code and tying the value to a specific table.
#
# # we also need to think about the types of the values, see if we can loop through a list of bank's first, find a data type and then create logic to develop the create table queries

# %%
result_df.to_csv("C:\\Users\\whill\\call-report-database\\MDRM_CSV_Filtered_Schedules.csv")

# %%
schedule_list = set(result_df['schedule_type'][~result_df['schedule_type'].isnull()])
# Out:
# {'ENT',
#  'LEO',
#  'NARR',
#  'RC',
#  'RCA',
#  'RCB',
#  'RCCI',
#  'RCCII',
#  'RCD',
#  'RCE',
#  'RCEI',
#  'RCEII',
#  'RCF',
#  'RCG',
#  'RCH',
#  'RCI',
#  'RCK',
#  'RCL',
#  'RCM',
#  'RCN',
#  'RCO',
#  'RCP',
#  'RCQ',
#  'RCR',
#  'RCRI',
#  'RCRII',
#  'RCS',
#  'RCT',
#  'RCV',
#  'RI',
#  'RIA',
#  'RIBI',
#  'RIBII',
#  'RIC',
#  'RICI',
#  'RICII',
#  'RID',
#  'RIE',
#  'SU'}

# %%
result_df[result_df['schedule_type'].isin(['ENT'])]
# Out:
#       Mnemonic Item Code mdrm_code      Start Date         End Date  \
# 62559     RCON      9224  RCON9224  3/31/2017 0:00  12/31/9999 0:00
# 62578     RCON      9999  RCON9999  3/31/2017 0:00  12/31/9999 0:00
# 69882     RSSD      9017  RSSD9017  9/30/2005 0:00  12/31/9999 0:00
# 69884     RSSD      9017  RSSD9017  3/31/2017 0:00  12/31/9999 0:00
# 69996     RSSD      9130  RSSD9130  9/30/2005 0:00  12/31/9999 0:00
# 69998     RSSD      9130  RSSD9130  3/31/2017 0:00  12/31/9999 0:00
# 70063     RSSD      9200  RSSD9200  9/30/2005 0:00  12/31/9999 0:00
# 70065     RSSD      9200  RSSD9200  3/31/2017 0:00  12/31/9999 0:00
# 70084     RSSD      9220  RSSD9220  9/30/2005 0:00  12/31/9999 0:00
# 70086     RSSD      9220  RSSD9220  3/31/2017 0:00  12/31/9999 0:00
#
#                                Item Name Confidentiality ItemType  form_type  \
# 62559            LEGAL ENTITY IDENTIFIER               N        F  FFIEC 051
# 62578       REPORTING DATE (CC;YR;MO;DA)               N        F  FFIEC 051
# 69882                         LEGAL NAME               N        S  FFIEC 031
# 69884                         LEGAL NAME               N        S  FFIEC 051
# 69996                CITY/TOWN TEXT NAME               N        S  FFIEC 031
# 69998                CITY/TOWN TEXT NAME               N        S  FFIEC 051
# 70063             ABBREVIATED STATE NAME               N        S  FFIEC 031
# 70065             ABBREVIATED STATE NAME               N        S  FFIEC 051
# 70084  PHYSICAL ZIP/FOREIGN MAILING CODE               N        S  FFIEC 031
# 70086  PHYSICAL ZIP/FOREIGN MAILING CODE               N        S  FFIEC 051
#
#                                              Description  \
# 62559  The Legal Entity Identifier (LEI) is a 20-digi...
# 62578  Effective 10/24/2011; the FR 2572 information ...
# 69882  Effective 10/24/2011; the FR 2572 information ...
# 69884  Effective 10/24/2011; the FR 2572 information ...
# 69996  The name of the city or town in which the enti...
# 69998  The name of the city or town in which the enti...
# 70063  Two character state abbreviation as assigned t...
# 70065  Two character state abbreviation as assigned t...
# 70084  The zip code or foreign mailing code of the ph...
# 70086  The zip code or foreign mailing code of the ph...
#
#                                           SeriesGlossary schedule_type  \
# 62559   The mnemonic prefixes in this file represent ...           ENT
# 62578   The mnemonic prefixes in this file represent ...           ENT
# 69882                                                              ENT
# 69884                                                              ENT
# 69996                                                              ENT
# 69998                                                              ENT
# 70063                                                              ENT
# 70065                                                              ENT
# 70084                                                              ENT
# 70086                                                              ENT
#
#                                       schedule_label  \
# 62559  Bank Demographic Information(Form Type - 051)
# 62578  Bank Demographic Information(Form Type - 051)
# 69882  Bank Demographic Information(Form Type - 031)
# 69884  Bank Demographic Information(Form Type - 051)
# 69996  Bank Demographic Information(Form Type - 031)
# 69998  Bank Demographic Information(Form Type - 051)
# 70063  Bank Demographic Information(Form Type - 031)
# 70065  Bank Demographic Information(Form Type - 051)
# 70084  Bank Demographic Information(Form Type - 031)
# 70086  Bank Demographic Information(Form Type - 051)
#
#                                               mdrm_label
# 62559  Legal Entity Identifier (LEI) (Report only if ...
# 62578                                     Reporting date
# 69882                                Legal title of bank
# 69884                                Legal title of bank
# 69996                                               City
# 69998                                               City
# 70063                                 State abbreviation
# 70065                                 State abbreviation
# 70084                                           Zip code
# 70086                                           Zip code

# %%
start_list = ['IDRSSD', 'RCON9999']
result_df['mdrm_code'][result_df['schedule_type'].isin(['ENT'])].to_list()
start_list.extend(result_df['mdrm_code'][result_df['schedule_type'].isin(['ENT'])].to_list())
columns_set = set(start_list)
columns_set
# Out:
# {'IDRSSD',
#  'RCON9224',
#  'RCON9999',
#  'RSSD9017',
#  'RSSD9130',
#  'RSSD9200',
#  'RSSD9220'}

# %%
data_list = ['VARCHAR', 'DATE']
for i in range(len(columns_set)-2):
    data_list.append('NUMBER')
data_list
# Out:
# ['VARCHAR', 'DATE', 'NUMBER', 'NUMBER', 'NUMBER', 'NUMBER', 'NUMBER']

# %%
def create_table_query(table_name, columns, data_types):
    # Check if the lengths of the lists are the same
    if len(columns) != len(data_types):
        raise ValueError("Number of columns and data types must be the same.")

    # Construct the Create table query
    columns_str = ', '.join([f'{col} {data_type}' for col, data_type in zip(columns, data_types)])
    query = f'CREATE TABLE {table_name} ({columns_str});'

    return query

# Example usage:
table_name = 'example_table'
column_names = ['id', 'name', 'age']
data_types = ['INT', 'VARCHAR(255)', 'INT']

sql_query = create_table_query(table_name, columns_set, data_list)
print(sql_query)
# Out:
# CREATE TABLE example_table (IDRSSD VARCHAR, RCON9224 DATE, RSSD9200 NUMBER, RSSD9130 NUMBER, RCON9999 NUMBER, RSSD9220 NUMBER, RSSD9017 NUMBER);

# %%
import pandas
from snowflake.connector.pandas_tools import write_pandas

# Create the connection to the Snowflake database.
cnx = snowflake.connector.connect(...)

# Create a DataFrame containing data about customers
df = pandas.DataFrame([('Mark', 10), ('Luke', 20)], columns=['name', 'balance'])

# Write the data from the DataFrame to the table named "customers".
success, nchunks, nrows, _ = write_pandas(cnx, df, 'customers')

# %%
import snowflake.snowpark as snowpark
from snowflake.snowpark.functions import col

def main(session: snowpark.Session): 
    # CREATE TABLE
    create_table_query  = f"""
       CREATE OR REPLACE TABLE TEST_DB.TEST_SCHEMA.CALL_CENTER_COPY AS
       SELECT 
              CC_CALL_CENTER_ID
             ,CC_REC_START_DATE 
             ,CC_REC_END_DATE
       FROM TEST_DB.TEST_SCHEMA.CALL_CENTER;
    """
    session.sql(create_table_query).collect()
    # SELECT TABLE
    create_table_query  = f"""
       SELECT 
              *
       FROM TEST_DB.TEST_SCHEMA.CALL_CENTER_COPY;
    """
    call_center_table = session.sql(create_table_query).collect()
    return call_center_table

# %%
df_2000_2023['mdrm_code'].str.contains('TEXT').sum()
# Out:
# 251

# %%
older_df.loc[older_df['mdrm_code'] == 'RIADB527']
# Out:
#      mdrm_code schedule_type                schedule_label  \
# 852   RIADB527           RIE  Schedule RI-E - Explanations
# 1675  RIADB527           RIE  Schedule RI-E - Explanations
#
#                                              mdrm_label  form_type
# 852   Restatements due to corrections of material ac...  FFIEC 031
# 1675  Restatements due to corrections of material ac...  FFIEC 041

# %%
older_df['mdrm_label'].iloc[1675]
# Out:
# 'Restatements due to corrections of material accounting errors and changes in accounting principles (from Schedule RI-A)Itemized amount of Restatements'

# %%
merged_df.to_csv("C:\\Users\\whill\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\example\\Taxonomies_example.csv")

# %%
final_df
# Out:
#      mdrm_code schedule_type  \
# 0     RCFA2170          RCRI
# 1     RCFA3128          RCRI
# 2     RCFA3792          RCRI
# 3     RCFA5310          RCRI
# 4     RCFA5311          RCRI
# ...        ...           ...
# 2367  TEXTG561           RCQ
# 2368  TEXTG571           RCQ
# 2369  TEXTG576           RCQ
# 2370  TEXTG581           RCQ
# 2371  TEXTG586           RCQ
#
#                                          schedule_label  \
# 0     Schedule RC-R Part I - Regulatory Capital Comp...
# 1     Schedule RC-R Part I - Regulatory Capital Comp...
# 2     Schedule RC-R Part I - Regulatory Capital Comp...
# 3     Schedule RC-R Part I - Regulatory Capital Comp...
# 4     Schedule RC-R Part I - Regulatory Capital Comp...
# ...                                                 ...
# 2367  Schedule RC-Q - Assets and Liabilities Measure...
# 2368  Schedule RC-Q - Assets and Liabilities Measure...
# 2369  Schedule RC-Q - Assets and Liabilities Measure...
# 2370  Schedule RC-Q - Assets and Liabilities Measure...
# 2371  Schedule RC-Q - Assets and Liabilities Measure...
#
#                                              mdrm_label
# 0     Total assets (Schedule RC, item 12); (must be ...
# 1                       Allocated transfer risk reserve
# 2     Total capitalTotal capital (sum of items 26 an...
# 3     Allowance for loan and lease losses and eligib...
# 4     Tier 2 capitalTier 2 capital (greater of item ...
# ...                                                 ...
# 2367                                 Describe component
# 2368                                 Describe component
# 2369                                 Describe component
# 2370                                 Describe component
# 2371                                 Describe component
#
# [2372 rows x 4 columns]

# %%
df3=pd.read_json("C:\\Users\\whill\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\example\\031_2023-09-30.json")
df3

# %%
sys.path.append(os.path.abspath("C:\\Users\\whill\\OneDrive\\Desktop\\Fall 2022\\ISYE 6740\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json"))

# %%
import cdr_taxonomy_processor as cdr_processor

# %%
cdr_processor.process_zip("C:\\Users\\whill\\OneDrive\\Desktop\\Fall 2022\\ISYE 6740\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\FFIEC CDR UBPR Bulk XBRL 03312022.zip")
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Loading ZIP file:  C:\Users\whill\OneDrive\Desktop\Fall 2022\ISYE 6740\call-report-database\python\cdr_taxonomy_xbrl_to_json\FFIEC CDR UBPR Bulk XBRL 03312022.zip
# The included ZIP file does not appear to be a valid CDR taxonomy file.
#
# Exiting with error
# Traceback (most recent call last):
#   File "C:\Users\whill\OneDrive\Desktop\Fall 2022\ISYE 6740\call-report-database\python\cdr_taxonomy_xbrl_to_json\cdr_taxonomy_processor.py", line 96, in process_zip
#     cap_file = list(filter(lambda x: '-cap' in x, files_parsed))[0]
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\whill\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-27-db84e2cba177>", line 1, in <module>
#     cdr_processor.process_zip("C:\\Users\\whill\\OneDrive\\Desktop\\Fall 2022\\ISYE 6740\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\FFIEC CDR UBPR Bulk XBRL 03312022.zip")
#   File "C:\Users\whill\OneDrive\Desktop\Fall 2022\ISYE 6740\call-report-database\python\cdr_taxonomy_xbrl_to_json\cdr_taxonomy_processor.py", line 109, in process_zip
#     sys.exit(1)
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\whill\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\whill\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\whill\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\whill\anaconda3\lib\inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\OneDrive\Desktop\Fall 2022\ISYE 6740\call-report-database\python\cdr_taxonomy_xbrl_to_json\cdr_taxonomy_processor.py in process_zip(filename)
#      95     try:
# ---> 96         cap_file = list(filter(lambda x: '-cap' in x, files_parsed))[0]
#      97         def_file = list(filter(lambda x: '-def' in x, files_parsed))[0]
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-27-db84e2cba177> in <module>
# ----> 1 cdr_processor.process_zip("C:\\Users\\whill\\OneDrive\\Desktop\\Fall 2022\\ISYE 6740\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\FFIEC CDR UBPR Bulk XBRL 03312022.zip")
#
# ~\OneDrive\Desktop\Fall 2022\ISYE 6740\call-report-database\python\cdr_taxonomy_xbrl_to_json\cdr_taxonomy_processor.py in process_zip(filename)
#     108         print("Exiting with error")
# --> 109         sys.exit(1)
#     110
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2052                     stb = ['An exception has occurred, use %tb to see '
#    2053                            'the full traceback.\n']
# -> 2054                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2055                                                                      value))
#    2056                 else:
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     627             chained_exceptions_tb_offset = 0
#     628             out_list = (
# --> 629                 self.structured_traceback(
#     630                     etype, evalue, (etb, chained_exc_ids),
#     631                     chained_exceptions_tb_offset, context)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1122         """Return a nice text document describing the traceback."""
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#    1126
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
# !python C:\\Users\\whill\\OneDrive\\Desktop\\Fall 2022\\ISYE 6740\\call-report-database\\python\\cdr_taxonomy_xbrl_to_json\\cdr_taxonomy_processor.py
# Out:
# python: can't open file 'C:\\Users\\whill\\OneDrive\\Desktop\\Fall': [Errno 2] No such file or directory

# %%
df= pd.json_normalize(df2["data"])
df
# Out:
#      RCRI.line_ids.schedule.code
# 0             ffiec031_pres-RCRI  \
# 1             ffiec031_pres-RCRI
# 2             ffiec031_pres-RCRI
# 3             ffiec031_pres-RCRI
# 4             ffiec031_pres-RCRI
# ...                          ...
# 2367                         NaN
# 2368                         NaN
# 2369                         NaN
# 2370                         NaN
# 2371                         NaN
#
#                            RCRI.line_ids.schedule.label
# 0     Schedule RC-R Part I - Regulatory Capital Comp...  \
# 1     Schedule RC-R Part I - Regulatory Capital Comp...
# 2     Schedule RC-R Part I - Regulatory Capital Comp...
# 3     Schedule RC-R Part I - Regulatory Capital Comp...
# 4     Schedule RC-R Part I - Regulatory Capital Comp...
# ...                                                 ...
# 2367                                                NaN
# 2368                                                NaN
# 2369                                                NaN
# 2370                                                NaN
# 2371                                                NaN
#
#      RCRI.line_ids.extra_col_0.code
# 0        ffiec031_pres-line-1010119  \
# 1        ffiec031_pres-line-1010106
# 2        ffiec031_pres-line-1010113
# 3        ffiec031_pres-line-1010112
# 4        ffiec031_pres-line-1010118
# ...                             ...
# 2367                            NaN
# 2368                            NaN
# 2369                            NaN
# 2370                            NaN
# 2371                            NaN
#
#                         RCRI.line_ids.extra_col_0.label
# 0     Total assets (Schedule RC, item 12); (must be ...  \
# 1                       Allocated transfer risk reserve
# 2                                         Total capital
# 3     Allowance for loan and lease losses and eligib...
# 4                                        Tier 2 capital
# ...                                                 ...
# 2367                                                NaN
# 2368                                                NaN
# 2369                                                NaN
# 2370                                                NaN
# 2371                                                NaN
#
#      RCRI.column_ids.schedule.code
# 0               ffiec031_pres-RCRI  \
# 1               ffiec031_pres-RCRI
# 2               ffiec031_pres-RCRI
# 3               ffiec031_pres-RCRI
# 4               ffiec031_pres-RCRI
# ...                            ...
# 2367                           NaN
# 2368                           NaN
# 2369                           NaN
# 2370                           NaN
# 2371                           NaN
#
#                          RCRI.column_ids.schedule.label
# 0     Schedule RC-R Part I - Regulatory Capital Comp...  \
# 1     Schedule RC-R Part I - Regulatory Capital Comp...
# 2     Schedule RC-R Part I - Regulatory Capital Comp...
# 3     Schedule RC-R Part I - Regulatory Capital Comp...
# 4     Schedule RC-R Part I - Regulatory Capital Comp...
# ...                                                 ...
# 2367                                                NaN
# 2368                                                NaN
# 2369                                                NaN
# 2370                                                NaN
# 2371                                                NaN
#
#        RCRI.column_ids.colset.code  RCRI.column_ids.colset.label
# 0     ffiec031_pres-RCRI-76-colset                           NaN  \
# 1     ffiec031_pres-RCRI-77-colset                           NaN
# 2     ffiec031_pres-RCRI-77-colset                           NaN
# 3     ffiec031_pres-RCRI-77-colset                           NaN
# 4     ffiec031_pres-RCRI-77-colset                           NaN
# ...                            ...                           ...
# 2367                           NaN                           NaN
# 2368                           NaN                           NaN
# 2369                           NaN                           NaN
# 2370                           NaN                           NaN
# 2371                           NaN                           NaN
#
#          RCRI.column_ids.column.code RCRI.column_ids.column.label  ...
# 0     ffiec031_pres-RCRI-76-column-A            (Column A) Amount  ...  \
# 1     ffiec031_pres-RCRI-77-column-A                  DummyColumn  ...
# 2     ffiec031_pres-RCRI-77-column-A                  DummyColumn  ...
# 3     ffiec031_pres-RCRI-77-column-A                  DummyColumn  ...
# 4     ffiec031_pres-RCRI-77-column-A                  DummyColumn  ...
# ...                              ...                          ...  ...
# 2367                             NaN                          NaN  ...
# 2368                             NaN                          NaN  ...
# 2369                             NaN                          NaN  ...
# 2370                             NaN                          NaN  ...
# 2371                             NaN                          NaN  ...
#
#      CI.line_ids.extra_col_2.code CI.line_ids.extra_col_2.label
# 0                             NaN                           NaN  \
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ...                           ...                           ...
# 2367                          NaN                           NaN
# 2368                          NaN                           NaN
# 2369                          NaN                           NaN
# 2370                          NaN                           NaN
# 2371                          NaN                           NaN
#
#      CI.column_ids.schedule.code CI.column_ids.schedule.label
# 0                            NaN                          NaN  \
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ...                          ...                          ...
# 2367                         NaN                          NaN
# 2368                         NaN                          NaN
# 2369                         NaN                          NaN
# 2370                         NaN                          NaN
# 2371                         NaN                          NaN
#
#      CI.column_ids.colset.code CI.column_ids.colset.label
# 0                          NaN                        NaN  \
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2367                       NaN                        NaN
# 2368                       NaN                        NaN
# 2369                       NaN                        NaN
# 2370                       NaN                        NaN
# 2371                       NaN                        NaN
#
#      CI.column_ids.column.code CI.column_ids.column.label CI.reference.line
# 0                          NaN                        NaN               NaN  \
# 1                          NaN                        NaN               NaN
# 2                          NaN                        NaN               NaN
# 3                          NaN                        NaN               NaN
# 4                          NaN                        NaN               NaN
# ...                        ...                        ...               ...
# 2367                       NaN                        NaN               NaN
# 2368                       NaN                        NaN               NaN
# 2369                       NaN                        NaN               NaN
# 2370                       NaN                        NaN               NaN
# 2371                       NaN                        NaN               NaN
#
#      CI.reference.column
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 2367                 NaN
# 2368                 NaN
# 2369                 NaN
# 2370                 NaN
# 2371                 NaN
#
# [2372 rows x 538 columns]

# %%
keys_list = list(df2["data"][0].keys())
subset_of_data = df2["data"][0][keys_list[0]]
#subset_of_data['line_ids']['schedule']['label']
subset_of_data['line_ids']['extra_col_0']['label']
# Out:
# 2

# %%
re.split('_',df2.index[0])[1]
# Out:
# 'RCFA2170'

# %%
data = df2['data']

# Create an empty DataFrame to store the results
result_df = pd.DataFrame()

# Iterate over keys in 'data'
for key, value in data.items():
    # Flatten the nested structures under the current key
    df_temp = pd.json_normalize(value, sep='_')
    
    # Check if DataFrame has columns before setting the index
    if not df_temp.empty:
        df_temp.set_index(key, inplace=True)
    
        # Add 'schedule' field as metadata from df2
        df_temp['schedule'] = df2.get('schedule', None)
    
        # Add the DataFrame to the result DataFrame
        result_df = pd.concat([result_df, df_temp])


# Set 'schedule' as the first column (optional)
result_df = result_df[['schedule'] + [col for col in result_df.columns if col != 'schedule']]

print(result_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-0917dc85104a> in <module>
#      11     # Check if DataFrame has columns before setting the index
#      12     if not df_temp.empty:
# ---> 13         df_temp.set_index(key, inplace=True)
#      14
#      15         # Add 'schedule' field as metadata from df2
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5867
#    5868         if missing:
# -> 5869             raise KeyError(f"None of {missing} are in the columns")
#    5870
#    5871         if inplace:
#
# KeyError: "None of ['cc_RCFA2170'] are in the columns"

# %%
# Out:
# cc_RCFA2170    {'RCRI': {'line_ids': {'schedule': {'code': 'f...
# cc_RCFA3128    {'RCRI': {'line_ids': {'schedule': {'code': 'f...
# cc_RCFA3792    {'RCRI': {'line_ids': {'schedule': {'code': 'f...
# cc_RCFA5310    {'RCRI': {'line_ids': {'schedule': {'code': 'f...
# cc_RCFA5311    {'RCRI': {'line_ids': {'schedule': {'code': 'f...
#                                      ...
# cc_TEXTG561    {'RCQ': {'line_ids': {'schedule': {'code': 'ff...
# cc_TEXTG571    {'RCQ': {'line_ids': {'schedule': {'code': 'ff...
# cc_TEXTG576    {'RCQ': {'line_ids': {'schedule': {'code': 'ff...
# cc_TEXTG581    {'RCQ': {'line_ids': {'schedule': {'code': 'ff...
# cc_TEXTG586    {'RCQ': {'line_ids': {'schedule': {'code': 'ff...
# Name: data, Length: 2372, dtype: object

# %%
df['data'][0]
# Out:
# {'RCRI': {'line_ids': {'schedule': {'code': 'ffiec031_pres-RCRI',
#     'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#    'extra_col_0': {'code': 'ffiec031_pres-line-1010119',
#     'label': 'Total assets (Schedule RC, item 12); (must be less than $10 billion)'}},
#   'column_ids': {'schedule': {'code': 'ffiec031_pres-RCRI',
#     'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#    'colset': {'code': 'ffiec031_pres-RCRI-76-colset', 'label': None},
#    'column': {'code': 'ffiec031_pres-RCRI-76-column-A',
#     'label': '(Column A) Amount'}},
#   'reference': {'line': '32', 'column': 'A'}}}

# %%
new_dict ={}
for i in range(len(df)):
    clone= df['data'][i]
    line_ids_data = clone[next(iter(df['data'][i]))][keys[0]]
    if len(line_ids_data) > 2:
        print(line_ids_data)
        schedule_data = line_ids_data['schedule']
        schedule_label = schedule_data.get('label', None)
        extra_col_0_data = []
        for i in range(1,len(line_ids_data)):
            key = f'extra_col_{i}'
            extra_col_data = line_ids_data.get(key, {})
            extra_col_0_data.append(str(extra_col_data.get('label', None)))
        extra_col_0_label = ' '.join(filter(None, extra_col_0_data))
    else:
        schedule_data = line_ids_data['schedule']
        extra_col_0_data = line_ids_data['extra_col_0']
        schedule_label = schedule_data.get('label', None)
        extra_col_0_label = extra_col_0_data.get('label', None)
    new_dict.update({re.split('_',df.index[i])[1]:{'Schedule':next(iter(df['data'][i])),
                                                   'MDRM_Label':f'{extra_col_0_label}',
                                                   'Schedule_label':f'{schedule_label}'}})
    
#new_dict
# Out:
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010113', 'label': 'Total capital'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010098', 'label': 'Total capital (sum of items 26 and 46.a)'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010112', 'label': 'Allowance for loan and lease losses and eligible credit reserves includable in tier 2 capital'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010093', 'label': 'Allowance for loan and lease losses includable in tier 2 capital'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010118', 'label': 'Tier 2 capital'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010095', 'label': 'Tier 2 capital (greater of item 44.a minus item 45, or zero)'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010114', 'label': 'Total risk-weighted assets'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010096', 'label': 'Total risk-weighted assets (from Schedule RC-R, Part II, item 31)'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010062', 'label': 'Advanced approaches institutions and institutions subject to Category III capital standards only: Supplementary leverage ratio information:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010057', 'label': 'Total leverage exposure'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010062', 'label': 'Advanced approaches institutions and institutions subject to Category III capital standards only: Supplementary leverage ratio information:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010060', 'label': 'Supplementary leverage ratio'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010055', 'label': 'Institution-specific capital buffer necessary to avoid limitations on distributions and discretionary bonus payments:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010056', 'label': 'Capital conservation buffer'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010108', 'label': 'Amount of allowances for credit losses on purchased credit-deteriorated assets:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010097', 'label': 'Loans and leases held for investment'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010108', 'label': 'Amount of allowances for credit losses on purchased credit-deteriorated assets:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010104', 'label': 'Held-to-maturity debt securities'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010108', 'label': 'Amount of allowances for credit losses on purchased credit-deteriorated assets:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010107', 'label': 'Other financial assets measured at amortized cost'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010123', 'label': 'Off-balance sheet exposures:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010120', 'label': 'Unused portion of conditionally cancellable commitments'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010123', 'label': 'Off-balance sheet exposures:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010122', 'label': 'Securities lent and borrowed (Schedule RC-L, sum of items 6.a and 6.b)'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010123', 'label': 'Off-balance sheet exposures:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010124', 'label': 'Other off-balance sheet exposures'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010123', 'label': 'Off-balance sheet exposures:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010125', 'label': 'Total off-balance sheet exposures (sum of items 34.a through 34.c). Report as a dollar amount in Column A and as a percentage of total assets (25% limit) in Column B'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010123', 'label': 'Off-balance sheet exposures:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010125', 'label': 'Total off-balance sheet exposures (sum of items 34.a through 34.c). Report as a dollar amount in Column A and as a percentage of total assets (25% limit) in Column B'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010071', 'label': 'Not available'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010064', 'label': 'LESS: Investments in the capital of unconsolidated financial institutions, net of associated DTLs, that exceed 25 percent of item 12'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010072', 'label': 'Not available'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010065', 'label': 'LESS: MSAs, net of associated DTLs, that exceed 25 percent of item 12'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010073', 'label': 'Not available'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010066', 'label': 'LESS: DTAs arising from temporary differences that could not be realized through net operating loss carrybacks, net of related valuation allowances and net of DTLs, that exceed 25 percent of item 12'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010047', 'label': 'AOCI-related adjustments (items 9.a through 9.e are effective January 1, 2015) (if entered "1" for Yes in item 3.a, complete only items 9.a through 9.e; if entered "0" for No in item 3.a, complete only item 9.f):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010035', 'label': 'LESS: Net unrealized gains (losses) on available-for-sale debt securities (if a gain, report as a positive value; if a loss, report as a negative value)'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010047', 'label': 'AOCI-related adjustments (items 9.a through 9.e are effective January 1, 2015) (if entered "1" for Yes in item 3.a, complete only items 9.a through 9.e; if entered "0" for No in item 3.a, complete only item 9.f):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010041', 'label': 'LESS: Accumulated net gains (losses) on cash flow hedges (if a gain, report as a positive value; if a loss, report as a negative value)'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010047', 'label': 'AOCI-related adjustments (items 9.a through 9.e are effective January 1, 2015) (if entered "1" for Yes in item 3.a, complete only items 9.a through 9.e; if entered "0" for No in item 3.a, complete only item 9.f):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010043', 'label': 'LESS: Amounts recorded in AOCI attributed to defined benefit postretirement plans resulting from the initial and subsequent application of the relevant GAAP standards that pertain to such plans (if a gain, report as a positive value; if a loss, report as a negative value)'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010047', 'label': 'AOCI-related adjustments (items 9.a through 9.e are effective January 1, 2015) (if entered "1" for Yes in item 3.a, complete only items 9.a through 9.e; if entered "0" for No in item 3.a, complete only item 9.f):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010045', 'label': 'LESS: Net unrealized gains (losses) on held-to-maturity securities that are included in AOCI (if a gain, report as a positive value; if a loss, report as a negative value)'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010047', 'label': 'AOCI-related adjustments (items 9.a through 9.e are effective January 1, 2015) (if entered "1" for Yes in item 3.a, complete only items 9.a through 9.e; if entered "0" for No in item 3.a, complete only item 9.f):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010051', 'label': 'LESS: Accumulated net gain (loss) on cash flow hedges included in AOCI, net of applicable income taxes, that relate to the hedging of items that are not recognized at fair value on the balance sheet (if a gain, report as a positive value; if a loss, report as a negative value) (To be completed only by institutions that entered "0" for No in item 3.a)'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010048', 'label': 'Other deductions from (additions to) common equity tier 1 capital before threshold-based deductions:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010039', 'label': 'LESS: All other deductions from (additions to) common equity tier 1 capital before threshold-based deductions'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010116', 'label': 'Tier 2 capital before deductions'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010094', 'label': 'Tier 2 capital before deductions (sum of items 39 through 42)'}}
# {'schedule': {'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010048', 'label': 'Other deductions from (additions to) common equity tier 1 capital before threshold-based deductions:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010036', 'label': 'LESS: Unrealized net gain (loss) related to changes in the fair value of liabilities that are due to changes in own credit risk (if a gain, report as a positive value; if a loss, report as a negative value)'}}
# {'schedule': {'code': 'ffiec031_pres-RC', 'label': 'Schedule RC - Balance Sheet(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009028', 'label': 'Cash and balances due from depository institutions (from Schedule RC-A):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009040', 'label': 'Interest-bearing balances'}}
# {'schedule': {'code': 'ffiec031_pres-RC', 'label': 'Schedule RC - Balance Sheet(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009028', 'label': 'Cash and balances due from depository institutions (from Schedule RC-A):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009029', 'label': 'Noninterest-bearing balances and currency and coin'}}
# {'schedule': {'code': 'ffiec031_pres-RCN', 'label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009835', 'label': 'Commercial and industrial loans:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009791', 'label': 'To U.S. addressees (domicile)'}}
# {'schedule': {'code': 'ffiec031_pres-RCN', 'label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009835', 'label': 'Commercial and industrial loans:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009791', 'label': 'To U.S. addressees (domicile)'}}
# {'schedule': {'code': 'ffiec031_pres-RCN', 'label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009835', 'label': 'Commercial and industrial loans:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009791', 'label': 'To U.S. addressees (domicile)'}}
# {'schedule': {'code': 'ffiec031_pres-RCN', 'label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009835', 'label': 'Commercial and industrial loans:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009814', 'label': 'To non-U.S. addressees (domicile)'}}
# {'schedule': {'code': 'ffiec031_pres-RCN', 'label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009835', 'label': 'Commercial and industrial loans:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009814', 'label': 'To non-U.S. addressees (domicile)'}}
# {'schedule': {'code': 'ffiec031_pres-RCN', 'label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009835', 'label': 'Commercial and industrial loans:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009814', 'label': 'To non-U.S. addressees (domicile)'}}
# {'schedule': {'code': 'ffiec031_pres-RCCI', 'label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009156', 'label': 'Loans secured by real estate'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009171', 'label': 'Secured by farmland (including farm residential and other improvements)'}}
# {'schedule': {'code': 'ffiec031_pres-RCCI', 'label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009156', 'label': 'Loans secured by real estate'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009189', 'label': 'Secured by multifamily (5 or more) residential properties'}}
# {'schedule': {'code': 'ffiec031_pres-RCF', 'label': 'Schedule RC-F - Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009466', 'label': 'All other assets (itemize and describe amounts greater than $100,000 that exceed 25% of this item)'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009455', 'label': 'Repossessed personal property (including vehicles)'}}
# {'schedule': {'code': 'ffiec031_pres-RCB', 'label': 'Schedule RC-B - Securities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009114', 'label': 'Other debt securities:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009097', 'label': 'Other domestic debt securities'}}
# {'schedule': {'code': 'ffiec031_pres-RCB', 'label': 'Schedule RC-B - Securities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009114', 'label': 'Other debt securities:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009097', 'label': 'Other domestic debt securities'}}
# {'schedule': {'code': 'ffiec031_pres-RCB', 'label': 'Schedule RC-B - Securities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009114', 'label': 'Other debt securities:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009097', 'label': 'Other domestic debt securities'}}
# {'schedule': {'code': 'ffiec031_pres-RCB', 'label': 'Schedule RC-B - Securities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009114', 'label': 'Other debt securities:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009097', 'label': 'Other domestic debt securities'}}
# {'schedule': {'code': 'ffiec031_pres-RCB', 'label': 'Schedule RC-B - Securities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009114', 'label': 'Other debt securities:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009106', 'label': 'Other foreign debt securities'}}
# {'schedule': {'code': 'ffiec031_pres-RCB', 'label': 'Schedule RC-B - Securities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009114', 'label': 'Other debt securities:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009106', 'label': 'Other foreign debt securities'}}
# {'schedule': {'code': 'ffiec031_pres-RCB', 'label': 'Schedule RC-B - Securities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009114', 'label': 'Other debt securities:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009106', 'label': 'Other foreign debt securities'}}
# {'schedule': {'code': 'ffiec031_pres-RCB', 'label': 'Schedule RC-B - Securities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009114', 'label': 'Other debt securities:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009106', 'label': 'Other foreign debt securities'}}
# {'schedule': {'code': 'ffiec031_pres-RCCI', 'label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009188', 'label': 'Commercial and industrial loans:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009164', 'label': 'To U.S. addressees (domicile)'}}
# {'schedule': {'code': 'ffiec031_pres-RCCI', 'label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009188', 'label': 'Commercial and industrial loans:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009178', 'label': 'To non-U.S. addressees (domicile)'}}
# {'schedule': {'code': 'ffiec031_pres-RCCI', 'label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009156', 'label': 'Loans secured by real estate'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009185', 'label': 'Secured by 1-4 family residential properties:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009162', 'label': 'Revolving, open-end loans secured by 1-4 family residential properties and extended under lines of credit'}}
# {'schedule': {'code': 'ffiec031_pres-RCM', 'label': 'Schedule RC-M - Memoranda(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009694', 'label': 'Intangible assets:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009743', 'label': 'Total (sum of items 2.a, 2.b, and 2.c) (must equal Schedule RC, item 10)'}}
# {'schedule': {'code': 'ffiec031_pres-RCM', 'label': 'Schedule RC-M - Memoranda(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009722', 'label': 'Other real estate owned:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009779', 'label': 'Total (sum of items 3.a through 3.g) (must equal Schedule RC, item 7)'}}
# {'schedule': {'code': 'ffiec031_pres-RCF', 'label': 'Schedule RC-F - Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009466', 'label': 'All other assets (itemize and describe amounts greater than $100,000 that exceed 25% of this item)'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009449', 'label': 'Prepaid expenses'}}
# {'schedule': {'code': 'ffiec031_pres-RCM', 'label': 'Schedule RC-M - Memoranda(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009750', 'label': 'Other borrowed money:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009681', 'label': 'Federal Home Loan Bank advances:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009698', 'label': 'Advances with a remaining maturity of one year or less (included in item 5.a.(1)(a) above)'}}
# {'schedule': {'code': 'ffiec031_pres-RCG', 'label': 'Schedule RC-G - Other Liabilities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009487', 'label': 'All other liabilities (itemize and describe amounts greater than $100,000 that exceed 25 percent of this item)'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009486', 'label': 'Dividends declared but not yet payable'}}
# {'schedule': {'code': 'ffiec031_pres-RC', 'label': 'Schedule RC - Balance Sheet(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009075', 'label': 'Not available'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009049', 'label': 'Noncontrolling (minority) interests in consolidated subsidiaries'}}
# {'schedule': {'code': 'ffiec031_pres-RCG', 'label': 'Schedule RC-G - Other Liabilities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009487', 'label': 'All other liabilities (itemize and describe amounts greater than $100,000 that exceed 25 percent of this item)'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009475', 'label': 'Accounts payable'}}
# {'schedule': {'code': 'ffiec031_pres-RCM', 'label': 'Schedule RC-M - Memoranda(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009694', 'label': 'Intangible assets:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009702', 'label': 'Goodwill'}}
# {'schedule': {'code': 'ffiec031_pres-RCM', 'label': 'Schedule RC-M - Memoranda(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009694', 'label': 'Intangible assets:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009674', 'label': 'Mortgage servicing assets'}}
# {'schedule': {'code': 'ffiec031_pres-RCM', 'label': 'Schedule RC-M - Memoranda(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009750', 'label': 'Other borrowed money:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009732', 'label': 'Total (sum of items 5.a.(1)(a)-(d) and items 5.b.(1)(a)-(d)) (must equal Schedule RC, item 16)'}}
# {'schedule': {'code': 'ffiec031_pres-RC', 'label': 'Schedule RC - Balance Sheet(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009075', 'label': 'Not available'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009038', 'label': 'Total bank equity capital (sum of items 23 through 26.c)'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009578', 'label': 'Securities lent and borrowed:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009569', 'label': 'Securities borrowed'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009578', 'label': 'Securities lent and borrowed:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009561', 'label': "Securities lent (including customers' securities lent where the customer is indemnified against loss by the reporting bank)"}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009645', 'label': 'All other off-balance sheet liabilities (exclude derivatives) (itemize and describe each component of this item over 25% of Schedule RC, item 27.a, "Total bank equity capital")'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009646', 'label': 'Commitments to purchase when-issued securities'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009656', 'label': 'All other off-balance sheet assets (exclude derivatives) (itemize and describe each component of this item over 25% of Schedule RC, item 27.a, "Total bank equity capital")'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009637', 'label': 'Commitments to sell when-issued securities'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009598', 'label': 'Swaps'}}
# {'schedule': {'code': 'ffiec031_pres-RCQ', 'label': 'Schedule RC-Q - Assets and Liabilities Measured at Fair Value on a Recurring Basis(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009980', 'label': 'Trading assets:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009971', 'label': 'Derivative assets'}}
# {'schedule': {'code': 'ffiec031_pres-RCD', 'label': 'Schedule RC-D - Trading Assets and Liabilities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009333', 'label': 'Not available'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009299', 'label': 'Liability for short positions'}}
# {'schedule': {'code': 'ffiec031_pres-RCQ', 'label': 'Schedule RC-Q - Assets and Liabilities Measured at Fair Value on a Recurring Basis(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009985', 'label': 'Trading liabilities:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009972', 'label': 'Derivative liabilities'}}
# {'schedule': {'code': 'ffiec031_pres-RCF', 'label': 'Schedule RC-F - Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009466', 'label': 'All other assets (itemize and describe amounts greater than $100,000 that exceed 25% of this item)'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009469', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009456', 'label': 'Amount of component'}}
# {'schedule': {'code': 'ffiec031_pres-RCF', 'label': 'Schedule RC-F - Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009466', 'label': 'All other assets (itemize and describe amounts greater than $100,000 that exceed 25% of this item)'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009471', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009458', 'label': 'Amount of component'}}
# {'schedule': {'code': 'ffiec031_pres-RCF', 'label': 'Schedule RC-F - Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009466', 'label': 'All other assets (itemize and describe amounts greater than $100,000 that exceed 25% of this item)'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009470', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009457', 'label': 'Amount of component'}}
# {'schedule': {'code': 'ffiec031_pres-RCG', 'label': 'Schedule RC-G - Other Liabilities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009487', 'label': 'All other liabilities (itemize and describe amounts greater than $100,000 that exceed 25 percent of this item)'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009491', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009482', 'label': 'Amount of component'}}
# {'schedule': {'code': 'ffiec031_pres-RCG', 'label': 'Schedule RC-G - Other Liabilities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009487', 'label': 'All other liabilities (itemize and describe amounts greater than $100,000 that exceed 25 percent of this item)'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009492', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009483', 'label': 'Amount of component'}}
# {'schedule': {'code': 'ffiec031_pres-RCG', 'label': 'Schedule RC-G - Other Liabilities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009487', 'label': 'All other liabilities (itemize and describe amounts greater than $100,000 that exceed 25 percent of this item)'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009493', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009484', 'label': 'Amount of component'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009645', 'label': 'All other off-balance sheet liabilities (exclude derivatives) (itemize and describe each component of this item over 25% of Schedule RC, item 27.a, "Total bank equity capital")'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009660', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009654', 'label': 'Amount of component'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009645', 'label': 'All other off-balance sheet liabilities (exclude derivatives) (itemize and describe each component of this item over 25% of Schedule RC, item 27.a, "Total bank equity capital")'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009662', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009655', 'label': 'Amount of component'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009645', 'label': 'All other off-balance sheet liabilities (exclude derivatives) (itemize and describe each component of this item over 25% of Schedule RC, item 27.a, "Total bank equity capital")'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009664', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009653', 'label': 'Amount of component'}}
# {'schedule': {'code': 'ffiec031_pres-RC', 'label': 'Schedule RC - Balance Sheet(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009074', 'label': 'Not available'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009037', 'label': 'Retained earnings'}}
# {'schedule': {'code': 'ffiec031_pres-RCG', 'label': 'Schedule RC-G - Other Liabilities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009473', 'label': 'Not available'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009480', 'label': 'Other expenses accrued and unpaid (includes accrued income taxes payable)'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009554', 'label': 'Unused commitments:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009555', 'label': 'Revolving, open-end lines secured by 1-4 family residential properties, i.e., home equity lines'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009554', 'label': 'Unused commitments:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009565', 'label': 'Credit card lines (Sum of items 1.b.(1) and 1.b.(2) must equal item 1.b)'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009554', 'label': 'Unused commitments:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009575', 'label': 'Securities underwriting'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009564', 'label': 'Financial standby letters of credit and foreign office guarantees'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009558', 'label': 'Amount of financial standby letters of credit conveyed to others'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009571', 'label': 'Performance standby letters of credit and foreign office guarantees'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009562', 'label': 'Amount of performance standby letters of credit conveyed to others'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009598', 'label': 'Swaps'}}
# {'schedule': {'code': 'ffiec031_pres-RCCI', 'label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009156', 'label': 'Loans secured by real estate'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009185', 'label': 'Secured by 1-4 family residential properties:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009176', 'label': 'Closed-end loans secured by 1-4 family residential properties:'}, 'extra_col_3': {'code': 'ffiec031_pres-line-1009160', 'label': 'Secured by first liens'}}
# {'schedule': {'code': 'ffiec031_pres-RCCI', 'label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009156', 'label': 'Loans secured by real estate'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009185', 'label': 'Secured by 1-4 family residential properties:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009176', 'label': 'Closed-end loans secured by 1-4 family residential properties:'}, 'extra_col_3': {'code': 'ffiec031_pres-line-1009174', 'label': 'Secured by junior liens'}}
# {'schedule': {'code': 'ffiec031_pres-RC', 'label': 'Schedule RC - Balance Sheet(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009054', 'label': 'Loans and lease financing receivables (from Schedule RC-C):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009033', 'label': 'Loans and leases held for sale'}}
# {'schedule': {'code': 'ffiec031_pres-RCN', 'label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009804', 'label': 'Loans to depository institutions and acceptances of other banks:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009787', 'label': 'To U.S. banks and other U.S. depository institutions'}}
# {'schedule': {'code': 'ffiec031_pres-RCN', 'label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009804', 'label': 'Loans to depository institutions and acceptances of other banks:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009787', 'label': 'To U.S. banks and other U.S. depository institutions'}}
# {'schedule': {'code': 'ffiec031_pres-RCN', 'label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009804', 'label': 'Loans to depository institutions and acceptances of other banks:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009787', 'label': 'To U.S. banks and other U.S. depository institutions'}}
# {'schedule': {'code': 'ffiec031_pres-RCN', 'label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009804', 'label': 'Loans to depository institutions and acceptances of other banks:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009810', 'label': 'To foreign banks'}}
# {'schedule': {'code': 'ffiec031_pres-RCN', 'label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009804', 'label': 'Loans to depository institutions and acceptances of other banks:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009810', 'label': 'To foreign banks'}}
# {'schedule': {'code': 'ffiec031_pres-RCN', 'label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009804', 'label': 'Loans to depository institutions and acceptances of other banks:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009810', 'label': 'To foreign banks'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009656', 'label': 'All other off-balance sheet assets (exclude derivatives) (itemize and describe each component of this item over 25% of Schedule RC, item 27.a, "Total bank equity capital")'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009648', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009647', 'label': 'Amount of component'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009656', 'label': 'All other off-balance sheet assets (exclude derivatives) (itemize and describe each component of this item over 25% of Schedule RC, item 27.a, "Total bank equity capital")'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009658', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009649', 'label': 'Amount of component'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009656', 'label': 'All other off-balance sheet assets (exclude derivatives) (itemize and describe each component of this item over 25% of Schedule RC, item 27.a, "Total bank equity capital")'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009661', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009651', 'label': 'Amount of component'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009656', 'label': 'All other off-balance sheet assets (exclude derivatives) (itemize and describe each component of this item over 25% of Schedule RC, item 27.a, "Total bank equity capital")'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009663', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009652', 'label': 'Amount of component'}}
# {'schedule': {'code': 'ffiec031_pres-RCM', 'label': 'Schedule RC-M - Memoranda(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009665', 'label': 'Extensions of credit by the reporting bank to its executive officers, directors, principal shareholders, and their related interests as of the report date:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009666', 'label': 'Aggregate amount of all extensions of credit to all executive officers, directors, principal shareholders, and their related interests'}}
# {'schedule': {'code': 'ffiec031_pres-RCM', 'label': 'Schedule RC-M - Memoranda(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009665', 'label': 'Extensions of credit by the reporting bank to its executive officers, directors, principal shareholders, and their related interests as of the report date:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009695', 'label': 'Number of executive officers, directors, and principal shareholders to whom the amount of all extensions of credit by the reporting bank (including extensions of credit to related interests) equals or exceeds the lesser of $500,000 or 5 percent of total capital as defined for this purpose in agency regulations'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009554', 'label': 'Unused commitments:'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009572', 'label': 'Commitments to fund commercial real estate, construction, and land development loans:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009568', 'label': 'Not secured by real estate'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009580', 'label': 'Futures contracts'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009580', 'label': 'Futures contracts'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009580', 'label': 'Futures contracts'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009580', 'label': 'Futures contracts'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009588', 'label': 'Forward contracts'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009588', 'label': 'Forward contracts'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009588', 'label': 'Forward contracts'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009588', 'label': 'Forward contracts'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009595', 'label': 'Exchange-traded option contracts:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009584', 'label': 'Written options'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009595', 'label': 'Exchange-traded option contracts:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009584', 'label': 'Written options'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009595', 'label': 'Exchange-traded option contracts:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009584', 'label': 'Written options'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009595', 'label': 'Exchange-traded option contracts:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009584', 'label': 'Written options'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009595', 'label': 'Exchange-traded option contracts:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009591', 'label': 'Purchased options'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009595', 'label': 'Exchange-traded option contracts:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009591', 'label': 'Purchased options'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009595', 'label': 'Exchange-traded option contracts:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009591', 'label': 'Purchased options'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009595', 'label': 'Exchange-traded option contracts:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009591', 'label': 'Purchased options'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009597', 'label': 'Over-the-counter option contracts:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009586', 'label': 'Written options'}}
# {'schedule': {'code': 'ffiec031_pres-RCL', 'label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009579', 'label': 'Gross amounts (e.g., notional amounts):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009597', 'label': 'Over-the-counter option contracts:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009586', 'label': 'Written options'}}
# ...
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008797', 'label': 'Emergency Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008793', 'label': 'Secondary Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008817', 'label': 'Telephone'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008797', 'label': 'Emergency Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008793', 'label': 'Secondary Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008825', 'label': 'FAX'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008782', 'label': 'Primary Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008772', 'label': 'Name'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008782', 'label': 'Primary Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008787', 'label': 'Title'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008782', 'label': 'Primary Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008801', 'label': 'E-mail Address'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008782', 'label': 'Primary Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008813', 'label': 'Telephone'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008796', 'label': 'Secondary Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008775', 'label': 'Name'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008796', 'label': 'Secondary Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008790', 'label': 'Title'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008796', 'label': 'Secondary Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008803', 'label': 'E-mail Address'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008796', 'label': 'Secondary Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008815', 'label': 'Telephone'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008768', 'label': 'Contact Information for the Reports of Condition and Income'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008773', 'label': 'Chief Financial Officer (or Equivalent) Signing the Reports'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008771', 'label': 'Name'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008768', 'label': 'Contact Information for the Reports of Condition and Income'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008773', 'label': 'Chief Financial Officer (or Equivalent) Signing the Reports'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008786', 'label': 'Title'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008768', 'label': 'Contact Information for the Reports of Condition and Income'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008773', 'label': 'Chief Financial Officer (or Equivalent) Signing the Reports'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008800', 'label': 'E-mail Address'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008768', 'label': 'Contact Information for the Reports of Condition and Income'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008773', 'label': 'Chief Financial Officer (or Equivalent) Signing the Reports'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008812', 'label': 'Telephone'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008768', 'label': 'Contact Information for the Reports of Condition and Income'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008773', 'label': 'Chief Financial Officer (or Equivalent) Signing the Reports'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008823', 'label': 'FAX'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008768', 'label': 'Contact Information for the Reports of Condition and Income'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008788', 'label': 'Other Person to Whom Questions about the Reports Should be Directed'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008776', 'label': 'Name'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008768', 'label': 'Contact Information for the Reports of Condition and Income'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008788', 'label': 'Other Person to Whom Questions about the Reports Should be Directed'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008791', 'label': 'Title'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008808', 'label': 'Third Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008779', 'label': 'Name'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008808', 'label': 'Third Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008794', 'label': 'Title'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008808', 'label': 'Third Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008806', 'label': 'E-mail Address'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008808', 'label': 'Third Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008818', 'label': 'Telephone'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008820', 'label': 'Fourth Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008781', 'label': 'Name'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008820', 'label': 'Fourth Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008795', 'label': 'Title'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008820', 'label': 'Fourth Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008807', 'label': 'E-mail Address'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008809', 'label': 'USA PATRIOT Act Section 314(a) Anti-Money Laundering Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008820', 'label': 'Fourth Contact'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008819', 'label': 'Telephone'}}
# {'schedule': {'code': 'ffiec031_pres-RCD', 'label': 'Schedule RC-D - Trading Assets and Liabilities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009373', 'label': 'Other trading assets (itemize and describe amounts included in Schedule RC-D, item 9, that are greater than $1,000,000 and exceed 25% of the item):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009354', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009347', 'label': 'Describe component'}}
# {'schedule': {'code': 'ffiec031_pres-RCD', 'label': 'Schedule RC-D - Trading Assets and Liabilities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009373', 'label': 'Other trading assets (itemize and describe amounts included in Schedule RC-D, item 9, that are greater than $1,000,000 and exceed 25% of the item):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009365', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009349', 'label': 'Describe component'}}
# {'schedule': {'code': 'ffiec031_pres-RCD', 'label': 'Schedule RC-D - Trading Assets and Liabilities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009373', 'label': 'Other trading assets (itemize and describe amounts included in Schedule RC-D, item 9, that are greater than $1,000,000 and exceed 25% of the item):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009369', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009352', 'label': 'Describe component'}}
# {'schedule': {'code': 'ffiec031_pres-RCD', 'label': 'Schedule RC-D - Trading Assets and Liabilities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009375', 'label': 'Other trading liabilities (itemize and describe amounts included in Schedule RC-D, item 13.b, that are greater than $1,000,000 and exceed 25% of the item):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009355', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009348', 'label': 'Describe component'}}
# {'schedule': {'code': 'ffiec031_pres-RCD', 'label': 'Schedule RC-D - Trading Assets and Liabilities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009375', 'label': 'Other trading liabilities (itemize and describe amounts included in Schedule RC-D, item 13.b, that are greater than $1,000,000 and exceed 25% of the item):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009366', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009350', 'label': 'Describe component'}}
# {'schedule': {'code': 'ffiec031_pres-RCD', 'label': 'Schedule RC-D - Trading Assets and Liabilities(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1009375', 'label': 'Other trading liabilities (itemize and describe amounts included in Schedule RC-D, item 13.b, that are greater than $1,000,000 and exceed 25% of the item):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1009370', 'label': 'Disclose component and the dollar amount of that component:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1009353', 'label': 'Describe component'}}
# {'schedule': {'code': 'ffiec031_pres-RIE', 'label': 'Schedule RI-E - Explanations (Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010642', 'label': 'Discontinued operations and applicable income tax effect (from Schedule RI, item 11) (itemize and describe each discontinued operation):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010605', 'label': 'Disclose component, the gross dollar amount of that component, and its related income tax:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1010601', 'label': 'Describe component'}}
# {'schedule': {'code': 'ffiec031_pres-RIE', 'label': 'Schedule RI-E - Explanations (Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1010642', 'label': 'Discontinued operations and applicable income tax effect (from Schedule RI, item 11) (itemize and describe each discontinued operation):'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1010627', 'label': 'Disclose component, the gross dollar amount of that component, and its related income tax:'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1010604', 'label': 'Describe component'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008821', 'label': 'Chief Executive Officer Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008780', 'label': 'Chief Executive Officer'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008769', 'label': 'Name'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008821', 'label': 'Chief Executive Officer Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008780', 'label': 'Chief Executive Officer'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008798', 'label': 'Telephone'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008821', 'label': 'Chief Executive Officer Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008780', 'label': 'Chief Executive Officer'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008784', 'label': 'E-mail Address'}}
# {'schedule': {'code': 'ffiec031_pres-CI', 'label': 'Contact Information(Form Type - 031)'}, 'extra_col_0': {'code': 'ffiec031_pres-line-1008821', 'label': 'Chief Executive Officer Contact Information'}, 'extra_col_1': {'code': 'ffiec031_pres-line-1008780', 'label': 'Chief Executive Officer'}, 'extra_col_2': {'code': 'ffiec031_pres-line-1008810', 'label': 'FAX'}}

# %%
[np.where(df.index=='cc_RCFDD965')]
# Out:
# [(array([498], dtype=int64),)]

# %%
new_dict
# Out:
# {'RCFA2170': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Total assets (Schedule RC, item 12); (must be less than $10 billion)',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFA3128': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Allocated transfer risk reserve',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFA3792': {'Schedule': 'RCRI',
#   'MDRM_Label': 'FAX None',
#   'Schedule_label': 'Contact Information(Form Type - 031)'},
#  'RCFA7204': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Interest on deposits: Interest on deposits in domestic offices: Nontransaction accounts: Time deposits of more than $250,000 None',
#   'Schedule_label': 'Schedule RI - Income Statement(Form Type - 031)'},
#  'RCFA7205': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Total capital ratio (Column A: item 47.a divided by item 48.a) (Advanced approaches institutions that exit parallel run only: Column B: item 47.b divided by item 48.b)',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFA7206': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Tier 1 capital ratio (Column A: item 26 divided by item 48.a) (Advanced approaches institutions that exit parallel run only: Column B: item 26 divided by item 48.b)',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFA8274': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Tier 1 capital',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAA224': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Total assets for the leverage ratio (item 27 minus items 28 and 29)',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAB530': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Accumulated other comprehensive income (AOCI)',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAB596': {'Schedule': 'RCRI',
#   'MDRM_Label': 'LESS: Other deductions from (additions to) assets for leverage ratio purposes',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAH313': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Eligible retained income',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAH314': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Distributions and discretionary bonus payments during the quarter',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAKW00': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Retained earnings',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAKW03': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Average total consolidated assets',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAKX77': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Trading assets and trading liabilities (Schedule RC, sum of items 5 and 15). Report as a dollar amount in Column A and as a percentage of total assets (5% limit) in Column B',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAKX78': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Trading assets and trading liabilities (Schedule RC, sum of items 5 and 15). Report as a dollar amount in Column A and as a percentage of total assets (5% limit) in Column B',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFALB61': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Investments in the tier 2 capital of unconsolidated financial institutions',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP742': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Common stock plus related surplus, net of treasury stock and unearned employee stock ownership plan (ESOP) shares',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP793': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Common equity tier 1 capital ratio (Column A: item 19, column A or B, as applicable, divided by item 48.a) (Advanced approaches institutions that exit parallel run only: Column B: item 19, column B, divided by item 48.b)',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP839': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Common equity tier 1 minority interest includable in common equity tier 1 capital',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP840': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Common equity tier 1 capital before adjustments and deductions (sum of items 1 through 4)',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP841': {'Schedule': 'RCRI',
#   'MDRM_Label': 'LESS: Goodwill net of associated deferred tax liabilities (DTLs)',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP842': {'Schedule': 'RCRI',
#   'MDRM_Label': 'LESS: Intangible assets (other than goodwill and mortgage servicing assets (MSAs)), net of associated DTLs',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP843': {'Schedule': 'RCRI',
#   'MDRM_Label': 'LESS: Deferred tax assets (DTAs) that arise from net operating loss and tax credit carryforwards, net of any related valuation allowances and net of DTLs',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP852': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Subtotal (for column A, item 5 minus items 6 through 10.b; for column B, item 5 minus items 6 through 11)',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP857': {'Schedule': 'RCRI',
#   'MDRM_Label': 'LESS: Deductions applied to common equity tier 1 capital due to insufficient amounts of additional tier 1 capital and tier 2 capital to cover deductions',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP858': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Total adjustments and deductions for common equity tier 1 capital',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP859': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Common equity tier 1 capital (item 12 minus item 18)',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP860': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Additional tier 1 capital instruments plus related surplus',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP861': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Non-qualifying capital instruments subject to phase out from additional tier 1 capital',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP862': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Tier 1 minority interest not included in common equity tier 1 capital',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP863': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Additional tier 1 capital before deductions (sum of items 20, 21, and 22)',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP864': {'Schedule': 'RCRI',
#   'MDRM_Label': 'LESS: Additional tier 1 capital deductions',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP865': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Additional tier 1 capital (greater of item 23 minus item 24, or zero)',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP866': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Tier 2 capital instruments plus related surplus',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP867': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Non-qualifying capital instruments subject to phase-out from tier 2 capital',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP868': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Total capital minority interest that is not included in tier 1 capital',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP872': {'Schedule': 'RCRI',
#   'MDRM_Label': 'LESS: Tier 2 capital deductions',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAP875': {'Schedule': 'RCRI',
#   'MDRM_Label': 'LESS: Deductions from common equity tier 1 capital and additional tier 1 capital (sum of items 6, 7, 8, 10.b, 13 through 15, 17, and certain elements of item 24 - see instructions)',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFAS540': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Unconditionally cancellable commitments',
#   'Schedule_label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'},
#  'RCFD0010': {'Schedule': 'RCA',
#   'MDRM_Label': 'Total',
#   'Schedule_label': 'Schedule RC-A - Cash and Balances Due From Depository Institutions(Form Type - 031)'},
#  'RCFD0022': {'Schedule': 'RCA',
#   'MDRM_Label': 'Cash items in process of collection, unposted debits, and currency and coin',
#   'Schedule_label': 'Schedule RC-A - Cash and Balances Due From Depository Institutions(Form Type - 031)'},
#  'RCFD0070': {'Schedule': 'RCA',
#   'MDRM_Label': 'Balances due from banks in foreign countries and foreign central banks',
#   'Schedule_label': 'Schedule RC-A - Cash and Balances Due From Depository Institutions(Form Type - 031)'},
#  'RCFD0082': {'Schedule': 'RCA',
#   'MDRM_Label': 'Balances due from depository institutions in the U.S.',
#   'Schedule_label': 'Schedule RC-A - Cash and Balances Due From Depository Institutions(Form Type - 031)'},
#  'RCFD0090': {'Schedule': 'RCA',
#   'MDRM_Label': 'Balances due from Federal Reserve Banks',
#   'Schedule_label': 'Schedule RC-A - Cash and Balances Due From Depository Institutions(Form Type - 031)'},
#  'RCFD0211': {'Schedule': 'RCB',
#   'MDRM_Label': 'U.S. Treasury securities',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFD0213': {'Schedule': 'RCB',
#   'MDRM_Label': 'U.S. Treasury securities',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFD0416': {'Schedule': 'RCB',
#   'MDRM_Label': 'Pledged securities',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFD1248': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans secured by real estate to non-U.S. addressees (domicile) (included in Schedule RC-N, item 1, above)',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD1249': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans secured by real estate to non-U.S. addressees (domicile) (included in Schedule RC-N, item 1, above)',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD1250': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans secured by real estate to non-U.S. addressees (domicile) (included in Schedule RC-N, item 1, above)',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD1286': {'Schedule': 'RCB',
#   'MDRM_Label': 'U.S. Treasury securities',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFD1287': {'Schedule': 'RCB',
#   'MDRM_Label': 'U.S. Treasury securities',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFD1403': {'Schedule': 'RCN',
#   'MDRM_Label': 'Total loans and leases (sum of items 1 through 8.b)',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD1406': {'Schedule': 'RCN',
#   'MDRM_Label': 'Total loans and leases (sum of items 1 through 8.b)',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD1407': {'Schedule': 'RCN',
#   'MDRM_Label': 'Total loans and leases (sum of items 1 through 8.b)',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD1410': {'Schedule': 'RCCI',
#   'MDRM_Label': 'Loans secured by real estate',
#   'Schedule_label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'},
#  'RCFD1563': {'Schedule': 'RCCI',
#   'MDRM_Label': 'Loans to nondepository financial institutions and other loans',
#   'Schedule_label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'},
#  'RCFD1583': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans to finance agricultural production and other loans to farmers',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD1590': {'Schedule': 'RCCI',
#   'MDRM_Label': 'Loans to finance agricultural production and other loans to farmers',
#   'Schedule_label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'},
#  'RCFD1594': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans to finance agricultural production and other loans to farmers',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD1597': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans to finance agricultural production and other loans to farmers',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD1752': {'Schedule': 'RCF',
#   'MDRM_Label': 'Equity investments without readily determinable fair values',
#   'Schedule_label': 'Schedule RC-F - Other Assets(Form Type - 031)'},
#  'RCFD1754': {'Schedule': 'RCB',
#   'MDRM_Label': 'Total (sum of items 1 through 7)',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFD1771': {'Schedule': 'RCB',
#   'MDRM_Label': 'Total (sum of items 1 through 7)',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFD1772': {'Schedule': 'RCB',
#   'MDRM_Label': 'Total (sum of items 1 through 7)',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFD1773': {'Schedule': 'RCB',
#   'MDRM_Label': 'Total (sum of items 1 through 7)',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFD1778': {'Schedule': 'RCB',
#   'MDRM_Label': 'Amortized cost of held-to-maturity securities sold or transferred to available-for-sale or trading securities during the calendar year-to-date (report the amortized cost at date of sale or transfer)',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFA5310': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Chief Executive Officer FAX None',
#   'Schedule_label': 'Contact Information(Form Type - 031)'},
#  'RCFD2081': {'Schedule': 'RCCI',
#   'MDRM_Label': 'Loans to foreign governments and official institutions (including foreign central banks)',
#   'Schedule_label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'},
#  'RCFD2107': {'Schedule': 'RCCI',
#   'MDRM_Label': 'Obligations (other than securities and leases) of states and political subdivisions in the U.S.',
#   'Schedule_label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'},
#  'RCFD2122': {'Schedule': 'RCCI',
#   'MDRM_Label': 'Total loans and leases held for investment and held for sale (item 12, column A must equal Schedule RC, sum of items 4.a and 4.b)',
#   'Schedule_label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'},
#  'RCFD2123': {'Schedule': 'RCCI',
#   'MDRM_Label': 'LESS: Any unearned income on loans reflected in items 1-9 above',
#   'Schedule_label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'},
#  'RCFD2130': {'Schedule': 'RC',
#   'MDRM_Label': 'Investments in unconsolidated subsidiaries and associated companies',
#   'Schedule_label': 'Schedule RC - Balance Sheet(Form Type - 031)'},
#  'RCFD2145': {'Schedule': 'RC',
#   'MDRM_Label': 'Premises and fixed assets (including capitalized leases)',
#   'Schedule_label': 'Schedule RC - Balance Sheet(Form Type - 031)'},
#  'RCFD2148': {'Schedule': 'RCF',
#   'MDRM_Label': 'Net deferred tax assets',
#   'Schedule_label': 'Schedule RC-F - Other Assets(Form Type - 031)'},
#  'RCFD2160': {'Schedule': 'RCF',
#   'MDRM_Label': 'Total (sum of items 1 through 6) (must equal Schedule RC, item 11)',
#   'Schedule_label': 'Schedule RC-F - Other Assets(Form Type - 031)'},
#  'RCFD2168': {'Schedule': 'RCF',
#   'MDRM_Label': 'All other assets (itemize and describe amounts greater than $100,000 that exceed 25% of this item)',
#   'Schedule_label': 'Schedule RC-F - Other Assets(Form Type - 031)'},
#  'RCFD2170': {'Schedule': 'RCRII',
#   'MDRM_Label': 'Total balance sheet assets',
#   'Schedule_label': 'Schedule RC-R Part II - Risk-Weighted Assets(Form Type - 031)'},
#  'RCFD2746': {'Schedule': 'RCCI',
#   'MDRM_Label': 'Loans to finance commercial real estate, construction, and land development activities (not secured by real estate) included in Schedule RC-C, part I, items 4 and 9, column A',
#   'Schedule_label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'},
#  'RCFD2930': {'Schedule': 'RCG',
#   'MDRM_Label': 'Total',
#   'Schedule_label': 'Schedule RC-G - Other Liabilities(Form Type - 031)'},
#  'RCFD2938': {'Schedule': 'RCG',
#   'MDRM_Label': 'All other liabilities (itemize and describe amounts greater than $100,000 that exceed 25 percent of this item)',
#   'Schedule_label': 'Schedule RC-G - Other Liabilities(Form Type - 031)'},
#  'RCFD2948': {'Schedule': 'RC',
#   'MDRM_Label': 'Total liabilities (sum of items 13 through 20)',
#   'Schedule_label': 'Schedule RC - Balance Sheet(Form Type - 031)'},
#  'RCFD3049': {'Schedule': 'RCG',
#   'MDRM_Label': 'Net deferred tax liabilities',
#   'Schedule_label': 'Schedule RC-G - Other Liabilities(Form Type - 031)'},
#  'RCFD3123': {'Schedule': 'RCRII',
#   'MDRM_Label': 'LESS: Allowance for loan and lease losses',
#   'Schedule_label': 'Schedule RC-R Part II - Risk-Weighted Assets(Form Type - 031)'},
#  'RCFD3128': {'Schedule': 'RCRII',
#   'MDRM_Label': 'LESS: Allocated transfer risk reserve',
#   'Schedule_label': 'Schedule RC-R Part II - Risk-Weighted Assets(Form Type - 031)'},
#  'RCFD3200': {'Schedule': 'RC',
#   'MDRM_Label': 'Subordinated notes and debentures',
#   'Schedule_label': 'Schedule RC - Balance Sheet(Form Type - 031)'},
#  'RCFD3230': {'Schedule': 'RC',
#   'MDRM_Label': 'Common stock',
#   'Schedule_label': 'Schedule RC - Balance Sheet(Form Type - 031)'},
#  'RCFD3300': {'Schedule': 'RC',
#   'MDRM_Label': 'Total liabilities and equity capital (sum of items 21 and 28)',
#   'Schedule_label': 'Schedule RC - Balance Sheet(Form Type - 031)'},
#  'RCFD3353': {'Schedule': 'RCK',
#   'MDRM_Label': 'Federal funds purchased and securities sold under agreements to repurchase',
#   'Schedule_label': 'Schedule RC-K - Quarterly Averages(Form Type - 031)'},
#  'RCFD3355': {'Schedule': 'RCK',
#   'MDRM_Label': 'Other borrowed money (includes mortgage indebtedness and obligations under capitalized leases)',
#   'Schedule_label': 'Schedule RC-K - Quarterly Averages(Form Type - 031)'},
#  'RCFD3365': {'Schedule': 'RCK',
#   'MDRM_Label': 'Federal funds sold and securities purchased under agreements to resell',
#   'Schedule_label': 'Schedule RC-K - Quarterly Averages(Form Type - 031)'},
#  'RCFD3368': {'Schedule': 'RCK',
#   'MDRM_Label': 'Total assets',
#   'Schedule_label': 'Schedule RC-K - Quarterly Averages(Form Type - 031)'},
#  'RCFD3381': {'Schedule': 'RCK',
#   'MDRM_Label': 'Interest-bearing balances due from depository institutions',
#   'Schedule_label': 'Schedule RC-K - Quarterly Averages(Form Type - 031)'},
#  'RCFD3401': {'Schedule': 'RCK',
#   'MDRM_Label': 'Trading assets',
#   'Schedule_label': 'Schedule RC-K - Quarterly Averages(Form Type - 031)'},
#  'RCFD3411': {'Schedule': 'RCL',
#   'MDRM_Label': 'Commercial and similar letters of credit',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFD3430': {'Schedule': 'RCL',
#   'MDRM_Label': 'All other off-balance sheet liabilities (exclude derivatives) (itemize and describe each component of this item over 25% of Schedule RC, item 27.a, "Total bank equity capital")',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFD3484': {'Schedule': 'RCK',
#   'MDRM_Label': 'Lease financing receivables (net of unearned income)',
#   'Schedule_label': 'Schedule RC-K - Quarterly Averages(Form Type - 031)'},
#  'RCFD3505': {'Schedule': 'RCN',
#   'MDRM_Label': 'Debt securities and other assets (exclude other real estate owned and other repossessed assets)',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD3506': {'Schedule': 'RCN',
#   'MDRM_Label': 'Debt securities and other assets (exclude other real estate owned and other repossessed assets)',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD3507': {'Schedule': 'RCN',
#   'MDRM_Label': 'Debt securities and other assets (exclude other real estate owned and other repossessed assets)',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD3529': {'Schedule': 'RCN',
#   'MDRM_Label': 'Derivative contracts: Fair value of amounts carried as assets',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD3530': {'Schedule': 'RCN',
#   'MDRM_Label': 'Derivative contracts: Fair value of amounts carried as assets',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD3531': {'Schedule': 'RCD',
#   'MDRM_Label': 'U.S. Treasury securities',
#   'Schedule_label': 'Schedule RC-D - Trading Assets and Liabilities(Form Type - 031)'},
#  'RCFD3532': {'Schedule': 'RCD',
#   'MDRM_Label': 'U.S. Government agency obligations (exclude mortgage-backed securities)',
#   'Schedule_label': 'Schedule RC-D - Trading Assets and Liabilities(Form Type - 031)'},
#  'RCFD3533': {'Schedule': 'RCD',
#   'MDRM_Label': 'Securities issued by states and political subdivisions in the U.S.',
#   'Schedule_label': 'Schedule RC-D - Trading Assets and Liabilities(Form Type - 031)'},
#  'RCFD3541': {'Schedule': 'RCD',
#   'MDRM_Label': 'Other trading assets',
#   'Schedule_label': 'Schedule RC-D - Trading Assets and Liabilities(Form Type - 031)'},
#  'RCFD3545': {'Schedule': 'RCD',
#   'MDRM_Label': 'Total trading assets (sum of items 1 through 11) (total of column A must equal Schedule RC, item 5)',
#   'Schedule_label': 'Schedule RC-D - Trading Assets and Liabilities(Form Type - 031)'},
#  'RCFD3548': {'Schedule': 'RCD',
#   'MDRM_Label': 'Total trading liabilities (sum of items 13.a through 14) (total of column A must equal Schedule RC, item 15)',
#   'Schedule_label': 'Schedule RC-D - Trading Assets and Liabilities(Form Type - 031)'},
#  'RCFD3656': {'Schedule': 'RC',
#   'MDRM_Label': 'Direct and indirect investments in real estate ventures',
#   'Schedule_label': 'Schedule RC - Balance Sheet(Form Type - 031)'},
#  'RCFD3819': {'Schedule': 'RCL',
#   'MDRM_Label': 'Financial standby letters of credit and foreign office guarantees',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFD3821': {'Schedule': 'RCL',
#   'MDRM_Label': 'Performance standby letters of credit and foreign office guarantees',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFD3838': {'Schedule': 'RC',
#   'MDRM_Label': 'Perpetual preferred stock and related surplus',
#   'Schedule_label': 'Schedule RC - Balance Sheet(Form Type - 031)'},
#  'RCFD3839': {'Schedule': 'RC',
#   'MDRM_Label': 'Surplus (exclude all surplus related to preferred stock)',
#   'Schedule_label': 'Schedule RC - Balance Sheet(Form Type - 031)'},
#  'RCFD4088': {'Schedule': 'RCM',
#   'MDRM_Label': "Do any of the bank's Internet Web sites have transactional capability, i.e., allow the bank's customers to execute transactions on their accounts through the Web site?",
#   'Schedule_label': 'Schedule RC-M - Memoranda(Form Type - 031)'},
#  'RCFA5311': {'Schedule': 'RCRI',
#   'MDRM_Label': 'Secured by 1-4 family residential properties in domestic offices: Closed-end loans secured by 1-4 family residential properties: Secured by junior liens None',
#   'Schedule_label': 'Schedule RI-B Part I - Charge-offs and Recoveries on Loans and Leases(Form Type - 031)'},
#  'RCFD5389': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans to foreign governments and official institutions',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD5390': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans to foreign governments and official institutions',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD5391': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans to foreign governments and official institutions',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD5459': {'Schedule': 'RCN',
#   'MDRM_Label': 'All other loans',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD5460': {'Schedule': 'RCN',
#   'MDRM_Label': 'All other loans',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD5461': {'Schedule': 'RCN',
#   'MDRM_Label': 'All other loans',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD5591': {'Schedule': 'RCL',
#   'MDRM_Label': 'All other off-balance sheet assets (exclude derivatives) (itemize and describe each component of this item over 25% of Schedule RC, item 27.a, "Total bank equity capital")',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFD6558': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans to finance commercial real estate, construction, and land development activities (not secured by real estate) included in Schedule RC-N, items 4 and 7, above',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD6559': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans to finance commercial real estate, construction, and land development activities (not secured by real estate) included in Schedule RC-N, items 4 and 7, above',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD6560': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans to finance commercial real estate, construction, and land development activities (not secured by real estate) included in Schedule RC-N, items 4 and 7, above',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFD6724': {'Schedule': 'RC',
#   'MDRM_Label': 'Indicate in the box at the right the number of the statement below that best describes the most comprehensive level of auditing work performed for the bank by independent external auditors as of any date during 2022',
#   'Schedule_label': 'Schedule RC - Balance Sheet(Form Type - 031)'},
#  'RCFD8496': {'Schedule': 'RCB',
#   'MDRM_Label': 'Securities issued by states and political subdivisions in the U.S.',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFD8497': {'Schedule': 'RCB',
#   'MDRM_Label': 'Securities issued by states and political subdivisions in the U.S.',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFD8498': {'Schedule': 'RCB',
#   'MDRM_Label': 'Securities issued by states and political subdivisions in the U.S.',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFD8499': {'Schedule': 'RCB',
#   'MDRM_Label': 'Securities issued by states and political subdivisions in the U.S.',
#   'Schedule_label': 'Schedule RC-B - Securities(Form Type - 031)'},
#  'RCFD8723': {'Schedule': 'RCL',
#   'MDRM_Label': 'Total gross notional amount of derivative contracts held for trading',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFD8724': {'Schedule': 'RCL',
#   'MDRM_Label': 'Total gross notional amount of derivative contracts held for trading',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFD8725': {'Schedule': 'RCL',
#   'MDRM_Label': 'Total gross notional amount of derivative contracts held for purposes other than trading',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFD8726': {'Schedule': 'RCL',
#   'MDRM_Label': 'Total gross notional amount of derivative contracts held for purposes other than trading',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFD8727': {'Schedule': 'RCL',
#   'MDRM_Label': 'Total gross notional amount of derivative contracts held for purposes other than trading',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFD8728': {'Schedule': 'RCL',
#   'MDRM_Label': 'Total gross notional amount of derivative contracts held for purposes other than trading',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFD8765': {'Schedule': 'RCL',
#   'MDRM_Label': 'Spot foreign exchange contracts',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFDA126': {'Schedule': 'RCL',
#   'MDRM_Label': 'Total gross notional amount of derivative contracts held for trading',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFDA127': {'Schedule': 'RCL',
#   'MDRM_Label': 'Total gross notional amount of derivative contracts held for trading',
#   'Schedule_label': 'Schedule RC-L - Derivatives and Off-Balance Sheet Items(Form Type - 031)'},
#  'RCFDA222': {'Schedule': 'RCRII',
#   'MDRM_Label': 'LESS: Excess allowance for loan and lease losses',
#   'Schedule_label': 'Schedule RC-R Part II - Risk-Weighted Assets(Form Type - 031)'},
#  'RCFDA345': {'Schedule': 'RCT',
#   'MDRM_Label': 'Does the institution have fiduciary powers?  (If "NO," do not complete Schedule RC-T.)',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDA346': {'Schedule': 'RCT',
#   'MDRM_Label': 'Does the institution exercise the fiduciary powers it has been granted?',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB556': {'Schedule': 'RCF',
#   'MDRM_Label': 'Accrued interest receivable',
#   'Schedule_label': 'Schedule RC-F - Other Assets(Form Type - 031)'},
#  'RCFDB557': {'Schedule': 'RCG',
#   'MDRM_Label': 'Allowance for credit losses on off-balance sheet credit exposures',
#   'Schedule_label': 'Schedule RC-G - Other Liabilities(Form Type - 031)'},
#  'RCFDB558': {'Schedule': 'RCK',
#   'MDRM_Label': 'U.S. Treasury securities and U.S. Government agency obligations (excluding mortgage-backed securities)',
#   'Schedule_label': 'Schedule RC-K - Quarterly Averages(Form Type - 031)'},
#  'RCFDB559': {'Schedule': 'RCK',
#   'MDRM_Label': 'Mortgage-backed securities',
#   'Schedule_label': 'Schedule RC-K - Quarterly Averages(Form Type - 031)'},
#  'RCFDB560': {'Schedule': 'RCK',
#   'MDRM_Label': 'All other debt securities and equity securities with readily determinable fair values not held for trading',
#   'Schedule_label': 'Schedule RC-K - Quarterly Averages(Form Type - 031)'},
#  'RCFDB569': {'Schedule': 'RCM',
#   'MDRM_Label': 'Does the reporting bank sell private label or third party mutual funds and annuities?',
#   'Schedule_label': 'Schedule RC-M - Memoranda(Form Type - 031)'},
#  'RCFDB570': {'Schedule': 'RCM',
#   'MDRM_Label': "Assets under the reporting bank's management in proprietary mutual funds and annuities",
#   'Schedule_label': 'Schedule RC-M - Memoranda(Form Type - 031)'},
#  'RCFDB704': {'Schedule': 'RCRII',
#   'MDRM_Label': 'Risk-weighted assets before deductions for excess allowance of loan and lease losses and allocated risk transfer risk reserve',
#   'Schedule_label': 'Schedule RC-R Part II - Risk-Weighted Assets(Form Type - 031)'},
#  'RCFDB705': {'Schedule': 'RCS',
#   'MDRM_Label': 'Outstanding principal balance of assets sold and securitized by the reporting bank with servicing retained or with recourse or other seller-provided credit enhancements',
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB706': {'Schedule': 'RCS',
#   'MDRM_Label': 'Outstanding principal balance of assets sold and securitized by the reporting bank with servicing retained or with recourse or other seller-provided credit enhancements',
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB707': {'Schedule': 'RCS',
#   'MDRM_Label': 'Outstanding principal balance of assets sold and securitized by the reporting bank with servicing retained or with recourse or other seller-provided credit enhancements',
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB708': {'Schedule': 'RCS',
#   'MDRM_Label': 'Outstanding principal balance of assets sold and securitized by the reporting bank with servicing retained or with recourse or other seller-provided credit enhancements',
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB709': {'Schedule': 'RCS',
#   'MDRM_Label': 'Outstanding principal balance of assets sold and securitized by the reporting bank with servicing retained or with recourse or other seller-provided credit enhancements',
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB710': {'Schedule': 'RCS',
#   'MDRM_Label': 'Outstanding principal balance of assets sold and securitized by the reporting bank with servicing retained or with recourse or other seller-provided credit enhancements',
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB711': {'Schedule': 'RCS',
#   'MDRM_Label': 'Outstanding principal balance of assets sold and securitized by the reporting bank with servicing retained or with recourse or other seller-provided credit enhancements',
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB726': {'Schedule': 'RCS',
#   'MDRM_Label': "Reporting bank's unused commitments to provide liquidity to structures reported in item 1",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB727': {'Schedule': 'RCS',
#   'MDRM_Label': "Reporting bank's unused commitments to provide liquidity to structures reported in item 1",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB728': {'Schedule': 'RCS',
#   'MDRM_Label': "Reporting bank's unused commitments to provide liquidity to structures reported in item 1",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB729': {'Schedule': 'RCS',
#   'MDRM_Label': "Reporting bank's unused commitments to provide liquidity to structures reported in item 1",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB730': {'Schedule': 'RCS',
#   'MDRM_Label': "Reporting bank's unused commitments to provide liquidity to structures reported in item 1",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB731': {'Schedule': 'RCS',
#   'MDRM_Label': "Reporting bank's unused commitments to provide liquidity to structures reported in item 1",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB732': {'Schedule': 'RCS',
#   'MDRM_Label': "Reporting bank's unused commitments to provide liquidity to structures reported in item 1",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB776': {'Schedule': 'RCS',
#   'MDRM_Label': "Maximum amount of credit exposure arising from credit enhancements provided by the reporting bank to other institutions' securitization structures in the form of standby letters of credit, purchased subordinated securities, and other enhancements",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB779': {'Schedule': 'RCS',
#   'MDRM_Label': "Maximum amount of credit exposure arising from credit enhancements provided by the reporting bank to other institutions' securitization structures in the form of standby letters of credit, purchased subordinated securities, and other enhancements",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB780': {'Schedule': 'RCS',
#   'MDRM_Label': "Maximum amount of credit exposure arising from credit enhancements provided by the reporting bank to other institutions' securitization structures in the form of standby letters of credit, purchased subordinated securities, and other enhancements",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB781': {'Schedule': 'RCS',
#   'MDRM_Label': "Maximum amount of credit exposure arising from credit enhancements provided by the reporting bank to other institutions' securitization structures in the form of standby letters of credit, purchased subordinated securities, and other enhancements",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB782': {'Schedule': 'RCS',
#   'MDRM_Label': "Maximum amount of credit exposure arising from credit enhancements provided by the reporting bank to other institutions' securitization structures in the form of standby letters of credit, purchased subordinated securities, and other enhancements",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB783': {'Schedule': 'RCS',
#   'MDRM_Label': "Reporting bank's unused commitments to provide liquidity to other institutions' securitization structures",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB786': {'Schedule': 'RCS',
#   'MDRM_Label': "Reporting bank's unused commitments to provide liquidity to other institutions' securitization structures",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB787': {'Schedule': 'RCS',
#   'MDRM_Label': "Reporting bank's unused commitments to provide liquidity to other institutions' securitization structures",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB788': {'Schedule': 'RCS',
#   'MDRM_Label': "Reporting bank's unused commitments to provide liquidity to other institutions' securitization structures",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB789': {'Schedule': 'RCS',
#   'MDRM_Label': "Reporting bank's unused commitments to provide liquidity to other institutions' securitization structures",
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB790': {'Schedule': 'RCS',
#   'MDRM_Label': 'Assets sold with recourse or other seller-provided credit enhancements and not securitized by the reporting bank',
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB796': {'Schedule': 'RCS',
#   'MDRM_Label': 'Assets sold with recourse or other seller-provided credit enhancements and not securitized by the reporting bank',
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB797': {'Schedule': 'RCS',
#   'MDRM_Label': 'Maximum amount of credit exposure arising from recourse or other seller-provided credit enhancements provided to assets reported in item 11',
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB803': {'Schedule': 'RCS',
#   'MDRM_Label': 'Maximum amount of credit exposure arising from recourse or other seller-provided credit enhancements provided to assets reported in item 11',
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDB837': {'Schedule': 'RCCI',
#   'MDRM_Label': 'Loans secured by real estate to non-U.S. addressees (domicile) (included in Schedule RC-C, Part I, item 1, column A, or Schedule RC-C, Part I, items 1.a.(1) through 1.e.(2), column A, as appropriate)',
#   'Schedule_label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'},
#  'RCFDB867': {'Schedule': 'RCT',
#   'MDRM_Label': 'Does the institution have any fiduciary or related activity (in the form of assets or accounts) to report in this schedule?  (If "NO," do not complete the rest of Schedule RC-T.)',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB868': {'Schedule': 'RCT',
#   'MDRM_Label': 'Personal trust and agency accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB869': {'Schedule': 'RCT',
#   'MDRM_Label': 'Personal trust and agency accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB870': {'Schedule': 'RCT',
#   'MDRM_Label': 'Personal trust and agency accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB871': {'Schedule': 'RCT',
#   'MDRM_Label': 'Personal trust and agency accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB884': {'Schedule': 'RCT',
#   'MDRM_Label': 'Corporate trust and agency accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB885': {'Schedule': 'RCT',
#   'MDRM_Label': 'Corporate trust and agency accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB886': {'Schedule': 'RCT',
#   'MDRM_Label': 'Investment management and investment advisory agency accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB888': {'Schedule': 'RCT',
#   'MDRM_Label': 'Investment management and investment advisory agency accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB890': {'Schedule': 'RCT',
#   'MDRM_Label': 'Other fiduciary accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB891': {'Schedule': 'RCT',
#   'MDRM_Label': 'Other fiduciary accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB892': {'Schedule': 'RCT',
#   'MDRM_Label': 'Other fiduciary accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB893': {'Schedule': 'RCT',
#   'MDRM_Label': 'Other fiduciary accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB894': {'Schedule': 'RCT',
#   'MDRM_Label': 'Total fiduciary accounts (sum of items 4 through 9)',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB895': {'Schedule': 'RCT',
#   'MDRM_Label': 'Total fiduciary accounts (sum of items 4 through 9)',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB896': {'Schedule': 'RCT',
#   'MDRM_Label': 'Total fiduciary accounts (sum of items 4 through 9)',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB897': {'Schedule': 'RCT',
#   'MDRM_Label': 'Total fiduciary accounts (sum of items 4 through 9)',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB898': {'Schedule': 'RCT',
#   'MDRM_Label': 'Custody and safekeeping accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDB899': {'Schedule': 'RCT',
#   'MDRM_Label': 'Custody and safekeeping accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDC001': {'Schedule': 'RCT',
#   'MDRM_Label': 'Corporate trust and agency accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDC002': {'Schedule': 'RCT',
#   'MDRM_Label': 'Corporate trust and agency accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RCFDC226': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans and leases held for sale (included in Schedule RC-N, items 1 through 8, above)',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFDC240': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans and leases held for sale (included in Schedule RC-N, items 1 through 8, above)',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFDC241': {'Schedule': 'RCN',
#   'MDRM_Label': 'Loans and leases held for sale (included in Schedule RC-N, items 1 through 8, above)',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFDC391': {'Schedule': 'RCCI',
#   'MDRM_Label': 'Outstanding credit card fees and finance charges included in Schedule RC-C, part I, item 6.a, column A',
#   'Schedule_label': 'Schedule RC-C Part I - Loans and Leases(Form Type - 031)'},
#  'RCFDC407': {'Schedule': 'RCS',
#   'MDRM_Label': 'Outstanding credit card fees and finance charges included in Schedule RC-S, item 1, column C',
#   'Schedule_label': 'Schedule RC-S - Servicing Securitization and Asset Sale Activities(Form Type - 031)'},
#  'RCFDC410': {'Schedule': 'RCN',
#   'MDRM_Label': 'Additions to nonaccrual assets during the previous six months',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFDC411': {'Schedule': 'RCN',
#   'MDRM_Label': 'Nonaccrual assets sold during the previous six months',
#   'Schedule_label': 'Schedule RC-N - Past Due and Nonaccrual Loans Leases and Other Assets(Form Type - 031)'},
#  'RCFDD957': {'Schedule': 'RCRII',
#   'MDRM_Label': 'Cash and balances due from depository institutions',
#   'Schedule_label': 'Schedule RC-R Part II - Risk-Weighted Assets(Form Type - 031)'},
#  'RCFDD958': {'Schedule': 'RCRII',
#   'MDRM_Label': 'Cash and balances due from depository institutions',
#   'Schedule_label': 'Schedule RC-R Part II - Risk-Weighted Assets(Form Type - 031)'},
#  'RCFDD959': {'Schedule': 'RCRII',
#   'MDRM_Label': 'Cash and balances due from depository institutions',
#   'Schedule_label': 'Schedule RC-R Part II - Risk-Weighted Assets(Form Type - 031)'},
#  'RCFDD960': {'Schedule': 'RCRII',
# ...
#  'RIADA488': {'Schedule': 'RCT',
#   'MDRM_Label': 'Less:  Net losses from fiduciary and related services',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RIADA491': {'Schedule': 'RCT',
#   'MDRM_Label': 'Net fiduciary and related services income',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RIADA530': {'Schedule': 'RI',
#   'MDRM_Label': 'Does the reporting bank have a Subchapter S election in effect for federal income tax purposes for the current tax year?',
#   'Schedule_label': 'Schedule RI - Income Statement(Form Type - 031)'},
#  'RIADB507': {'Schedule': 'RIA',
#   'MDRM_Label': 'Cumulative effect of changes in accounting principles and corrections of material accounting errors',
#   'Schedule_label': 'Schedule RI-A - Changes in Bank Equity Capital(Form Type - 031)'},
#  'RIADB508': {'Schedule': 'RIA',
#   'MDRM_Label': 'Balance end of previous calendar year as restated (sum of items 1 and 2)',
#   'Schedule_label': 'Schedule RI-A - Changes in Bank Equity Capital(Form Type - 031)'},
#  'RIADB509': {'Schedule': 'RIA',
#   'MDRM_Label': 'Sale, conversion, acquisition, or retirement of capital stock, net (excluding treasury stock transactions)',
#   'Schedule_label': 'Schedule RI-A - Changes in Bank Equity Capital(Form Type - 031)'},
#  'RIADB510': {'Schedule': 'RIA',
#   'MDRM_Label': 'Treasury stock transactions, net',
#   'Schedule_label': 'Schedule RI-A - Changes in Bank Equity Capital(Form Type - 031)'},
#  'RIADB511': {'Schedule': 'RIA',
#   'MDRM_Label': 'Other comprehensive income',
#   'Schedule_label': 'Schedule RI-A - Changes in Bank Equity Capital(Form Type - 031)'},
#  'RIADB522': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Balance most recently reported for the December 31, 2022, Reports of Condition and Income (i.e., after adjustments from amended Reports of Income)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADB904': {'Schedule': 'RCT',
#   'MDRM_Label': 'Personal trust and agency accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RIADB909': {'Schedule': 'RCT',
#   'MDRM_Label': 'Custody and safekeeping accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RIADB910': {'Schedule': 'RCT',
#   'MDRM_Label': 'Other fiduciary and related services income',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RIADB911': {'Schedule': 'RCT',
#   'MDRM_Label': 'Plus:  Intracompany income credits for fiduciary and related services',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RIADC058': {'Schedule': 'RCT',
#   'MDRM_Label': 'Less:  Expenses',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RIADC079': {'Schedule': 'RIBII',
#   'MDRM_Label': 'LESS:  Charge-offs (column A must equal Part I, item 9, column A, above less Schedule RI-B, Part II, item 4, column A)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADC233': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Adjustments* (see instructions for this schedule)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADC388': {'Schedule': 'RIBI',
#   'MDRM_Label': 'Uncollectible retail credit card fees and finance charges reversed against income (i.e., not included in charge-offs against the allowance for loan and lease losses)',
#   'Schedule_label': 'Schedule RI-B Part I - Charge-offs and Recoveries on Loans and Leases(Form Type - 031)'},
#  'RIADC389': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Separate valuation allowance for uncollectible retail credit card fees and finance charges',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADC390': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Amount of allowance for loan and lease losses attributable to retail credit card fees and finance charges',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADC435': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Allocated transfer risk reserve included in Schedule RI-B, Part II, item 7, column A, above',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADC781': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Amount of allowance for post-acquisition credit losses on purchased credit-impaired loans accounted for in accordance with FASB ASC 310-30 (former AICPA Statement of Position 03-3) (included in Schedule RI-B, Part II, item 7, column A, above)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADC899': {'Schedule': 'RID',
#   'MDRM_Label': 'Total interest income in foreign offices',
#   'Schedule_label': 'Schedule RI-D - Income from Foreign Offices(Form Type - 031)'},
#  'RIADC900': {'Schedule': 'RID',
#   'MDRM_Label': 'Total interest expense in foreign offices',
#   'Schedule_label': 'Schedule RI-D - Income from Foreign Offices(Form Type - 031)'},
#  'RIADC907': {'Schedule': 'RID',
#   'MDRM_Label': 'Total noninterest expense in foreign offices',
#   'Schedule_label': 'Schedule RI-D - Income from Foreign Offices(Form Type - 031)'},
#  'RIADC908': {'Schedule': 'RID',
#   'MDRM_Label': 'Adjustments to pretax income in foreign offices for internal allocations to foreign offices to reflect the effects of equity capital on overall bank funding costs',
#   'Schedule_label': 'Schedule RI-D - Income from Foreign Offices(Form Type - 031)'},
#  'RIADC909': {'Schedule': 'RID',
#   'MDRM_Label': 'Applicable income taxes (on items 1 through 7)',
#   'Schedule_label': 'Schedule RI-D - Income from Foreign Offices(Form Type - 031)'},
#  'RIADC911': {'Schedule': 'RID',
#   'MDRM_Label': 'Net income attributable to foreign offices before internal allocations of income and expense (item 1 plus or minus items 2 through 9)',
#   'Schedule_label': 'Schedule RI-D - Income from Foreign Offices(Form Type - 031)'},
#  'RIADC913': {'Schedule': 'RID',
#   'MDRM_Label': 'Eliminations arising from the consolidation of foreign offices with domestic offices',
#   'Schedule_label': 'Schedule RI-D - Income from Foreign Offices(Form Type - 031)'},
#  'RIADC914': {'Schedule': 'RID',
#   'MDRM_Label': 'Consolidated net income attributable to foreign offices (sum of items 10 and 12)',
#   'Schedule_label': 'Schedule RI-D - Income from Foreign Offices(Form Type - 031)'},
#  'RIADFT28': {'Schedule': 'RI',
#   'MDRM_Label': 'Discontinued operations, net of applicable income taxes (Describe on Schedule RI-E - Explanations)',
#   'Schedule_label': 'Schedule RI - Income Statement(Form Type - 031)'},
#  'RIADG103': {'Schedule': 'RI',
#   'MDRM_Label': 'LESS: Net income (loss) attributable to noncontrolling (minority) interests (if net income, report as a positive value; if net loss, report as a negative value)',
#   'Schedule_label': 'Schedule RI - Income Statement(Form Type - 031)'},
#  'RIADG104': {'Schedule': 'RI',
#   'MDRM_Label': 'Net income (loss) attributable to bank and noncontrolling (minority) interests (sum of items 10 and 11)',
#   'Schedule_label': 'Schedule RI - Income Statement(Form Type - 031)'},
#  'RIADGW64': {'Schedule': 'RID',
#   'MDRM_Label': 'Discontinued operations, net of applicable income taxes, in foreign offices',
#   'Schedule_label': 'Schedule RI-D - Income from Foreign Offices(Form Type - 031)'},
#  'RIADHT85': {'Schedule': 'RCP',
#   'MDRM_Label': 'Noninterest income for the quarter from the sale, securitization, and servicing of 1-4 family residential mortgage loans (included in Schedule RI, items 5.c, 5.f, 5.g, and 5.i)',
#   'Schedule_label': 'Schedule RC-P - 1-4 Family Residential Mortgage Banking Activities in Domestic Offices(Form Type - 031)'},
#  'RIADJ315': {'Schedule': 'RCT',
#   'MDRM_Label': 'Investment management and investment advisory agency accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RIADJ316': {'Schedule': 'RCT',
#   'MDRM_Label': 'Foundation and endowment trust and agency accounts',
#   'Schedule_label': 'Schedule RC-T - Fiduciary and Related Services(Form Type - 031)'},
#  'RIADJ321': {'Schedule': 'RI',
#   'MDRM_Label': 'Other-than-temporary impairment losses on held-to-maturity and available-for-sale debt securities',
#   'Schedule_label': 'Schedule RI - Income Statement(Form Type - 031)'},
#  'RIADJA28': {'Schedule': 'RID',
#   'MDRM_Label': 'Realized gains (losses) on held-to-maturity and available-for-sale debt securities and change in net unrealized holding gains (losses) on equity securities not held for trading in foreign offices',
#   'Schedule_label': 'Schedule RI-D - Income from Foreign Offices(Form Type - 031)'},
#  'RIADJH88': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Balance most recently reported for the December 31, 2022, Reports of Condition and Income (i.e., after adjustments from amended Reports of Income)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJH89': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Recoveries (column A must equal Part I, item 9, column B, above)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJH90': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Provisions for credit losses',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJH91': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Adjustments* (see instructions for this schedule)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJH92': {'Schedule': 'RIBII',
#   'MDRM_Label': 'LESS:  Charge-offs (column A must equal Part I, item 9, column A, above less Schedule RI-B, Part II, item 4, column A)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJH93': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Balance end of current period (sum of items 1, 2, 5, and 6, less items 3 and 4) (column A must equal Schedule RC, item 4.c)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJH94': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Balance most recently reported for the December 31, 2022, Reports of Condition and Income (i.e., after adjustments from amended Reports of Income)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJH95': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Recoveries (column A must equal Part I, item 9, column B, above)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJH96': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Provisions for credit losses',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJH97': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Adjustments* (see instructions for this schedule)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJH98': {'Schedule': 'RIBII',
#   'MDRM_Label': 'LESS:  Charge-offs (column A must equal Part I, item 9, column A, above less Schedule RI-B, Part II, item 4, column A)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJH99': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Balance end of current period (sum of items 1, 2, 5, and 6, less items 3 and 4) (column A must equal Schedule RC, item 4.c)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJJ00': {'Schedule': 'RIBII',
#   'MDRM_Label': 'LESS:  Write-downs arising from transfers of financial assets',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJJ01': {'Schedule': 'RIBII',
#   'MDRM_Label': 'LESS:  Write-downs arising from transfers of financial assets',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJJ02': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Provisions for credit losses on other financial assets measured at amortized cost (not included in item 5, above)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADJJ33': {'Schedule': 'RI',
#   'MDRM_Label': 'Provision for loan and lease losses',
#   'Schedule_label': 'Schedule RI - Income Statement(Form Type - 031)'},
#  'RIADKW02': {'Schedule': 'RID',
#   'MDRM_Label': 'Provision for loan and lease losses in foreign offices',
#   'Schedule_label': 'Schedule RI-D - Income from Foreign Offices(Form Type - 031)'},
#  'RIADMG93': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Provisions for credit losses on off-balance-sheet credit exposures',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RIADMG94': {'Schedule': 'RIBII',
#   'MDRM_Label': 'Estimated amount of expected recoveries of amounts previously written off included within the allowance for credit losses on loans and leases held for investment (included in item 7, column A, "Balance end of current period," above)',
#   'Schedule_label': 'Schedule RI-B Part II - Changes in Allowances for Credit Losses(Form Type - 031)'},
#  'RSSD9017': {'Schedule': 'ENT',
#   'MDRM_Label': 'Legal title of bank',
#   'Schedule_label': 'Bank Demographic Information(Form Type - 031)'},
#  'RSSD9050': {'Schedule': 'ENT',
#   'MDRM_Label': 'FDIC certificate number',
#   'Schedule_label': 'Bank Demographic Information(Form Type - 031)'},
#  'RSSD9130': {'Schedule': 'ENT',
#   'MDRM_Label': 'City',
#   'Schedule_label': 'Bank Demographic Information(Form Type - 031)'},
#  'RSSD9200': {'Schedule': 'ENT',
#   'MDRM_Label': 'State abbreviation',
#   'Schedule_label': 'Bank Demographic Information(Form Type - 031)'},
#  'RSSD9220': {'Schedule': 'ENT',
#   'MDRM_Label': 'Zip code',
#   'Schedule_label': 'Bank Demographic Information(Form Type - 031)'},
#  'TEXT6980': {'Schedule': 'NARR',
#   'MDRM_Label': 'Bank Management Statement',
#   'Schedule_label': 'Optional Narrative Statement Concerning the Amounts Reported in the Consolidated Reports of Condition and Income(Form Type - 031)'},
#  'TEXTG546': {'Schedule': 'RCQ',
#   'MDRM_Label': 'Describe component',
#   'Schedule_label': 'Schedule RC-Q - Assets and Liabilities Measured at Fair Value on a Recurring Basis(Form Type - 031)'},
#  'TEXTG551': {'Schedule': 'RCQ',
#   'MDRM_Label': 'Describe component',
#   'Schedule_label': 'Schedule RC-Q - Assets and Liabilities Measured at Fair Value on a Recurring Basis(Form Type - 031)'},
#  'TEXTG556': {'Schedule': 'RCQ',
#   'MDRM_Label': 'Describe component',
#   'Schedule_label': 'Schedule RC-Q - Assets and Liabilities Measured at Fair Value on a Recurring Basis(Form Type - 031)'},
#  'TEXTG561': {'Schedule': 'RCQ',
#   'MDRM_Label': 'Describe component',
#   'Schedule_label': 'Schedule RC-Q - Assets and Liabilities Measured at Fair Value on a Recurring Basis(Form Type - 031)'},
#  'TEXTG571': {'Schedule': 'RCQ',
#   'MDRM_Label': 'Describe component',
#   'Schedule_label': 'Schedule RC-Q - Assets and Liabilities Measured at Fair Value on a Recurring Basis(Form Type - 031)'},
#  'TEXTG576': {'Schedule': 'RCQ',
#   'MDRM_Label': 'Describe component',
#   'Schedule_label': 'Schedule RC-Q - Assets and Liabilities Measured at Fair Value on a Recurring Basis(Form Type - 031)'},
#  'TEXTG581': {'Schedule': 'RCQ',
#   'MDRM_Label': 'Describe component',
#   'Schedule_label': 'Schedule RC-Q - Assets and Liabilities Measured at Fair Value on a Recurring Basis(Form Type - 031)'},
#  'TEXTG586': {'Schedule': 'RCQ',
#   'MDRM_Label': 'Describe component',
#   'Schedule_label': 'Schedule RC-Q - Assets and Liabilities Measured at Fair Value on a Recurring Basis(Form Type - 031)'}}

# %%
df['data'][498]
# Out:
# {'RCRII': {'line_ids': {'schedule': {'code': 'ffiec031_pres-RCRII',
#     'label': 'Schedule RC-R Part II - Risk-Weighted Assets(Form Type - 031)'},
#    'extra_col_0': {'code': 'ffiec031_pres-line-1010130',
#     'label': 'Securities:'},
#    'extra_col_1': {'code': 'ffiec031_pres-line-1010129',
#     'label': 'Held-to-maturity securities'}},
#   'column_ids': {'schedule': {'code': 'ffiec031_pres-RCRII',
#     'label': 'Schedule RC-R Part II - Risk-Weighted Assets(Form Type - 031)'},
#    'colset': {'code': 'ffiec031_pres-RCRII-80-colset', 'label': None},
#    'column': {'code': 'ffiec031_pres-RCRII-80-column-I',
#     'label': '(Column I) Allocation by Risk-Weight Category 100%'}},
#   'reference': {'line': '2a', 'column': 'I'}}}

# %%
re.split('_',df.index[0])[1]
# Out:
# 'RCFA2170'

# %%
next(iter(df['data'][0]))
# Out:
# 'RCRI'

# %%
line_ids_data = test[next(iter(df['data'][0]))][keys[0]]
schedule_data = line_ids_data['schedule']
extra_col_0_data = line_ids_data['extra_col_0']
schedule_label = schedule_data.get('label', None)
extra_col_0_label = extra_col_0_data.get('label', None)
print("Schedule Label:", schedule_label)
print("Extra_col_0 Label:", extra_col_0_label)
# Out:
# Schedule Label: Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)
# Extra_col_0 Label: Total assets (Schedule RC, item 12); (must be less than $10 billion)

# %%
line_ids_data
# Out:
# {'schedule': {'code': 'ffiec031_pres-RCQ',
#   'label': 'Schedule RC-Q - Assets and Liabilities Measured at Fair Value on a Recurring Basis(Form Type - 031)'},
#  'extra_col_0': {'code': 'ffiec031_pres-line-1010016',
#   'label': 'Describe component'}}

# %%
for key, value in test[next(iter(df['data'][0]))][keys[0]]:
    print(key, '->', value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-904f10967ca1> in <module>
# ----> 1 for key, value in test[next(iter(df['data'][0]))][keys[0]]:
#       2     print(key, '->', value)
#
# ValueError: too many values to unpack (expected 2)

# %%
test = df['data'][0]
for i in test:
    keys= list(test[i].keys())

# %%
keys
# Out:
# ['line_ids', 'column_ids', 'reference']

# %%
    if test[i].keys() == 'line_ids':
        print(test[i].value())

# %%
for ids, info in test.items():
    print("\ntop :", ids)
    for key in info:
        if key == 'line_ids':
            print(list(info[key].values()))
# Out:
# top : RCRI
# [{'code': 'ffiec031_pres-RCRI', 'label': 'Schedule RC-R Part I - Regulatory Capital Components and Ratios(Form Type - 031)'}, {'code': 'ffiec031_pres-line-1010119', 'label': 'Total assets (Schedule RC, item 12); (must be less than $10 billion)'}]
